# %%
model = train_and_get_model(verbose=1)
# Out:
# Training XGB model with hyperparameter tuning... Make sure csv is updated.
# C:\Users\kevin\Anaconda3\envs\tensorflow_env\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# Test Score: 0.903427551664873
# RMSE: 19.234993

# %%
from market_tests import *
test_market_suite()
# Out:
# Tests for market.py PASSED!
# C:\Users\kevin\Anaconda3\envs\tensorflow_env\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# The model could not be found at: ml_models/xgbr_2019-12-24.dat
# Could not train model for the data located in company_stats_2019-12-24.csv. Check that this file exists.
# The model could not be found at: ml_models/xgbr_2019-12-25.dat
# Could not train model for the data located in company_stats_2019-12-25.csv. Check that this file exists.
# C:\Users\kevin\Documents\Projects\Coding Projects\Stock Market\Stock-Market-Analysis\market_ml.py:43: RuntimeWarning: get_model_from_date(2019-12-24) is getting called but date is invalid
#   warnings.warn('get_model_from_date(' + date + ') is getting called but date is invalid', RuntimeWarning)
# C:\Users\kevin\Documents\Projects\Coding Projects\Stock Market\Stock-Market-Analysis\market_ml.py:43: RuntimeWarning: get_model_from_date(2019-12-25) is getting called but date is invalid
#   warnings.warn('get_model_from_date(' + date + ') is getting called but date is invalid', RuntimeWarning)
# C:\Users\kevin\Documents\Projects\Coding Projects\Stock Market\Stock-Market-Analysis\market_ml.py:231: RuntimeWarning: Model has more features than X contains. Using nan instead. Extra features: ['Industry_Publishing - Newspapers', 'Sector_Services']
#   warnings.warn('Model has more features than X contains. Using nan instead. Extra features: ' + str(extra_model_features), RuntimeWarning)
# Tests for market_ml.py PASSED!
# Warning: in_csv is set to False but date has been specified. date will not be used
# Warning: in_csv is set to False but date has been specified. date will not be used
# Warning: in_csv is set to False but date has been specified. date will not be used
# Warning: in_csv is set to False but date has been specified. date will not be used
# The model could not be found at: ml_models/xgbr_2019-12-24.dat
# Could not train model for the data located in company_stats_2019-12-24.csv. Check that this file exists.
# The model could not be found at: ml_models/xgbr_2019-12-25.dat
# Could not train model for the data located in company_stats_2019-12-25.csv. Check that this file exists.
# Calculating Decider for AAPL
# Predicted Price: 282.00122. Actual Price: 289.46
# t-statistic: -2.31813319061614
# The model could not be found at: ml_models/xgbr_2019-12-24.dat
# Could not train model for the data located in company_stats_2019-12-24.csv. Check that this file exists.
# The model could not be found at: ml_models/xgbr_2019-12-25.dat
# Could not train model for the data located in company_stats_2019-12-25.csv. Check that this file exists.
# Calculating Decider for TSLA
# Predicted Price: 417.87943. Actual Price: 428.79
# t-statistic: -1.752808713638999
# The model could not be found at: ml_models/xgbr_2019-12-24.dat
# Could not train model for the data located in company_stats_2019-12-24.csv. Check that this file exists.
# The model could not be found at: ml_models/xgbr_2019-12-25.dat
# Could not train model for the data located in company_stats_2019-12-25.csv. Check that this file exists.
# Calculating Decider for ATVI
# Predicted Price: 59.83601. Actual Price: 59.35
# t-statistic: 0.37121450410081863
# The model could not be found at: ml_models/xgbr_2019-12-24.dat
# Could not train model for the data located in company_stats_2019-12-24.csv. Check that this file exists.
# The model could not be found at: ml_models/xgbr_2019-12-25.dat
# Could not train model for the data located in company_stats_2019-12-25.csv. Check that this file exists.
# Calculating Decider for SNE
# Predicted Price: 69.51187. Actual Price: 67.78
# t-statistic: 2.0905521437824586
# Tests for market_trading.py PASSED!

# %%
update_csv()
# Out:
# Getting data for: A
# Getting data for: AA
# Getting data for: AACG
# Failed to obtain sector and industry for AACG
# Getting data for: AAL
# Getting data for: AAMC
# Failed to parse json response for AAMC
# Ticker: AAMC did not work.
# Getting data for: AAME
# Failed to parse json response for AAME
# Ticker: AAME did not work.
# Getting data for: AAN
# Getting data for: AAOI
# Getting data for: AAON
# Getting data for: AAP
# Getting data for: AAPL
# Getting data for: AAT
# Getting data for: AAU
# Failed to parse json response for AAU
# Ticker: AAU did not work.
# Getting data for: AAWW
# Getting data for: AAXN
# Failed to obtain sector and industry for AAXN
# Getting data for: AB
# Getting data for: ABB
# Getting data for: ABBV
# Getting data for: ABC
# Getting data for: ABCB
# Getting data for: ABDC
# Failed to obtain sector and industry for ABDC
# Getting data for: ABEO
# Failed to obtain sector and industry for ABEO
# Getting data for: ABEOW
# Failed to obtain sector and industry for ABEOW
# Failed to parse json response for ABEOW
# Ticker: ABEOW did not work.
# Getting data for: ABEV
# Failed to obtain sector and industry for ABEV
# Getting data for: ABG
# Getting data for: ABIL
# Failed to obtain sector and industry for ABIL
# Getting data for: ABIO
# Getting data for: ABM
# Getting data for: ABMD
# Getting data for: ABR
# Getting data for: ABR$A
# Failed to obtain sector and industry for ABR$A
# Failed to parse json response for ABR$A
# Ticker: ABR$A did not work.
# Getting data for: ABR$B
# Failed to obtain sector and industry for ABR$B
# Failed to parse json response for ABR$B
# Ticker: ABR$B did not work.
# Getting data for: ABR$C
# Failed to obtain sector and industry for ABR$C
# Failed to parse json response for ABR$C
# Ticker: ABR$C did not work.
# Getting data for: ABT
# Getting data for: ABTX
# Failed to obtain sector and industry for ABTX
# Getting data for: ABUS
# Getting data for: AC
# Failed to obtain sector and industry for AC
# Failed to parse json response for AC
# Ticker: AC did not work.
# Getting data for: ACA
# Failed to obtain sector and industry for ACA
# Getting data for: ACAD
# Getting data for: ACAM
# Failed to obtain sector and industry for ACAM
# Failed to parse json response for ACAM
# Ticker: ACAM did not work.
# Getting data for: ACAMU
# Failed to obtain sector and industry for ACAMU
# Failed to parse json response for ACAMU
# Ticker: ACAMU did not work.
# Getting data for: ACAMW
# Failed to obtain sector and industry for ACAMW
# Failed to parse json response for ACAMW
# Ticker: ACAMW did not work.
# Getting data for: ACB
# Failed to obtain sector and industry for ACB
# Failed to parse json response for ACB
# Ticker: ACB did not work.
# Getting data for: ACBI
# Failed to obtain sector and industry for ACBI
# Getting data for: ACC
# Getting data for: ACCO
# Getting data for: ACER
# Failed to obtain sector and industry for ACER
# Getting data for: ACGL
# Getting data for: ACGLO
# Failed to obtain sector and industry for ACGLO
# Failed to parse json response for ACGLO
# Ticker: ACGLO did not work.
# Getting data for: ACGLP
# Failed to obtain sector and industry for ACGLP
# Failed to parse json response for ACGLP
# Ticker: ACGLP did not work.
# Getting data for: ACH
# Ticker: ACH did not work.
# Getting data for: ACHC
# Getting data for: ACHN
# Getting data for: ACHV
# Failed to obtain sector and industry for ACHV
# Getting data for: ACIA
# Failed to obtain sector and industry for ACIA
# Getting data for: ACIU
# Failed to obtain sector and industry for ACIU
# Getting data for: ACIW
# Getting data for: ACLS
# Getting data for: ACM
# Getting data for: ACMR
# Getting data for: ACN
# Getting data for: ACNB
# Failed to parse json response for ACNB
# Ticker: ACNB did not work.
# Getting data for: ACOR
# Getting data for: ACP
# Failed to obtain sector and industry for ACP
# Failed to parse json response for ACP
# Ticker: ACP did not work.
# Getting data for: ACRE
# Getting data for: ACRS
# Failed to obtain sector and industry for ACRS
# Getting data for: ACRX
# Getting data for: ACST
# Getting data for: ACTG
# Getting data for: ACTT
# Failed to obtain sector and industry for ACTT
# Getting data for: ACTTU
# Failed to obtain sector and industry for ACTTU
# Failed to parse json response for ACTTU
# Ticker: ACTTU did not work.
# Getting data for: ACTTW
# Failed to obtain sector and industry for ACTTW
# Failed to parse json response for ACTTW
# Ticker: ACTTW did not work.
# Getting data for: ACU
# Getting data for: ACV
# Failed to parse json response for ACV
# Ticker: ACV did not work.
# Getting data for: ACY
# Getting data for: ADAP
# Getting data for: ADBE
# Getting data for: ADC
# Getting data for: ADES
# Getting data for: ADI
# Getting data for: ADIL
# Failed to obtain sector and industry for ADIL
# Getting data for: ADILW
# Failed to obtain sector and industry for ADILW
# Failed to parse json response for ADILW
# Ticker: ADILW did not work.
# Getting data for: ADM
# Getting data for: ADMA
# Getting data for: ADMP
# Getting data for: ADMS
# Getting data for: ADNT
# Getting data for: ADP
# Getting data for: ADPT
# Getting data for: ADRO
# Getting data for: ADS
# Getting data for: ADSK
# Getting data for: ADSW
# Failed to obtain sector and industry for ADSW
# Failed to parse json response for ADSW
# Ticker: ADSW did not work.
# Getting data for: ADT
# Getting data for: ADTN
# Getting data for: ADUS
# Getting data for: ADVM
# Failed to obtain sector and industry for ADVM
# Getting data for: ADX
# Failed to parse json response for ADX
# Ticker: ADX did not work.
# Getting data for: ADXS
# Getting data for: AE
# Failed to parse json response for AE
# Ticker: AE did not work.
# Getting data for: AEB
# Failed to obtain sector and industry for AEB
# Failed to parse json response for AEB
# Ticker: AEB did not work.
# Getting data for: AEE
# Getting data for: AEF
# Failed to obtain sector and industry for AEF
# Failed to parse json response for AEF
# Ticker: AEF did not work.
# Getting data for: AEFC
# Failed to obtain sector and industry for AEFC
# Failed to parse json response for AEFC
# Ticker: AEFC did not work.
# Getting data for: AEG
# Failed to obtain sector and industry for AEG
# Getting data for: AEGN
# Getting data for: AEH
# Failed to obtain sector and industry for AEH
# Failed to parse json response for AEH
# Ticker: AEH did not work.
# Getting data for: AEHR
# Getting data for: AEIS
# Getting data for: AEL
# Getting data for: AEM
# Getting data for: AEMD
# Getting data for: AEO
# Getting data for: AEP
# Getting data for: AEP$B
# Failed to obtain sector and industry for AEP$B
# Failed to parse json response for AEP$B
# Ticker: AEP$B did not work.
# Getting data for: AER
# Ticker: AER did not work.
# Getting data for: AERI
# Getting data for: AES
# Getting data for: AESE
# Failed to obtain sector and industry for AESE
# Failed to parse json response for AESE
# Ticker: AESE did not work.
# Getting data for: AEY
# Getting data for: AEYE
# Ticker: AEYE did not work.
# Getting data for: AEZS
# Getting data for: AFB
# Failed to parse json response for AFB
# Ticker: AFB did not work.
# Getting data for: AFC
# Failed to obtain sector and industry for AFC
# Failed to parse json response for AFC
# Ticker: AFC did not work.
# Getting data for: AFG
# Getting data for: AFGB
# Failed to obtain sector and industry for AFGB
# Failed to parse json response for AFGB
# Ticker: AFGB did not work.
# Getting data for: AFGE
# Failed to obtain sector and industry for AFGE
# Failed to parse json response for AFGE
# Ticker: AFGE did not work.
# Getting data for: AFGH
# Failed to obtain sector and industry for AFGH
# Failed to parse json response for AFGH
# Ticker: AFGH did not work.
# Getting data for: AFH
# Getting data for: AFI
# Failed to obtain sector and industry for AFI
# Getting data for: AFIN
# Failed to obtain sector and industry for AFIN
# Getting data for: AFINP
# Failed to obtain sector and industry for AFINP
# Failed to parse json response for AFINP
# Ticker: AFINP did not work.
# Getting data for: AFL
# Getting data for: AFMD
# Getting data for: AFT
# Failed to obtain sector and industry for AFT
# Failed to parse json response for AFT
# Ticker: AFT did not work.
# Getting data for: AFYA
# Failed to obtain sector and industry for AFYA
# Getting data for: AG
# Getting data for: AGBA
# Failed to obtain sector and industry for AGBA
# Failed to parse json response for AGBA
# Ticker: AGBA did not work.
# Getting data for: AGBAR
# Failed to obtain sector and industry for AGBAR
# Failed to parse json response for AGBAR
# Ticker: AGBAR did not work.
# Getting data for: AGBAU
# Failed to obtain sector and industry for AGBAU
# Failed to parse json response for AGBAU
# Ticker: AGBAU did not work.
# Getting data for: AGBAW
# Failed to obtain sector and industry for AGBAW
# Failed to parse json response for AGBAW
# Ticker: AGBAW did not work.
# Getting data for: AGCO
# Getting data for: AGD
# Failed to parse json response for AGD
# Ticker: AGD did not work.
# Getting data for: AGE
# Failed to obtain sector and industry for AGE
# Failed to parse json response for AGE
# Ticker: AGE did not work.
# Getting data for: AGEN
# Getting data for: AGFS
# Getting data for: AGFSW
# Failed to obtain sector and industry for AGFSW
# Failed to parse json response for AGFSW
# Ticker: AGFSW did not work.
# Getting data for: AGI
# Getting data for: AGIO
# Getting data for: AGLE
# Failed to obtain sector and industry for AGLE
# Getting data for: AGM
# Getting data for: AGM$A
# Failed to obtain sector and industry for AGM$A
# Failed to parse json response for AGM$A
# Ticker: AGM$A did not work.
# Getting data for: AGM$C
# Failed to obtain sector and industry for AGM$C
# Failed to parse json response for AGM$C
# Ticker: AGM$C did not work.
# Getting data for: AGM$D
# Failed to obtain sector and industry for AGM$D
# Failed to parse json response for AGM$D
# Ticker: AGM$D did not work.
# Getting data for: AGM.A
# Failed to obtain sector and industry for AGM.A
# Failed to parse json response for AGM.A
# Ticker: AGM.A did not work.
# Getting data for: AGMH
# Failed to obtain sector and industry for AGMH
# Failed to parse json response for AGMH
# Ticker: AGMH did not work.
# Getting data for: AGN
# Getting data for: AGNC
# Getting data for: AGNCB
# Failed to obtain sector and industry for AGNCB
# Failed to parse json response for AGNCB
# Ticker: AGNCB did not work.
# Getting data for: AGNCM
# Failed to obtain sector and industry for AGNCM
# Failed to parse json response for AGNCM
# Ticker: AGNCM did not work.
# Getting data for: AGNCN
# Failed to obtain sector and industry for AGNCN
# Failed to parse json response for AGNCN
# Ticker: AGNCN did not work.
# Getting data for: AGNCO
# Failed to obtain sector and industry for AGNCO
# Failed to parse json response for AGNCO
# Ticker: AGNCO did not work.
# Getting data for: AGO
# Getting data for: AGO$B
# Failed to obtain sector and industry for AGO$B
# Failed to parse json response for AGO$B
# Ticker: AGO$B did not work.
# Getting data for: AGO$E
# Failed to obtain sector and industry for AGO$E
# Failed to parse json response for AGO$E
# Ticker: AGO$E did not work.
# Getting data for: AGO$F
# Failed to obtain sector and industry for AGO$F
# Failed to parse json response for AGO$F
# Ticker: AGO$F did not work.
# Getting data for: AGR
# Failed to obtain sector and industry for AGR
# Getting data for: AGRO
# Getting data for: AGRX
# Getting data for: AGS
# Failed to obtain sector and industry for AGS
# Getting data for: AGTC
# Getting data for: AGX
# Getting data for: AGYS
# Getting data for: AHC
# Getting data for: AHCO
# Failed to obtain sector and industry for AHCO
# Failed to parse json response for AHCO
# Ticker: AHCO did not work.
# Getting data for: AHCOW
# Failed to obtain sector and industry for AHCOW
# Failed to parse json response for AHCOW
# Ticker: AHCOW did not work.
# Getting data for: AHH
# Getting data for: AHH$A
# Failed to obtain sector and industry for AHH$A
# Failed to parse json response for AHH$A
# Ticker: AHH$A did not work.
# Getting data for: AHL$C
# Failed to obtain sector and industry for AHL$C
# Failed to parse json response for AHL$C
# Ticker: AHL$C did not work.
# Getting data for: AHL$D
# Failed to obtain sector and industry for AHL$D
# Failed to parse json response for AHL$D
# Ticker: AHL$D did not work.
# Getting data for: AHL$E
# Failed to obtain sector and industry for AHL$E
# Failed to parse json response for AHL$E
# Ticker: AHL$E did not work.
# Getting data for: AHPI
# Getting data for: AHT
# Getting data for: AHT$D
# Failed to obtain sector and industry for AHT$D
# Failed to parse json response for AHT$D
# Ticker: AHT$D did not work.
# Getting data for: AHT$F
# Failed to obtain sector and industry for AHT$F
# Failed to parse json response for AHT$F
# Ticker: AHT$F did not work.
# Getting data for: AHT$G
# Failed to obtain sector and industry for AHT$G
# Failed to parse json response for AHT$G
# Ticker: AHT$G did not work.
# Getting data for: AHT$H
# Failed to obtain sector and industry for AHT$H
# Failed to parse json response for AHT$H
# Ticker: AHT$H did not work.
# Getting data for: AHT$I
# Failed to obtain sector and industry for AHT$I
# Failed to parse json response for AHT$I
# Ticker: AHT$I did not work.
# Getting data for: AI
# Getting data for: AI$B
# Failed to obtain sector and industry for AI$B
# Failed to parse json response for AI$B
# Ticker: AI$B did not work.
# Getting data for: AI$C
# Failed to obtain sector and industry for AI$C
# Failed to parse json response for AI$C
# Ticker: AI$C did not work.
# Getting data for: AIC
# Failed to obtain sector and industry for AIC
# Failed to parse json response for AIC
# Ticker: AIC did not work.
# Getting data for: AIF
# Failed to obtain sector and industry for AIF
# Failed to parse json response for AIF
# Ticker: AIF did not work.
# Getting data for: AIG
# Getting data for: AIG$A
# Failed to obtain sector and industry for AIG$A
# Failed to parse json response for AIG$A
# Ticker: AIG$A did not work.
# Getting data for: AIG.W
# Failed to obtain sector and industry for AIG.W
# Failed to parse json response for AIG.W
# Ticker: AIG.W did not work.
# Getting data for: AIH
# Failed to obtain sector and industry for AIH
# Failed to parse json response for AIH
# Ticker: AIH did not work.
# Getting data for: AIHS
# Failed to obtain sector and industry for AIHS
# Failed to parse json response for AIHS
# Ticker: AIHS did not work.
# Getting data for: AIM
# Getting data for: AIMC
# Getting data for: AIMT
# Getting data for: AIN
# Getting data for: AINC
# Failed to obtain sector and industry for AINC
# Getting data for: AINV
# Getting data for: AIO
# Failed to obtain sector and industry for AIO
# Failed to parse json response for AIO
# Ticker: AIO did not work.
# Getting data for: AIR
# Getting data for: AIRG
# Failed to obtain sector and industry for AIRG
# Getting data for: AIRI
# Getting data for: AIRT
# Failed to parse json response for AIRT
# Ticker: AIRT did not work.
# Getting data for: AIRTP
# Failed to obtain sector and industry for AIRTP
# Failed to parse json response for AIRTP
# Ticker: AIRTP did not work.
# Getting data for: AIRTW
# Failed to obtain sector and industry for AIRTW
# Failed to parse json response for AIRTW
# Ticker: AIRTW did not work.
# Getting data for: AIT
# Getting data for: AIV
# Getting data for: AIW
# Failed to obtain sector and industry for AIW
# Failed to parse json response for AIW
# Ticker: AIW did not work.
# Getting data for: AIZ
# Getting data for: AIZP
# Failed to obtain sector and industry for AIZP
# Failed to parse json response for AIZP
# Ticker: AIZP did not work.
# Getting data for: AJG
# Getting data for: AJRD
# Getting data for: AJX
# Failed to parse json response for AJX
# Ticker: AJX did not work.
# Getting data for: AJXA
# Failed to obtain sector and industry for AJXA
# Failed to parse json response for AJXA
# Ticker: AJXA did not work.
# Getting data for: AKAM
# Getting data for: AKBA
# Getting data for: AKCA
# Failed to obtain sector and industry for AKCA
# Getting data for: AKER
# Failed to obtain sector and industry for AKER
# Getting data for: AKG
# Getting data for: AKO.A
# Failed to obtain sector and industry for AKO.A
# Failed to parse json response for AKO.A
# Ticker: AKO.A did not work.
# Getting data for: AKO.B
# Failed to obtain sector and industry for AKO.B
# Failed to parse json response for AKO.B
# Ticker: AKO.B did not work.
# Getting data for: AKR
# Getting data for: AKRO
# Failed to obtain sector and industry for AKRO
# Getting data for: AKRX
# Getting data for: AKS
# Getting data for: AKTS
# Getting data for: AKTX
# Getting data for: AL
# Getting data for: AL$A
# Failed to obtain sector and industry for AL$A
# Failed to parse json response for AL$A
# Ticker: AL$A did not work.
# Getting data for: ALAC
# Failed to obtain sector and industry for ALAC
# Failed to parse json response for ALAC
# Ticker: ALAC did not work.
# Getting data for: ALACR
# Failed to obtain sector and industry for ALACR
# Failed to parse json response for ALACR
# Ticker: ALACR did not work.
# Getting data for: ALACU
# Failed to obtain sector and industry for ALACU
# Failed to parse json response for ALACU
# Ticker: ALACU did not work.
# Getting data for: ALACW
# Failed to obtain sector and industry for ALACW
# Failed to parse json response for ALACW
# Ticker: ALACW did not work.
# Getting data for: ALB
# Getting data for: ALBO
# Failed to obtain sector and industry for ALBO
# Getting data for: ALC
# Getting data for: ALCO
# Getting data for: ALDX
# Getting data for: ALE
# Getting data for: ALEC
# Failed to obtain sector and industry for ALEC
# Ticker: ALEC did not work.
# Getting data for: ALEX
# Getting data for: ALG
# Getting data for: ALGN
# Getting data for: ALGR
# Failed to obtain sector and industry for ALGR
# Failed to parse json response for ALGR
# Ticker: ALGR did not work.
# Getting data for: ALGRR
# Failed to obtain sector and industry for ALGRR
# Failed to parse json response for ALGRR
# Ticker: ALGRR did not work.
# Getting data for: ALGRU
# Failed to obtain sector and industry for ALGRU
# Failed to parse json response for ALGRU
# Ticker: ALGRU did not work.
# Getting data for: ALGRW
# Failed to obtain sector and industry for ALGRW
# Failed to parse json response for ALGRW
# Ticker: ALGRW did not work.
# Getting data for: ALGT
# Getting data for: ALIM
# Getting data for: ALJJ
# Failed to obtain sector and industry for ALJJ
# Failed to parse json response for ALJJ
# Ticker: ALJJ did not work.
# Getting data for: ALK
# Getting data for: ALKS
# Getting data for: ALL
# Getting data for: ALL$A
# Failed to obtain sector and industry for ALL$A
# Failed to parse json response for ALL$A
# Ticker: ALL$A did not work.
# Getting data for: ALL$B
# Failed to obtain sector and industry for ALL$B
# Failed to parse json response for ALL$B
# Ticker: ALL$B did not work.
# Getting data for: ALL$G
# Failed to obtain sector and industry for ALL$G
# Failed to parse json response for ALL$G
# Ticker: ALL$G did not work.
# Getting data for: ALL$H
# Failed to obtain sector and industry for ALL$H
# Failed to parse json response for ALL$H
# Ticker: ALL$H did not work.
# Getting data for: ALL$I
# Failed to obtain sector and industry for ALL$I
# Failed to parse json response for ALL$I
# Ticker: ALL$I did not work.
# Getting data for: ALLE
# Getting data for: ALLK
# Failed to obtain sector and industry for ALLK
# Getting data for: ALLO
# Failed to obtain sector and industry for ALLO
# Getting data for: ALLT
# Getting data for: ALLY
# Getting data for: ALLY$A
# Failed to obtain sector and industry for ALLY$A
# Failed to parse json response for ALLY$A
# Ticker: ALLY$A did not work.
# Getting data for: ALNA
# Failed to obtain sector and industry for ALNA
# Ticker: ALNA did not work.
# Getting data for: ALNY
# Getting data for: ALO
# Failed to obtain sector and industry for ALO
# Getting data for: ALOT
# Getting data for: ALP$Q
# Failed to obtain sector and industry for ALP$Q
# Failed to parse json response for ALP$Q
# Ticker: ALP$Q did not work.
# Getting data for: ALPN
# Failed to obtain sector and industry for ALPN
# Getting data for: ALRM
# Getting data for: ALRN
# Getting data for: ALRS
# Failed to obtain sector and industry for ALRS
# Getting data for: ALSK
# Getting data for: ALSN
# Getting data for: ALT
# Failed to obtain sector and industry for ALT
# Getting data for: ALTM
# Failed to obtain sector and industry for ALTM
# Getting data for: ALTR
# Getting data for: ALV
# Getting data for: ALX
# Getting data for: ALXN
# Getting data for: ALYA
# Failed to obtain sector and industry for ALYA
# Getting data for: AM
# Getting data for: AMAG
# Getting data for: AMAL
# Failed to obtain sector and industry for AMAL
# Getting data for: AMAT
# Getting data for: AMBA
# Failed to parse json response for AMBA
# Ticker: AMBA did not work.
# Getting data for: AMBC
# Getting data for: AMBCW
# Failed to obtain sector and industry for AMBCW
# Failed to parse json response for AMBCW
# Ticker: AMBCW did not work.
# Getting data for: AMBO
# Getting data for: AMC
# Getting data for: AMCI
# Failed to obtain sector and industry for AMCI
# Failed to parse json response for AMCI
# Ticker: AMCI did not work.
# Getting data for: AMCIU
# Failed to obtain sector and industry for AMCIU
# Failed to parse json response for AMCIU
# Ticker: AMCIU did not work.
# Getting data for: AMCIW
# Failed to obtain sector and industry for AMCIW
# Failed to parse json response for AMCIW
# Ticker: AMCIW did not work.
# Getting data for: AMCR
# Failed to obtain sector and industry for AMCR
# Getting data for: AMCX
# Getting data for: AMD
# Getting data for: AME
# Getting data for: AMED
# Getting data for: AMEH
# Getting data for: AMG
# Getting data for: AMGN
# Getting data for: AMH
# Getting data for: AMH$D
# Failed to obtain sector and industry for AMH$D
# Failed to parse json response for AMH$D
# Ticker: AMH$D did not work.
# Getting data for: AMH$E
# Failed to obtain sector and industry for AMH$E
# Failed to parse json response for AMH$E
# Ticker: AMH$E did not work.
# Getting data for: AMH$F
# Failed to obtain sector and industry for AMH$F
# Failed to parse json response for AMH$F
# Ticker: AMH$F did not work.
# Getting data for: AMH$G
# Failed to obtain sector and industry for AMH$G
# Failed to parse json response for AMH$G
# Ticker: AMH$G did not work.
# Getting data for: AMH$H
# Failed to obtain sector and industry for AMH$H
# Failed to parse json response for AMH$H
# Ticker: AMH$H did not work.
# Getting data for: AMJ
# Failed to obtain sector and industry for AMJ
# Failed to parse json response for AMJ
# Ticker: AMJ did not work.
# Getting data for: AMJL
# Failed to obtain sector and industry for AMJL
# Failed to parse json response for AMJL
# Ticker: AMJL did not work.
# Getting data for: AMK
# Failed to obtain sector and industry for AMK
# Getting data for: AMKR
# Getting data for: AMN
# Ticker: AMN did not work.
# Getting data for: AMNB
# Getting data for: AMOT
# Getting data for: AMOV
# Failed to obtain sector and industry for AMOV
# Failed to parse json response for AMOV
# Ticker: AMOV did not work.
# Getting data for: AMP
# Getting data for: AMPE
# Failed to obtain sector and industry for AMPE
# Getting data for: AMPH
# Getting data for: AMPY
# Failed to obtain sector and industry for AMPY
# Getting data for: AMRB
# Getting data for: AMRC
# Getting data for: AMRH
# Failed to obtain sector and industry for AMRH
# Getting data for: AMRHW
# Failed to obtain sector and industry for AMRHW
# Failed to parse json response for AMRHW
# Ticker: AMRHW did not work.
# Getting data for: AMRK
# Getting data for: AMRN
# Getting data for: AMRS
# Getting data for: AMRX
# Getting data for: AMS
# Failed to parse json response for AMS
# Ticker: AMS did not work.
# Getting data for: AMSC
# Getting data for: AMSF
# Getting data for: AMSWA
# Getting data for: AMT
# Getting data for: AMTB
# Failed to obtain sector and industry for AMTB
# Getting data for: AMTBB
# Failed to obtain sector and industry for AMTBB
# Failed to parse json response for AMTBB
# Ticker: AMTBB did not work.
# Getting data for: AMTD
# Getting data for: AMTX
# Getting data for: AMU
# Failed to obtain sector and industry for AMU
# Failed to parse json response for AMU
# Ticker: AMU did not work.
# Getting data for: AMUB
# Failed to obtain sector and industry for AMUB
# Failed to parse json response for AMUB
# Ticker: AMUB did not work.
# Getting data for: AMWD
# Getting data for: AMX
# Getting data for: AMZN
# Ticker: AMZN did not work.
# Getting data for: AN
# Getting data for: ANAB
# Failed to obtain sector and industry for ANAB
# Getting data for: ANAT
# Getting data for: ANCN
# Failed to obtain sector and industry for ANCN
# Getting data for: ANDA
# Failed to parse json response for ANDA
# Ticker: ANDA did not work.
# Getting data for: ANDAR
# Failed to obtain sector and industry for ANDAR
# Failed to parse json response for ANDAR
# Ticker: ANDAR did not work.
# Getting data for: ANDAU
# Failed to obtain sector and industry for ANDAU
# Failed to parse json response for ANDAU
# Ticker: ANDAU did not work.
# Getting data for: ANDAW
# Failed to obtain sector and industry for ANDAW
# Failed to parse json response for ANDAW
# Ticker: ANDAW did not work.
# Getting data for: ANDE
# Getting data for: ANET
# Getting data for: ANF
# Getting data for: ANFI
# Getting data for: ANGI
# Getting data for: ANGO
# Getting data for: ANH
# Getting data for: ANH$A
# Failed to obtain sector and industry for ANH$A
# Failed to parse json response for ANH$A
# Ticker: ANH$A did not work.
# Getting data for: ANH$B
# Failed to obtain sector and industry for ANH$B
# Failed to parse json response for ANH$B
# Ticker: ANH$B did not work.
# Getting data for: ANH$C
# Failed to obtain sector and industry for ANH$C
# Failed to parse json response for ANH$C
# Ticker: ANH$C did not work.
# Getting data for: ANIK
# Getting data for: ANIP
# Failed to obtain sector and industry for ANIP
# Getting data for: ANIX
# Failed to obtain sector and industry for ANIX
# Getting data for: ANSS
# Getting data for: ANTE
# Failed to obtain sector and industry for ANTE
# Failed to parse json response for ANTE
# Ticker: ANTE did not work.
# Getting data for: ANTM
# Getting data for: ANY
# Getting data for: AOBC
# Failed to obtain sector and industry for AOBC
# Getting data for: AOD
# Failed to parse json response for AOD
# Ticker: AOD did not work.
# Getting data for: AON
# Getting data for: AOS
# Getting data for: AOSL
# Ticker: AOSL did not work.
# Getting data for: AP
# Getting data for: APA
# Getting data for: APAM
# Getting data for: APD
# Getting data for: APDN
# Getting data for: APDNW
# Failed to obtain sector and industry for APDNW
# Failed to parse json response for APDNW
# Ticker: APDNW did not work.
# Getting data for: APEI
# Getting data for: APEN
# Failed to obtain sector and industry for APEN
# Getting data for: APEX
# Failed to obtain sector and industry for APEX
# Getting data for: APH
# Getting data for: APHA
# Failed to obtain sector and industry for APHA
# Failed to parse json response for APHA
# Ticker: APHA did not work.
# Getting data for: APLE
# Failed to obtain sector and industry for APLE
# Getting data for: APLS
# Failed to obtain sector and industry for APLS
# Getting data for: APLT
# Failed to obtain sector and industry for APLT
# Getting data for: APM
# Failed to obtain sector and industry for APM
# Getting data for: APO
# Getting data for: APO$A
# Failed to obtain sector and industry for APO$A
# Failed to parse json response for APO$A
# Ticker: APO$A did not work.
# Getting data for: APO$B
# Failed to obtain sector and industry for APO$B
# Failed to parse json response for APO$B
# Ticker: APO$B did not work.
# Getting data for: APOG
# Getting data for: APOP
# Failed to obtain sector and industry for APOP
# Getting data for: APOPW
# Failed to obtain sector and industry for APOPW
# Failed to parse json response for APOPW
# Ticker: APOPW did not work.
# Getting data for: APPF
# Getting data for: APPN
# Failed to obtain sector and industry for APPN
# Getting data for: APPS
# Getting data for: APRE
# Failed to obtain sector and industry for APRE
# Getting data for: APRN
# Failed to obtain sector and industry for APRN
# Getting data for: APT
# Getting data for: APTO
# Failed to obtain sector and industry for APTO
# Getting data for: APTS
# Getting data for: APTV
# Getting data for: APTX
# Failed to obtain sector and industry for APTX
# Getting data for: APVO
# Failed to obtain sector and industry for APVO
# Getting data for: APWC
# Failed to parse json response for APWC
# Ticker: APWC did not work.
# Getting data for: APXT
# Failed to obtain sector and industry for APXT
# Failed to parse json response for APXT
# Ticker: APXT did not work.
# Getting data for: APXTU
# Failed to obtain sector and industry for APXTU
# Failed to parse json response for APXTU
# Ticker: APXTU did not work.
# Getting data for: APXTW
# Failed to obtain sector and industry for APXTW
# Failed to parse json response for APXTW
# Ticker: APXTW did not work.
# Getting data for: APY
# Failed to obtain sector and industry for APY
# Getting data for: APYX
# Failed to obtain sector and industry for APYX
# Getting data for: AQB
# Failed to obtain sector and industry for AQB
# Getting data for: AQMS
# Getting data for: AQN
# Failed to obtain sector and industry for AQN
# Failed to parse json response for AQN
# Ticker: AQN did not work.
# Getting data for: AQNA
# Failed to obtain sector and industry for AQNA
# Failed to parse json response for AQNA
# Ticker: AQNA did not work.
# Getting data for: AQNB
# Failed to obtain sector and industry for AQNB
# Failed to parse json response for AQNB
# Ticker: AQNB did not work.
# Getting data for: AQST
# Failed to obtain sector and industry for AQST
# Getting data for: AQUA
# Failed to obtain sector and industry for AQUA
# Getting data for: AR
# Getting data for: ARA
# Failed to obtain sector and industry for ARA
# Getting data for: ARAV
# Failed to obtain sector and industry for ARAV
# Getting data for: ARAY
# Getting data for: ARC
# Getting data for: ARCB
# Getting data for: ARCC
# Getting data for: ARCE
# Failed to obtain sector and industry for ARCE
# Getting data for: ARCH
# Failed to obtain sector and industry for ARCH
# Getting data for: ARCO
# Getting data for: ARCT
# Getting data for: ARD
# Failed to obtain sector and industry for ARD
# Getting data for: ARDC
# Failed to obtain sector and industry for ARDC
# Failed to parse json response for ARDC
# Ticker: ARDC did not work.
# Getting data for: ARDS
# Failed to obtain sector and industry for ARDS
# Getting data for: ARDX
# Getting data for: ARE
# Getting data for: AREC
# Failed to obtain sector and industry for AREC
# Getting data for: ARES
# Ticker: ARES did not work.
# Getting data for: ARES$A
# Failed to obtain sector and industry for ARES$A
# Failed to parse json response for ARES$A
# Ticker: ARES$A did not work.
# Getting data for: ARGD
# Failed to obtain sector and industry for ARGD
# Failed to parse json response for ARGD
# Ticker: ARGD did not work.
# Getting data for: ARGO
# Failed to obtain sector and industry for ARGO
# Getting data for: ARGX
# Failed to obtain sector and industry for ARGX
# Getting data for: ARI
# Getting data for: ARKR
# Getting data for: ARL
# Failed to parse json response for ARL
# Ticker: ARL did not work.
# Getting data for: ARLO
# Failed to obtain sector and industry for ARLO
# Getting data for: ARLP
# Getting data for: ARMK
# Getting data for: ARMP
# Getting data for: ARNA
# Getting data for: ARNC
# Failed to obtain sector and industry for ARNC
# Getting data for: ARNC$
# Failed to obtain sector and industry for ARNC$
# Failed to parse json response for ARNC$
# Ticker: ARNC$ did not work.
# Getting data for: AROC
# Failed to obtain sector and industry for AROC
# Getting data for: AROW
# Getting data for: ARPO
# Failed to obtain sector and industry for ARPO
# Getting data for: ARQL
# Getting data for: ARR
# Getting data for: ARR$B
# Failed to obtain sector and industry for ARR$B
# Failed to parse json response for ARR$B
# Ticker: ARR$B did not work.
# Getting data for: ARTL
# Failed to obtain sector and industry for ARTL
# Getting data for: ARTLW
# Failed to obtain sector and industry for ARTLW
# Failed to parse json response for ARTLW
# Ticker: ARTLW did not work.
# Getting data for: ARTNA
# Getting data for: ARTW
# Getting data for: ARTX
# Getting data for: ARVN
# Failed to obtain sector and industry for ARVN
# Getting data for: ARW
# Getting data for: ARWR
# Getting data for: ARYA
# Failed to obtain sector and industry for ARYA
# Failed to parse json response for ARYA
# Ticker: ARYA did not work.
# Getting data for: ARYAU
# Failed to obtain sector and industry for ARYAU
# Failed to parse json response for ARYAU
# Ticker: ARYAU did not work.
# Getting data for: ARYAW
# Failed to obtain sector and industry for ARYAW
# Failed to parse json response for ARYAW
# Ticker: ARYAW did not work.
# Getting data for: ASA
# Failed to parse json response for ASA
# Ticker: ASA did not work.
# Getting data for: ASB
# Getting data for: ASB$C
# Failed to obtain sector and industry for ASB$C
# Failed to parse json response for ASB$C
# Ticker: ASB$C did not work.
# Getting data for: ASB$D
# Failed to obtain sector and industry for ASB$D
# Failed to parse json response for ASB$D
# Ticker: ASB$D did not work.
# Getting data for: ASB$E
# Failed to obtain sector and industry for ASB$E
# Failed to parse json response for ASB$E
# Ticker: ASB$E did not work.
# Getting data for: ASC
# Getting data for: ASFI
# Getting data for: ASG
# Failed to parse json response for ASG
# Ticker: ASG did not work.
# Getting data for: ASGN
# Getting data for: ASH
# Getting data for: ASIX
# Failed to obtain sector and industry for ASIX
# Getting data for: ASLN
# Failed to obtain sector and industry for ASLN
# Getting data for: ASM
# Getting data for: ASMB
# Getting data for: ASML
# Failed to obtain sector and industry for ASML
# Getting data for: ASNA
# Getting data for: ASND
# Getting data for: ASPN
# Failed to parse json response for ASPN
# Ticker: ASPN did not work.
# Getting data for: ASPS
# Getting data for: ASPU
# Getting data for: ASR
# Getting data for: ASRT
# Failed to obtain sector and industry for ASRT
# Getting data for: ASRV
# Getting data for: ASRVP
# Failed to obtain sector and industry for ASRVP
# Failed to parse json response for ASRVP
# Ticker: ASRVP did not work.
# Getting data for: ASTC
# Getting data for: ASTE
# Getting data for: ASUR
# Getting data for: ASX
# Getting data for: ASYS
# Getting data for: AT
# Getting data for: ATAX
# Getting data for: ATEC
# Getting data for: ATEN
# Getting data for: ATEST
# Failed to obtain sector and industry for ATEST
# Failed to parse json response for ATEST
# Ticker: ATEST did not work.
# Getting data for: ATEST.A
# Failed to obtain sector and industry for ATEST.A
# Failed to parse json response for ATEST.A
# Ticker: ATEST.A did not work.
# Getting data for: ATEST.B
# Failed to obtain sector and industry for ATEST.B
# Failed to parse json response for ATEST.B
# Ticker: ATEST.B did not work.
# Getting data for: ATEST.C
# Failed to obtain sector and industry for ATEST.C
# Failed to parse json response for ATEST.C
# Ticker: ATEST.C did not work.
# Getting data for: ATEX
# Failed to obtain sector and industry for ATEX
# Getting data for: ATGE
# Failed to obtain sector and industry for ATGE
# Getting data for: ATH
# Failed to obtain sector and industry for ATH
# Getting data for: ATH$A
# Failed to obtain sector and industry for ATH$A
# Failed to parse json response for ATH$A
# Ticker: ATH$A did not work.
# Getting data for: ATH$B
# Failed to obtain sector and industry for ATH$B
# Failed to parse json response for ATH$B
# Ticker: ATH$B did not work.
# Getting data for: ATHE
# Failed to obtain sector and industry for ATHE
# Getting data for: ATHM
# Getting data for: ATHX
# Getting data for: ATI
# Getting data for: ATIF
# Failed to obtain sector and industry for ATIF
# Failed to parse json response for ATIF
# Ticker: ATIF did not work.
# Getting data for: ATKR
# Failed to obtain sector and industry for ATKR
# Getting data for: ATLC
# Getting data for: ATLO
# Failed to parse json response for ATLO
# Ticker: ATLO did not work.
# Getting data for: ATMP
# Failed to obtain sector and industry for ATMP
# Failed to parse json response for ATMP
# Ticker: ATMP did not work.
# Getting data for: ATNI
# Getting data for: ATNM
# Getting data for: ATNX
# Failed to obtain sector and industry for ATNX
# Getting data for: ATO
# Getting data for: ATOM
# Failed to obtain sector and industry for ATOM
# Getting data for: ATOS
# Getting data for: ATR
# Getting data for: ATRA
# Failed to obtain sector and industry for ATRA
# Getting data for: ATRC
# Getting data for: ATRI
# Getting data for: ATRO
# Getting data for: ATRS
# Getting data for: ATSG
# Getting data for: ATTO
# Getting data for: ATUS
# Failed to obtain sector and industry for ATUS
# Getting data for: ATV
# Getting data for: ATVI
# Getting data for: ATXI
# Failed to obtain sector and industry for ATXI
# Getting data for: AU
# Getting data for: AUB
# Failed to obtain sector and industry for AUB
# Getting data for: AUBN
# Failed to parse json response for AUBN
# Ticker: AUBN did not work.
# Getting data for: AUDC
# Getting data for: AUG
# Failed to obtain sector and industry for AUG
# Getting data for: AUMN
# Getting data for: AUPH
# Failed to obtain sector and industry for AUPH
# Getting data for: AUTL
# Failed to obtain sector and industry for AUTL
# Getting data for: AUTO
# Getting data for: AUY
# Getting data for: AVA
# Getting data for: AVAL
# Failed to obtain sector and industry for AVAL
# Getting data for: AVAV
# Getting data for: AVB
# Getting data for: AVCO
# Failed to obtain sector and industry for AVCO
# Failed to parse json response for AVCO
# Ticker: AVCO did not work.
# Getting data for: AVD
# Getting data for: AVDL
# Failed to obtain sector and industry for AVDL
# Getting data for: AVDR
# Failed to obtain sector and industry for AVDR
# Getting data for: AVEO
# Getting data for: AVGO
# Getting data for: AVGOP
# Failed to obtain sector and industry for AVGOP
# Failed to parse json response for AVGOP
# Ticker: AVGOP did not work.
# Getting data for: AVGR
# Getting data for: AVH
# Failed to obtain sector and industry for AVH
# Getting data for: AVID
# Getting data for: AVK
# Failed to parse json response for AVK
# Ticker: AVK did not work.
# Getting data for: AVLR
# Failed to obtain sector and industry for AVLR
# Getting data for: AVNS
# Failed to obtain sector and industry for AVNS
# Getting data for: AVNW
# Getting data for: AVP
# Getting data for: AVRO
# Failed to obtain sector and industry for AVRO
# Getting data for: AVT
# Getting data for: AVTR
# Getting data for: AVTR$A
# Failed to obtain sector and industry for AVTR$A
# Failed to parse json response for AVTR$A
# Ticker: AVTR$A did not work.
# Getting data for: AVX
# Getting data for: AVXL
# Getting data for: AVY
# Getting data for: AVYA
# Failed to obtain sector and industry for AVYA
# Getting data for: AWF
# Failed to parse json response for AWF
# Ticker: AWF did not work.
# Getting data for: AWI
# Getting data for: AWK
# Getting data for: AWP
# Failed to parse json response for AWP
# Ticker: AWP did not work.
# Getting data for: AWR
# Getting data for: AWRE
# Getting data for: AWX
# Failed to parse json response for AWX
# Ticker: AWX did not work.
# Getting data for: AX
# Failed to obtain sector and industry for AX
# Getting data for: AXAS
# Getting data for: AXDX
# Getting data for: AXE
# Getting data for: AXGN
# Getting data for: AXGT
# Failed to obtain sector and industry for AXGT
# Getting data for: AXL
# Getting data for: AXLA
# Failed to obtain sector and industry for AXLA
# Getting data for: AXNX
# Failed to obtain sector and industry for AXNX
# Getting data for: AXO
# Failed to obtain sector and industry for AXO
# Failed to parse json response for AXO
# Ticker: AXO did not work.
# Getting data for: AXP
# Getting data for: AXR
# Failed to parse json response for AXR
# Ticker: AXR did not work.
# Getting data for: AXS
# Getting data for: AXS$D
# Failed to obtain sector and industry for AXS$D
# Failed to parse json response for AXS$D
# Ticker: AXS$D did not work.
# Getting data for: AXS$E
# Failed to obtain sector and industry for AXS$E
# Failed to parse json response for AXS$E
# Ticker: AXS$E did not work.
# Getting data for: AXSM
# Failed to obtain sector and industry for AXSM
# Getting data for: AXTA
# Getting data for: AXTI
# Getting data for: AXU
# Getting data for: AY
# Failed to obtain sector and industry for AY
# Getting data for: AYI
# Ticker: AYI did not work.
# Getting data for: AYR
# Getting data for: AYTU
# Failed to obtain sector and industry for AYTU
# Getting data for: AYX
# Failed to obtain sector and industry for AYX
# Getting data for: AZN
# Getting data for: AZO
# Ticker: AZO did not work.
# Getting data for: AZPN
# Getting data for: AZRE
# Failed to obtain sector and industry for AZRE
# Getting data for: AZRX
# Failed to obtain sector and industry for AZRX
# Getting data for: AZUL
# Failed to obtain sector and industry for AZUL
# Getting data for: AZZ
# Getting data for: B
# Getting data for: BA
# Getting data for: BABA
# Getting data for: BAC
# Ticker: BAC did not work.
# Getting data for: BAC$A
# Failed to obtain sector and industry for BAC$A
# Failed to parse json response for BAC$A
# Ticker: BAC$A did not work.
# Getting data for: BAC$B
# Failed to obtain sector and industry for BAC$B
# Failed to parse json response for BAC$B
# Ticker: BAC$B did not work.
# Getting data for: BAC$C
# Failed to obtain sector and industry for BAC$C
# Failed to parse json response for BAC$C
# Ticker: BAC$C did not work.
# Getting data for: BAC$E
# Failed to obtain sector and industry for BAC$E
# Failed to parse json response for BAC$E
# Ticker: BAC$E did not work.
# Getting data for: BAC$K
# Failed to obtain sector and industry for BAC$K
# Failed to parse json response for BAC$K
# Ticker: BAC$K did not work.
# Getting data for: BAC$L
# Failed to obtain sector and industry for BAC$L
# Failed to parse json response for BAC$L
# Ticker: BAC$L did not work.
# Getting data for: BAC$M
# Failed to obtain sector and industry for BAC$M
# Failed to parse json response for BAC$M
# Ticker: BAC$M did not work.
# Getting data for: BAC$N
# Failed to obtain sector and industry for BAC$N
# Failed to parse json response for BAC$N
# Ticker: BAC$N did not work.
# Getting data for: BAC$Y
# Failed to obtain sector and industry for BAC$Y
# Failed to parse json response for BAC$Y
# Ticker: BAC$Y did not work.
# Getting data for: BAF
# Failed to parse json response for BAF
# Ticker: BAF did not work.
# Getting data for: BAH
# Getting data for: BAK
# Getting data for: BAL
# Failed to obtain sector and industry for BAL
# Failed to parse json response for BAL
# Ticker: BAL did not work.
# Getting data for: BAM
# Getting data for: BANC
# Getting data for: BANC$D
# Failed to obtain sector and industry for BANC$D
# Failed to parse json response for BANC$D
# Ticker: BANC$D did not work.
# Getting data for: BANC$E
# Failed to obtain sector and industry for BANC$E
# Failed to parse json response for BANC$E
# Ticker: BANC$E did not work.
# Getting data for: BAND
# Failed to obtain sector and industry for BAND
# Getting data for: BANF
# Getting data for: BANFP
# Failed to obtain sector and industry for BANFP
# Failed to parse json response for BANFP
# Ticker: BANFP did not work.
# Getting data for: BANR
# Getting data for: BANX
# Failed to obtain sector and industry for BANX
# Getting data for: BAP
# Getting data for: BAR
# Failed to obtain sector and industry for BAR
# Failed to parse json response for BAR
# Ticker: BAR did not work.
# Getting data for: BAS
# Getting data for: BASI
# Getting data for: BATRA
# Failed to obtain sector and industry for BATRA
# Getting data for: BATRK
# Failed to obtain sector and industry for BATRK
# Getting data for: BAX
# Getting data for: BB
# Failed to obtain sector and industry for BB
# Getting data for: BBAR
# Failed to obtain sector and industry for BBAR
# Getting data for: BBBY
# Getting data for: BBCP
# Failed to obtain sector and industry for BBCP
# Getting data for: BBD
# Getting data for: BBDC
# Failed to obtain sector and industry for BBDC
# Getting data for: BBDO
# Failed to parse json response for BBDO
# Ticker: BBDO did not work.
# Getting data for: BBF
# Failed to parse json response for BBF
# Ticker: BBF did not work.
# Getting data for: BBGI
# Getting data for: BBI
# Failed to obtain sector and industry for BBI
# Getting data for: BBIO
# Failed to obtain sector and industry for BBIO
# Getting data for: BBK
# Failed to parse json response for BBK
# Ticker: BBK did not work.
# Getting data for: BBL
# Getting data for: BBN
# Failed to obtain sector and industry for BBN
# Failed to parse json response for BBN
# Ticker: BBN did not work.
# Getting data for: BBQ
# Failed to obtain sector and industry for BBQ
# Getting data for: BBSI
# Getting data for: BBT
# Getting data for: BBT$F
# Failed to obtain sector and industry for BBT$F
# Failed to parse json response for BBT$F
# Ticker: BBT$F did not work.
# Getting data for: BBT$G
# Failed to obtain sector and industry for BBT$G
# Failed to parse json response for BBT$G
# Ticker: BBT$G did not work.
# Getting data for: BBT$H
# Failed to obtain sector and industry for BBT$H
# Failed to parse json response for BBT$H
# Ticker: BBT$H did not work.
# Getting data for: BBU
# Failed to obtain sector and industry for BBU
# Getting data for: BBVA
# Getting data for: BBW
# Getting data for: BBX
# Getting data for: BBY
# Getting data for: BC
# Getting data for: BC$A
# Failed to obtain sector and industry for BC$A
# Failed to parse json response for BC$A
# Ticker: BC$A did not work.
# Getting data for: BC$B
# Failed to obtain sector and industry for BC$B
# Failed to parse json response for BC$B
# Ticker: BC$B did not work.
# Getting data for: BC$C
# Failed to obtain sector and industry for BC$C
# Failed to parse json response for BC$C
# Ticker: BC$C did not work.
# Getting data for: BCBP
# Getting data for: BCC
# Getting data for: BCDA
# Failed to obtain sector and industry for BCDA
# Getting data for: BCDAW
# Failed to obtain sector and industry for BCDAW
# Failed to parse json response for BCDAW
# Ticker: BCDAW did not work.
# Getting data for: BCE
# Getting data for: BCEI
# Getting data for: BCEL
# Failed to obtain sector and industry for BCEL
# Getting data for: BCH
# Getting data for: BCLI
# Getting data for: BCM
# Failed to obtain sector and industry for BCM
# Failed to parse json response for BCM
# Ticker: BCM did not work.
# Getting data for: BCML
# Getting data for: BCO
# Getting data for: BCOM
# Ticker: BCOM did not work.
# Getting data for: BCOR
# Getting data for: BCOV
# Getting data for: BCOW
# Failed to obtain sector and industry for BCOW
# Failed to parse json response for BCOW
# Ticker: BCOW did not work.
# Getting data for: BCPC
# Getting data for: BCRH
# Getting data for: BCRX
# Getting data for: BCS
# Getting data for: BCSF
# Failed to obtain sector and industry for BCSF
# Getting data for: BCTF
# Failed to obtain sector and industry for BCTF
# Failed to parse json response for BCTF
# Ticker: BCTF did not work.
# Getting data for: BCV
# Failed to parse json response for BCV
# Ticker: BCV did not work.
# Getting data for: BCV$A
# Failed to obtain sector and industry for BCV$A
# Failed to parse json response for BCV$A
# Ticker: BCV$A did not work.
# Getting data for: BCX
# Failed to obtain sector and industry for BCX
# Failed to parse json response for BCX
# Ticker: BCX did not work.
# Getting data for: BCYC
# Failed to obtain sector and industry for BCYC
# Getting data for: BDC
# Getting data for: BDCL
# Failed to obtain sector and industry for BDCL
# Failed to parse json response for BDCL
# Ticker: BDCL did not work.
# Getting data for: BDCS
# Failed to obtain sector and industry for BDCS
# Failed to parse json response for BDCS
# Ticker: BDCS did not work.
# Getting data for: BDCZ
# Failed to obtain sector and industry for BDCZ
# Failed to parse json response for BDCZ
# Ticker: BDCZ did not work.
# Getting data for: BDGE
# Getting data for: BDJ
# Failed to parse json response for BDJ
# Ticker: BDJ did not work.
# Getting data for: BDL
# Failed to parse json response for BDL
# Ticker: BDL did not work.
# Getting data for: BDN
# Getting data for: BDR
# Failed to parse json response for BDR
# Ticker: BDR did not work.
# Getting data for: BDSI
# Getting data for: BDX
# Getting data for: BDXA
# Failed to obtain sector and industry for BDXA
# Failed to parse json response for BDXA
# Ticker: BDXA did not work.
# Getting data for: BE
# Failed to obtain sector and industry for BE
# Getting data for: BEAT
# Getting data for: BECN
# Getting data for: BEDU
# Failed to obtain sector and industry for BEDU
# Getting data for: BELFA
# Failed to obtain sector and industry for BELFA
# Getting data for: BELFB
# Getting data for: BEN
# Getting data for: BEP
# Getting data for: BERY
# Getting data for: BEST
# Getting data for: BF.A
# Failed to obtain sector and industry for BF.A
# Failed to parse json response for BF.A
# Ticker: BF.A did not work.
# Getting data for: BF.B
# Failed to obtain sector and industry for BF.B
# Failed to parse json response for BF.B
# Ticker: BF.B did not work.
# Getting data for: BFAM
# Getting data for: BFC
# Failed to obtain sector and industry for BFC
# Getting data for: BFIN
# Getting data for: BFK
# Failed to parse json response for BFK
# Ticker: BFK did not work.
# Getting data for: BFO
# Failed to parse json response for BFO
# Ticker: BFO did not work.
# Getting data for: BFRA
# Failed to obtain sector and industry for BFRA
# Getting data for: BFS
# Getting data for: BFS$D
# Failed to obtain sector and industry for BFS$D
# Failed to parse json response for BFS$D
# Ticker: BFS$D did not work.
# Getting data for: BFS$E
# Failed to obtain sector and industry for BFS$E
# Failed to parse json response for BFS$E
# Ticker: BFS$E did not work.
# Getting data for: BFST
# Failed to obtain sector and industry for BFST
# Getting data for: BFY
# Failed to parse json response for BFY
# Ticker: BFY did not work.
# Getting data for: BFZ
# Failed to parse json response for BFZ
# Ticker: BFZ did not work.
# Getting data for: BG
# Getting data for: BGB
# Failed to obtain sector and industry for BGB
# Failed to parse json response for BGB
# Ticker: BGB did not work.
# Getting data for: BGCP
# Failed to obtain sector and industry for BGCP
# Ticker: BGCP did not work.
# Getting data for: BGFV
# Getting data for: BGG
# Getting data for: BGH
# Getting data for: BGI
# Failed to parse json response for BGI
# Ticker: BGI did not work.
# Getting data for: BGIO
# Failed to obtain sector and industry for BGIO
# ...
# Failed to parse json response for WFC$V
# Ticker: WFC$V did not work.
# Getting data for: WFC$W
# Failed to obtain sector and industry for WFC$W
# Failed to parse json response for WFC$W
# Ticker: WFC$W did not work.
# Getting data for: WFC$X
# Failed to obtain sector and industry for WFC$X
# Failed to parse json response for WFC$X
# Ticker: WFC$X did not work.
# Getting data for: WFC$Y
# Failed to obtain sector and industry for WFC$Y
# Failed to parse json response for WFC$Y
# Ticker: WFC$Y did not work.
# Getting data for: WFE$A
# Failed to obtain sector and industry for WFE$A
# Failed to parse json response for WFE$A
# Ticker: WFE$A did not work.
# Getting data for: WGO
# Getting data for: WH
# Getting data for: WHD
# Failed to obtain sector and industry for WHD
# Getting data for: WHF
# Getting data for: WHFBZ
# Failed to obtain sector and industry for WHFBZ
# Failed to parse json response for WHFBZ
# Ticker: WHFBZ did not work.
# Getting data for: WHG
# Failed to parse json response for WHG
# Ticker: WHG did not work.
# Getting data for: WHLM
# Getting data for: WHLR
# Getting data for: WHLRD
# Failed to obtain sector and industry for WHLRD
# Failed to parse json response for WHLRD
# Ticker: WHLRD did not work.
# Getting data for: WHLRP
# Failed to obtain sector and industry for WHLRP
# Failed to parse json response for WHLRP
# Ticker: WHLRP did not work.
# Getting data for: WHR
# Getting data for: WIA
# Failed to parse json response for WIA
# Ticker: WIA did not work.
# Getting data for: WIFI
# Getting data for: WIL
# Failed to obtain sector and industry for WIL
# Failed to parse json response for WIL
# Ticker: WIL did not work.
# Getting data for: WILC
# Getting data for: WINA
# Failed to parse json response for WINA
# Ticker: WINA did not work.
# Getting data for: WING
# Getting data for: WINS
# Failed to obtain sector and industry for WINS
# Failed to parse json response for WINS
# Ticker: WINS did not work.
# Getting data for: WIRE
# Ticker: WIRE did not work.
# Getting data for: WISA
# Failed to obtain sector and industry for WISA
# Getting data for: WIT
# Getting data for: WIW
# Failed to obtain sector and industry for WIW
# Failed to parse json response for WIW
# Ticker: WIW did not work.
# Getting data for: WIX
# Getting data for: WK
# Getting data for: WKHS
# Failed to obtain sector and industry for WKHS
# Getting data for: WLDN
# Getting data for: WLFC
# Failed to obtain sector and industry for WLFC
# Getting data for: WLH
# Failed to obtain sector and industry for WLH
# Getting data for: WLK
# Getting data for: WLKP
# Getting data for: WLL
# Getting data for: WLTW
# Failed to obtain sector and industry for WLTW
# Getting data for: WM
# Getting data for: WMB
# Getting data for: WMC
# Getting data for: WMGI
# Getting data for: WMK
# Getting data for: WMS
# Getting data for: WMT
# Failed to obtain sector and industry for WMT
# Getting data for: WNC
# Getting data for: WNEB
# Failed to obtain sector and industry for WNEB
# Getting data for: WNS
# Getting data for: WOR
# Getting data for: WORK
# Failed to obtain sector and industry for WORK
# Getting data for: WORX
# Failed to parse json response for WORX
# Ticker: WORX did not work.
# Getting data for: WOW
# Failed to obtain sector and industry for WOW
# Getting data for: WPC
# Getting data for: WPG
# Getting data for: WPG$H
# Failed to obtain sector and industry for WPG$H
# Failed to parse json response for WPG$H
# Ticker: WPG$H did not work.
# Getting data for: WPG$I
# Failed to obtain sector and industry for WPG$I
# Failed to parse json response for WPG$I
# Ticker: WPG$I did not work.
# Getting data for: WPM
# Failed to obtain sector and industry for WPM
# Getting data for: WPP
# Getting data for: WPRT
# Failed to obtain sector and industry for WPRT
# Getting data for: WPX
# Getting data for: WRB
# Getting data for: WRB$B
# Failed to obtain sector and industry for WRB$B
# Failed to parse json response for WRB$B
# Ticker: WRB$B did not work.
# Getting data for: WRB$C
# Failed to obtain sector and industry for WRB$C
# Failed to parse json response for WRB$C
# Ticker: WRB$C did not work.
# Getting data for: WRB$D
# Failed to obtain sector and industry for WRB$D
# Failed to parse json response for WRB$D
# Ticker: WRB$D did not work.
# Getting data for: WRB$E
# Failed to obtain sector and industry for WRB$E
# Failed to parse json response for WRB$E
# Ticker: WRB$E did not work.
# Getting data for: WRE
# Failed to obtain sector and industry for WRE
# Getting data for: WRI
# Getting data for: WRK
# Getting data for: WRLD
# Getting data for: WRLS
# Failed to parse json response for WRLS
# Ticker: WRLS did not work.
# Getting data for: WRLSR
# Failed to obtain sector and industry for WRLSR
# Failed to parse json response for WRLSR
# Ticker: WRLSR did not work.
# Getting data for: WRLSU
# Failed to obtain sector and industry for WRLSU
# Failed to parse json response for WRLSU
# Ticker: WRLSU did not work.
# Getting data for: WRLSW
# Failed to obtain sector and industry for WRLSW
# Failed to parse json response for WRLSW
# Ticker: WRLSW did not work.
# Getting data for: WRN
# Failed to obtain sector and industry for WRN
# Failed to parse json response for WRN
# Ticker: WRN did not work.
# Getting data for: WRTC
# Failed to obtain sector and industry for WRTC
# Getting data for: WSBC
# Getting data for: WSBF
# Getting data for: WSC
# Getting data for: WSFS
# Failed to parse json response for WSFS
# Ticker: WSFS did not work.
# Getting data for: WSG
# Failed to obtain sector and industry for WSG
# Getting data for: WSM
# Getting data for: WSO
# Getting data for: WSO.B
# Failed to obtain sector and industry for WSO.B
# Failed to parse json response for WSO.B
# Ticker: WSO.B did not work.
# Getting data for: WSR
# Failed to obtain sector and industry for WSR
# Getting data for: WST
# Getting data for: WSTG
# Getting data for: WSTL
# Getting data for: WTBA
# Getting data for: WTER
# Getting data for: WTFC
# Failed to parse json response for WTFC
# Ticker: WTFC did not work.
# Getting data for: WTFCM
# Failed to obtain sector and industry for WTFCM
# Failed to parse json response for WTFCM
# Ticker: WTFCM did not work.
# Getting data for: WTI
# Getting data for: WTID
# Failed to obtain sector and industry for WTID
# Failed to parse json response for WTID
# Ticker: WTID did not work.
# Getting data for: WTIU
# Failed to obtain sector and industry for WTIU
# Failed to parse json response for WTIU
# Ticker: WTIU did not work.
# Getting data for: WTM
# Ticker: WTM did not work.
# Getting data for: WTR
# Getting data for: WTRE
# Failed to obtain sector and industry for WTRE
# Getting data for: WTREP
# Failed to obtain sector and industry for WTREP
# Failed to parse json response for WTREP
# Ticker: WTREP did not work.
# Getting data for: WTRH
# Failed to obtain sector and industry for WTRH
# Getting data for: WTRU
# Failed to obtain sector and industry for WTRU
# Failed to parse json response for WTRU
# Ticker: WTRU did not work.
# Getting data for: WTS
# Ticker: WTS did not work.
# Getting data for: WTT
# Getting data for: WTTR
# Failed to obtain sector and industry for WTTR
# Getting data for: WU
# Getting data for: WUBA
# Getting data for: WVE
# Failed to obtain sector and industry for WVE
# Getting data for: WVFC
# Failed to parse json response for WVFC
# Ticker: WVFC did not work.
# Getting data for: WVVI
# Failed to parse json response for WVVI
# Ticker: WVVI did not work.
# Getting data for: WVVIP
# Failed to obtain sector and industry for WVVIP
# Failed to parse json response for WVVIP
# Ticker: WVVIP did not work.
# Getting data for: WW
# Failed to obtain sector and industry for WW
# Getting data for: WWD
# Getting data for: WWE
# Getting data for: WWR
# Failed to obtain sector and industry for WWR
# Getting data for: WWW
# Getting data for: WY
# Getting data for: WYND
# Failed to obtain sector and industry for WYND
# Getting data for: WYNN
# Getting data for: WYY
# Getting data for: X
# Getting data for: XAIR
# Failed to obtain sector and industry for XAIR
# Getting data for: XAN
# Failed to obtain sector and industry for XAN
# Getting data for: XAN$C
# Failed to obtain sector and industry for XAN$C
# Failed to parse json response for XAN$C
# Ticker: XAN$C did not work.
# Getting data for: XBIO
# Getting data for: XBIOW
# Failed to obtain sector and industry for XBIOW
# Failed to parse json response for XBIOW
# Ticker: XBIOW did not work.
# Getting data for: XBIT
# Getting data for: XCUR
# Failed to obtain sector and industry for XCUR
# Getting data for: XEC
# Getting data for: XEL
# Getting data for: XELA
# Failed to obtain sector and industry for XELA
# Getting data for: XELB
# Getting data for: XENE
# Getting data for: XENT
# Getting data for: XERS
# Failed to obtain sector and industry for XERS
# Getting data for: XFLT
# Failed to obtain sector and industry for XFLT
# Failed to parse json response for XFLT
# Ticker: XFLT did not work.
# Getting data for: XFOR
# Failed to obtain sector and industry for XFOR
# Getting data for: XGN
# Failed to obtain sector and industry for XGN
# Getting data for: XHR
# Getting data for: XIN
# Getting data for: XLNX
# Getting data for: XLRN
# Getting data for: XNCR
# Getting data for: XNET
# Getting data for: XOG
# Failed to obtain sector and industry for XOG
# Getting data for: XOM
# Getting data for: XOMA
# Getting data for: XON
# Getting data for: XONE
# Getting data for: XPEL
# Failed to obtain sector and industry for XPEL
# Getting data for: XPER
# Failed to obtain sector and industry for XPER
# Getting data for: XPL
# Getting data for: XPO
# Getting data for: XRAY
# Getting data for: XRF
# Failed to obtain sector and industry for XRF
# Getting data for: XRX
# Getting data for: XSPA
# Failed to obtain sector and industry for XSPA
# Getting data for: XTLB
# Failed to obtain sector and industry for XTLB
# Getting data for: XTNT
# Failed to obtain sector and industry for XTNT
# Ticker: XTNT did not work.
# Getting data for: XVZ
# Failed to obtain sector and industry for XVZ
# Failed to parse json response for XVZ
# Ticker: XVZ did not work.
# Getting data for: XXII
# Getting data for: XYF
# Failed to obtain sector and industry for XYF
# Getting data for: XYL
# Getting data for: Y
# Getting data for: YAYO
# Failed to obtain sector and industry for YAYO
# Failed to parse json response for YAYO
# Ticker: YAYO did not work.
# Getting data for: YCBD
# Failed to obtain sector and industry for YCBD
# Getting data for: YCBD$A
# Failed to obtain sector and industry for YCBD$A
# Failed to parse json response for YCBD$A
# Ticker: YCBD$A did not work.
# Getting data for: YELP
# Getting data for: YETI
# Failed to obtain sector and industry for YETI
# Getting data for: YEXT
# Getting data for: YGRN
# Failed to obtain sector and industry for YGRN
# Failed to parse json response for YGRN
# Ticker: YGRN did not work.
# Getting data for: YGYI
# Failed to obtain sector and industry for YGYI
# Getting data for: YGYIP
# Failed to obtain sector and industry for YGYIP
# Failed to parse json response for YGYIP
# Ticker: YGYIP did not work.
# Getting data for: YI
# Failed to obtain sector and industry for YI
# Failed to parse json response for YI
# Ticker: YI did not work.
# Getting data for: YIN
# Failed to obtain sector and industry for YIN
# Getting data for: YJ
# Failed to obtain sector and industry for YJ
# Getting data for: YMAB
# Failed to obtain sector and industry for YMAB
# Getting data for: YNDX
# Getting data for: YORW
# Getting data for: YPF
# Getting data for: YRCW
# Getting data for: YRD
# Failed to obtain sector and industry for YRD
# Getting data for: YTEN
# Failed to obtain sector and industry for YTEN
# Getting data for: YTRA
# Failed to obtain sector and industry for YTRA
# Getting data for: YUM
# Failed to obtain sector and industry for YUM
# Getting data for: YUMA
# Getting data for: YUMC
# Failed to obtain sector and industry for YUMC
# Getting data for: YVR
# Failed to obtain sector and industry for YVR
# Getting data for: YY
# Getting data for: Z
# Getting data for: ZAGG
# Getting data for: ZAYO
# Getting data for: ZAZZT
# Failed to obtain sector and industry for ZAZZT
# Failed to parse json response for ZAZZT
# Ticker: ZAZZT did not work.
# Getting data for: ZB$A
# Failed to obtain sector and industry for ZB$A
# Failed to parse json response for ZB$A
# Ticker: ZB$A did not work.
# Getting data for: ZB$G
# Failed to obtain sector and industry for ZB$G
# Failed to parse json response for ZB$G
# Ticker: ZB$G did not work.
# Getting data for: ZB$H
# Failed to obtain sector and industry for ZB$H
# Failed to parse json response for ZB$H
# Ticker: ZB$H did not work.
# Getting data for: ZBH
# Ticker: ZBH did not work.
# Getting data for: ZBK
# Failed to obtain sector and industry for ZBK
# Failed to parse json response for ZBK
# Ticker: ZBK did not work.
# Getting data for: ZBRA
# Getting data for: ZBZX
# Failed to obtain sector and industry for ZBZX
# Failed to parse json response for ZBZX
# Ticker: ZBZX did not work.
# Getting data for: ZBZZT
# Failed to obtain sector and industry for ZBZZT
# Failed to parse json response for ZBZZT
# Ticker: ZBZZT did not work.
# Getting data for: ZCZZT
# Failed to obtain sector and industry for ZCZZT
# Failed to parse json response for ZCZZT
# Ticker: ZCZZT did not work.
# Getting data for: ZDGE
# Failed to obtain sector and industry for ZDGE
# Failed to parse json response for ZDGE
# Ticker: ZDGE did not work.
# Getting data for: ZEAL
# Failed to obtain sector and industry for ZEAL
# Getting data for: ZEN
# Getting data for: ZEUS
# Failed to parse json response for ZEUS
# Ticker: ZEUS did not work.
# Getting data for: ZEXIT
# Failed to obtain sector and industry for ZEXIT
# Failed to parse json response for ZEXIT
# Ticker: ZEXIT did not work.
# Getting data for: ZFGN
# Getting data for: ZG
# Getting data for: ZGNX
# Getting data for: ZIEXT
# Failed to obtain sector and industry for ZIEXT
# Failed to parse json response for ZIEXT
# Ticker: ZIEXT did not work.
# Getting data for: ZION
# Getting data for: ZIONW
# Failed to obtain sector and industry for ZIONW
# Failed to parse json response for ZIONW
# Ticker: ZIONW did not work.
# Getting data for: ZIOP
# Getting data for: ZIV
# Failed to obtain sector and industry for ZIV
# Failed to parse json response for ZIV
# Ticker: ZIV did not work.
# Getting data for: ZIXI
# Getting data for: ZJZZT
# Failed to obtain sector and industry for ZJZZT
# Failed to parse json response for ZJZZT
# Ticker: ZJZZT did not work.
# Getting data for: ZKIN
# Failed to obtain sector and industry for ZKIN
# Failed to parse json response for ZKIN
# Ticker: ZKIN did not work.
# Getting data for: ZLAB
# Failed to obtain sector and industry for ZLAB
# Getting data for: ZM
# Failed to obtain sector and industry for ZM
# Getting data for: ZN
# Failed to parse json response for ZN
# Ticker: ZN did not work.
# Getting data for: ZNGA
# Getting data for: ZNH
# Getting data for: ZNWAA
# Failed to obtain sector and industry for ZNWAA
# Failed to parse json response for ZNWAA
# Ticker: ZNWAA did not work.
# Getting data for: ZOM
# Failed to obtain sector and industry for ZOM
# Getting data for: ZS
# Failed to obtain sector and industry for ZS
# Getting data for: ZSAN
# Getting data for: ZTEST
# Failed to obtain sector and industry for ZTEST
# Failed to parse json response for ZTEST
# Ticker: ZTEST did not work.
# Getting data for: ZTO
# Failed to obtain sector and industry for ZTO
# Getting data for: ZTR
# Failed to parse json response for ZTR
# Ticker: ZTR did not work.
# Getting data for: ZTS
# Getting data for: ZUMZ
# Getting data for: ZUO
# Failed to obtain sector and industry for ZUO
# Getting data for: ZVO
# Failed to obtain sector and industry for ZVO
# Getting data for: ZVV
# Failed to obtain sector and industry for ZVV
# Failed to parse json response for ZVV
# Ticker: ZVV did not work.
# Getting data for: ZVZZC
# Failed to obtain sector and industry for ZVZZC
# Failed to parse json response for ZVZZC
# Ticker: ZVZZC did not work.
# Getting data for: ZVZZT
# Failed to obtain sector and industry for ZVZZT
# Failed to parse json response for ZVZZT
# Ticker: ZVZZT did not work.
# Getting data for: ZWZZT
# Failed to obtain sector and industry for ZWZZT
# Failed to parse json response for ZWZZT
# Ticker: ZWZZT did not work.
# Getting data for: ZXIET
# Failed to obtain sector and industry for ZXIET
# Failed to parse json response for ZXIET
# Ticker: ZXIET did not work.
# Getting data for: ZXYZ.A
# Failed to obtain sector and industry for ZXYZ.A
# Failed to parse json response for ZXYZ.A
# Ticker: ZXYZ.A did not work.
# Getting data for: ZXZZT
# Failed to obtain sector and industry for ZXZZT
# Failed to parse json response for ZXZZT
# Ticker: ZXZZT did not work.
# Getting data for: ZYME
# Failed to obtain sector and industry for ZYME
# Getting data for: ZYNE
# Getting data for: ZYXI
# Failed to parse json response for ZYXI
# Ticker: ZYXI did not work.

# %%
df = pd.read_csv('csv_files/company_statistics.csv', encoding='cp1252')

# %%
df.head()
# Out:
#   Ticker              Sector                       Industry    Price  \
# 0      A          Healthcare         Diagnostics & Research  85.3400
# 1     AA     Basic Materials                       Aluminum  21.7000
# 2   AACG  Consumer Defensive  Education & Training Services   1.4002
# 3    AAL         Industrials                       Airlines  28.5000
# 4    AAN         Industrials      Rental & Leasing Services  56.3500
#
#    Market Cap (intraday)  Trailing P/E  Forward P/E  \
# 0           2.600000e+10         25.15        22.30
# 1           4.000000e+09           NaN        28.67
# 2           3.300000e+07           NaN          NaN
# 3           1.200000e+10          8.00         5.29
# 4           3.800000e+09         19.19        12.47
#
#    PEG Ratio (5 yr expected)  Price/Sales  Price/Book  ...  Beta (3Y Monthly)  \
# 0                       2.73         5.09        5.52  ...                NaN
# 1                       1.62         0.35        0.88  ...                NaN
# 2                        NaN          NaN         NaN  ...                NaN
# 3                       0.61         0.27       77.47  ...                NaN
# 4                       0.82         0.95        2.01  ...                NaN
#
#    Shares Outstanding  Forward Annual Dividend Rate  \
# 0         309000000.0                          0.72
# 1         185570000.0                           NaN
# 2          23800000.0                           NaN
# 3         438060000.0                          0.40
# 4          67150000.0                          0.16
#
#    Forward Annual Dividend Yield  Trailing Annual Dividend Rate  \
# 0                           0.84                           0.66
# 1                            NaN                           0.36
# 2                            NaN                            NaN
# 3                           1.41                           0.40
# 4                           0.28                           0.14
#
#    Trailing Annual Dividend Yield  5 Year Average Dividend Yield  \
# 0                            0.77                           0.94
# 1                            1.67                            NaN
# 2                             NaN                            NaN
# 3                            1.41                           0.99
# 4                            0.25                           0.29
#
#    Payout Ratio  Net Income Avi to Common  Enterprise Value
# 0         19.47              1.070000e+09      2.752000e+10
# 1          0.00             -7.940000e+08      7.050000e+09
# 2          0.00                       NaN      3.486000e+07
# 3         11.30              1.600000e+09      4.173000e+10
# 4          4.81              2.002700e+08      4.350000e+09
#
# [5 rows x 42 columns]

# %%
df.corr()
# Out:
#                                    Price  Market Cap (intraday)  Trailing P/E  \
# Price                           1.000000               0.294579     -0.006413
# Market Cap (intraday)           0.294579               1.000000     -0.010471
# Trailing P/E                   -0.006413              -0.010471      1.000000
# Forward P/E                     0.015509               0.010356     -0.025532
# PEG Ratio (5 yr expected)      -0.016156              -0.002898     -0.033004
# Price/Sales                    -0.014559              -0.008498      0.028273
# Price/Book                      0.133739               0.039158      0.005066
# Enterprise Value/Revenue       -0.007525              -0.006135      0.029065
# Enterprise Value/EBITDA         0.009533               0.003804      0.020951
# Profit Margin                   0.141966               0.078135     -0.026548
# Operating Margin                0.021683               0.009467     -0.001107
# Return on Assets                0.066923               0.031102     -0.005021
# Return on Equity                0.109549               0.085731     -0.007330
# Revenue                         0.197160               0.600692     -0.013487
# Revenue Per Share               0.278700               0.056439     -0.020238
# Quarterly Revenue Growth       -0.012836              -0.007390     -0.001402
# Gross Profit                   -0.007329               0.025714     -0.004707
# EBITDA                          0.221227               0.853081     -0.018417
# Diluted EPS                     0.256339               0.101423     -0.026953
# EPS Beat Ratio                 -0.054400              -0.006798      0.032583
# Quarterly Earnings Growth      -0.017922              -0.002842      0.000432
# Total Cash                      0.054145               0.301427     -0.006614
# Total Cash Per Share            0.044298               0.030315     -0.007682
# Total Debt                      0.093119               0.410440     -0.008329
# Total Debt/Equity              -0.015806              -0.005840     -0.006424
# Current Ratio                  -0.011113              -0.001893     -0.002286
# Book Value Per Share            0.410341               0.097981     -0.015254
# Operating Cash Flow             0.178453               0.642643     -0.010984
# Levered Free Cash Flow          0.201915               0.780794     -0.013788
# Beta (3Y Monthly)                    NaN                    NaN           NaN
# Shares Outstanding              0.013369               0.471282     -0.012920
# Forward Annual Dividend Rate    0.625922               0.240179     -0.011778
# Forward Annual Dividend Yield  -0.190483              -0.054164      0.000708
# Trailing Annual Dividend Rate   0.256480               0.100184     -0.008288
# Trailing Annual Dividend Yield -0.022095              -0.008161      0.002098
# 5 Year Average Dividend Yield  -0.337991              -0.085814      0.034782
# Payout Ratio                   -0.008142               0.006142      0.219480
# Net Income Avi to Common        0.223848               0.881455     -0.020887
# Enterprise Value               -0.003554               0.035420     -0.002010
#
#                                 Forward P/E  PEG Ratio (5 yr expected)  \
# Price                              0.015509                  -0.016156
# Market Cap (intraday)              0.010356                  -0.002898
# Trailing P/E                      -0.025532                  -0.033004
# Forward P/E                        1.000000                   0.001665
# PEG Ratio (5 yr expected)          0.001665                   1.000000
# Price/Sales                       -0.008083                  -0.000805
# Price/Book                        -0.003694                  -0.015008
# Enterprise Value/Revenue          -0.007054                  -0.000909
# Enterprise Value/EBITDA           -0.000018                  -0.004280
# Profit Margin                      0.039372                   0.020481
# Operating Margin                   0.004564                   0.001229
# Return on Assets                   0.044950                   0.009633
# Return on Equity                   0.018336                   0.007301
# Revenue                           -0.000625                   0.002590
# Revenue Per Share                 -0.000582                  -0.001065
# Quarterly Revenue Growth          -0.012710                  -0.001012
# Gross Profit                      -0.000865                   0.005328
# EBITDA                             0.006034                   0.004693
# Diluted EPS                        0.018076                   0.000413
# EPS Beat Ratio                     0.030482                   0.008032
# Quarterly Earnings Growth          0.012630                   0.001065
# Total Cash                        -0.001169                  -0.000036
# Total Cash Per Share              -0.004682                  -0.000267
# Total Debt                        -0.000768                   0.001122
# Total Debt/Equity                 -0.004954                   0.006383
# Current Ratio                     -0.004558                  -0.002641
# Book Value Per Share               0.010013                  -0.007559
# Operating Cash Flow                0.005332                   0.003041
# Levered Free Cash Flow             0.005946                   0.004806
# Beta (3Y Monthly)                       NaN                        NaN
# Shares Outstanding                 0.006717                   0.007460
# Forward Annual Dividend Rate       0.017210                   0.000760
# Forward Annual Dividend Yield      0.006150                   0.054460
# Trailing Annual Dividend Rate      0.032183                   0.016394
# Trailing Annual Dividend Yield     0.002531                   0.064512
# 5 Year Average Dividend Yield      0.016561                   0.067676
# Payout Ratio                       0.039958                   0.006396
# Net Income Avi to Common           0.004581                   0.004396
# Enterprise Value                   0.011414                  -0.004466
#
#                                 Price/Sales  Price/Book  \
# Price                             -0.014559    0.133739
# Market Cap (intraday)             -0.008498    0.039158
# Trailing P/E                       0.028273    0.005066
# Forward P/E                       -0.008083   -0.003694
# PEG Ratio (5 yr expected)         -0.000805   -0.015008
# Price/Sales                        1.000000   -0.016202
# Price/Book                        -0.016202    1.000000
# Enterprise Value/Revenue           0.872140   -0.012761
# Enterprise Value/EBITDA            0.000794    0.000033
# Profit Margin                      0.007541   -0.001935
# Operating Margin                  -0.620679    0.008228
# Return on Assets                  -0.029505    0.143944
# Return on Equity                  -0.021043    0.176135
# Revenue                           -0.011660    0.005769
# Revenue Per Share                 -0.018913   -0.009565
# Quarterly Revenue Growth           0.005389   -0.000009
# Gross Profit                      -0.012209   -0.007631
# EBITDA                            -0.014275    0.006847
# Diluted EPS                       -0.024632    0.008265
# EPS Beat Ratio                    -0.000922   -0.001264
# Quarterly Earnings Growth         -0.002759   -0.004522
# Total Cash                        -0.002897   -0.009383
# Total Cash Per Share              -0.001650   -0.008932
# Total Debt                        -0.007405   -0.014198
# Total Debt/Equity                 -0.007601    0.146314
# Current Ratio                      0.024810   -0.005352
# Book Value Per Share              -0.017110   -0.079967
# Operating Cash Flow               -0.009627    0.009638
# Levered Free Cash Flow            -0.010412    0.021088
# Beta (3Y Monthly)                       NaN         NaN
# Shares Outstanding                -0.010869   -0.014202
# Forward Annual Dividend Rate       0.119790    0.062482
# Forward Annual Dividend Yield      0.023861    0.000588
# Trailing Annual Dividend Rate      0.035586    0.027584
# Trailing Annual Dividend Yield    -0.006197   -0.005462
# 5 Year Average Dividend Yield      0.053285   -0.001445
# Payout Ratio                      -0.005750   -0.014705
# Net Income Avi to Common          -0.009285    0.015323
# Enterprise Value                  -0.010234   -0.003020
#
#                                 Enterprise Value/Revenue  \
# Price                                          -0.007525
# Market Cap (intraday)                          -0.006135
# Trailing P/E                                    0.029065
# Forward P/E                                    -0.007054
# PEG Ratio (5 yr expected)                      -0.000909
# Price/Sales                                     0.872140
# Price/Book                                     -0.012761
# Enterprise Value/Revenue                        1.000000
# Enterprise Value/EBITDA                         0.000686
# Profit Margin                                   0.009401
# Operating Margin                               -0.208088
# Return on Assets                               -0.027343
# Return on Equity                               -0.022114
# Revenue                                        -0.009507
# Revenue Per Share                              -0.015552
# Quarterly Revenue Growth                        0.003298
# Gross Profit                                   -0.010692
# EBITDA                                         -0.012306
# Diluted EPS                                    -0.022726
# EPS Beat Ratio                                  0.000104
# Quarterly Earnings Growth                      -0.003543
# Total Cash                                     -0.002623
# Total Cash Per Share                           -0.001450
# Total Debt                                     -0.006008
# Total Debt/Equity                              -0.005594
# Current Ratio                                   0.019122
# Book Value Per Share                           -0.012289
# Operating Cash Flow                            -0.007697
# Levered Free Cash Flow                         -0.009221
# Beta (3Y Monthly)                                    NaN
# Shares Outstanding                             -0.008376
# Forward Annual Dividend Rate                    0.066142
# Forward Annual Dividend Yield                   0.029164
# Trailing Annual Dividend Rate                   0.025802
# Trailing Annual Dividend Yield                 -0.003368
# 5 Year Average Dividend Yield                   0.025029
# Payout Ratio                                   -0.002332
# Net Income Avi to Common                       -0.007512
# Enterprise Value                               -0.007396
#
#                                 Enterprise Value/EBITDA  Profit Margin  ...  \
# Price                                          0.009533       0.141966  ...
# Market Cap (intraday)                          0.003804       0.078135  ...
# Trailing P/E                                   0.020951      -0.026548  ...
# Forward P/E                                   -0.000018       0.039372  ...
# PEG Ratio (5 yr expected)                     -0.004280       0.020481  ...
# Price/Sales                                    0.000794       0.007541  ...
# Price/Book                                     0.000033      -0.001935  ...
# Enterprise Value/Revenue                       0.000686       0.009401  ...
# Enterprise Value/EBITDA                        1.000000      -0.000896  ...
# Profit Margin                                 -0.000896       1.000000  ...
# Operating Margin                              -0.000749      -0.001530  ...
# Return on Assets                              -0.001509       0.114780  ...
# Return on Equity                              -0.001341       0.155660  ...
# Revenue                                        0.004541       0.038588  ...
# Revenue Per Share                              0.007477       0.027073  ...
# Quarterly Revenue Growth                      -0.000533      -0.037206  ...
# Gross Profit                                   0.004720       0.013767  ...
# EBITDA                                         0.004408       0.091694  ...
# Diluted EPS                                    0.000875       0.198332  ...
# EPS Beat Ratio                                 0.000902      -0.003749  ...
# Quarterly Earnings Growth                     -0.006508       0.005686  ...
# Total Cash                                     0.003071       0.031468  ...
# Total Cash Per Share                           0.004963       0.011621  ...
# Total Debt                                     0.005316       0.056629  ...
# Total Debt/Equity                              0.003066       0.003286  ...
# Current Ratio                                  0.001597       0.006485  ...
# Book Value Per Share                           0.007515       0.138197  ...
# Operating Cash Flow                            0.004174       0.055350  ...
# Levered Free Cash Flow                         0.003352       0.068793  ...
# Beta (3Y Monthly)                                   NaN            NaN  ...
# Shares Outstanding                             0.005303       0.053950  ...
# Forward Annual Dividend Rate                   0.021048       0.087823  ...
# Forward Annual Dividend Yield                 -0.031267       0.027657  ...
# Trailing Annual Dividend Rate                  0.058319      -0.017862  ...
# Trailing Annual Dividend Yield                 0.049835      -0.078698  ...
# 5 Year Average Dividend Yield                 -0.122036       0.063904  ...
# Payout Ratio                                   0.003702       0.038900  ...
# Net Income Avi to Common                       0.002899       0.113325  ...
# Enterprise Value                               0.004423       0.006292  ...
#
#                                 Beta (3Y Monthly)  Shares Outstanding  \
# Price                                         NaN            0.013369
# Market Cap (intraday)                         NaN            0.471282
# Trailing P/E                                  NaN           -0.012920
# Forward P/E                                   NaN            0.006717
# PEG Ratio (5 yr expected)                     NaN            0.007460
# Price/Sales                                   NaN           -0.010869
# Price/Book                                    NaN           -0.014202
# Enterprise Value/Revenue                      NaN           -0.008376
# Enterprise Value/EBITDA                       NaN            0.005303
# Profit Margin                                 NaN            0.053950
# Operating Margin                              NaN            0.009061
# Return on Assets                              NaN            0.022328
# Return on Equity                              NaN            0.037063
# Revenue                                       NaN            0.577649
# Revenue Per Share                             NaN           -0.003309
# Quarterly Revenue Growth                      NaN           -0.005193
# Gross Profit                                  NaN            0.068253
# EBITDA                                        NaN            0.785990
# Diluted EPS                                   NaN            0.034214
# EPS Beat Ratio                                NaN            0.003074
# Quarterly Earnings Growth                     NaN            0.003310
# Total Cash                                    NaN            0.359410
# Total Cash Per Share                          NaN            0.018292
# Total Debt                                    NaN            0.558369
# Total Debt/Equity                             NaN           -0.005979
# Current Ratio                                 NaN            0.048947
# Book Value Per Share                          NaN            0.014016
# Operating Cash Flow                           NaN            0.547769
# Levered Free Cash Flow                        NaN            0.657977
# Beta (3Y Monthly)                             NaN                 NaN
# Shares Outstanding                            NaN            1.000000
# Forward Annual Dividend Rate                  NaN           -0.012159
# Forward Annual Dividend Yield                 NaN           -0.011131
# Trailing Annual Dividend Rate                 NaN           -0.008672
# Trailing Annual Dividend Yield                NaN           -0.006658
# 5 Year Average Dividend Yield                 NaN           -0.008998
# Payout Ratio                                  NaN            0.028514
# Net Income Avi to Common                      NaN            0.670649
# Enterprise Value                              NaN            0.340904
#
#                                 Forward Annual Dividend Rate  \
# Price                                               0.625922
# Market Cap (intraday)                               0.240179
# Trailing P/E                                       -0.011778
# Forward P/E                                         0.017210
# PEG Ratio (5 yr expected)                           0.000760
# Price/Sales                                         0.119790
# Price/Book                                          0.062482
# Enterprise Value/Revenue                            0.066142
# Enterprise Value/EBITDA                             0.021048
# Profit Margin                                       0.087823
# Operating Margin                                    0.070968
# Return on Assets                                    0.023632
# Return on Equity                                    0.075316
# Revenue                                             0.206689
# Revenue Per Share                                   0.202532
# Quarterly Revenue Growth                           -0.014877
# Gross Profit                                       -0.011271
# EBITDA                                              0.244730
# Diluted EPS                                         0.487796
# EPS Beat Ratio                                     -0.024047
# Quarterly Earnings Growth                          -0.014076
# Total Cash                                          0.074304
# Total Cash Per Share                                0.106730
# Total Debt                                          0.132715
# Total Debt/Equity                                   0.007668
# Current Ratio                                      -0.018279
# Book Value Per Share                                0.377884
# Operating Cash Flow                                 0.195982
# Levered Free Cash Flow                              0.210555
# Beta (3Y Monthly)                                        NaN
# Shares Outstanding                                 -0.012159
# Forward Annual Dividend Rate                        1.000000
# Forward Annual Dividend Yield                       0.076430
# Trailing Annual Dividend Rate                       0.927666
# Trailing Annual Dividend Yield                      0.063097
# 5 Year Average Dividend Yield                       0.051823
# Payout Ratio                                        0.017291
# Net Income Avi to Common                            0.232755
# Enterprise Value                                   -0.015686
#
#                                 Forward Annual Dividend Yield  \
# Price                                               -0.190483
# Market Cap (intraday)                               -0.054164
# Trailing P/E                                         0.000708
# Forward P/E                                          0.006150
# PEG Ratio (5 yr expected)                            0.054460
# Price/Sales                                          0.023861
# Price/Book                                           0.000588
# Enterprise Value/Revenue                             0.029164
# Enterprise Value/EBITDA                             -0.031267
# Profit Margin                                        0.027657
# Operating Margin                                     0.147573
# Return on Assets                                     0.104551
# Return on Equity                                     0.052194
# Revenue                                             -0.040482
# Revenue Per Share                                   -0.092826
# Quarterly Revenue Growth                            -0.003911
# Gross Profit                                        -0.002337
# EBITDA                                              -0.023261
# Diluted EPS                                         -0.121040
# EPS Beat Ratio                                      -0.015027
# Quarterly Earnings Growth                            0.004459
# Total Cash                                          -0.009602
# Total Cash Per Share                                -0.025331
# Total Debt                                          -0.002528
# Total Debt/Equity                                    0.105746
# Current Ratio                                        0.014172
# Book Value Per Share                                -0.114719
# Operating Cash Flow                                 -0.023599
# Levered Free Cash Flow                              -0.031413
# Beta (3Y Monthly)                                         NaN
# Shares Outstanding                                  -0.011131
# Forward Annual Dividend Rate                         0.076430
# Forward Annual Dividend Yield                        1.000000
# Trailing Annual Dividend Rate                        0.054352
# Trailing Annual Dividend Yield                       0.875579
# 5 Year Average Dividend Yield                        0.843155
# Payout Ratio                                         0.075006
# Net Income Avi to Common                            -0.045316
# Enterprise Value                                    -0.002189
#
#                                 Trailing Annual Dividend Rate  \
# Price                                                0.256480
# Market Cap (intraday)                                0.100184
# Trailing P/E                                        -0.008288
# Forward P/E                                          0.032183
# PEG Ratio (5 yr expected)                            0.016394
# Price/Sales                                          0.035586
# Price/Book                                           0.027584
# Enterprise Value/Revenue                             0.025802
# Enterprise Value/EBITDA                              0.058319
# Profit Margin                                       -0.017862
# Operating Margin                                     0.051735
# Return on Assets                                     0.012374
# Return on Equity                                     0.036346
# Revenue                                              0.085772
# Revenue Per Share                                    0.075648
# Quarterly Revenue Growth                            -0.009077
# Gross Profit                                         0.002427
# EBITDA                                               0.097495
# Diluted EPS                                          0.173951
# EPS Beat Ratio                                      -0.000707
# Quarterly Earnings Growth                           -0.023013
# Total Cash                                           0.021717
# Total Cash Per Share                                 0.006250
# Total Debt                                           0.046803
# Total Debt/Equity                                   -0.002363
# Current Ratio                                       -0.017204
# Book Value Per Share                                 0.151896
# Operating Cash Flow                                  0.194270
# Levered Free Cash Flow                               0.215372
# Beta (3Y Monthly)                                         NaN
# Shares Outstanding                                  -0.008672
# Forward Annual Dividend Rate                         0.927666
# Forward Annual Dividend Yield                        0.054352
# Trailing Annual Dividend Rate                        1.000000
# Trailing Annual Dividend Yield                       0.885704
# 5 Year Average Dividend Yield                        0.067603
# Payout Ratio                                         0.016701
# Net Income Avi to Common                             0.097209
# Enterprise Value                                    -0.007648
#
#                                 Trailing Annual Dividend Yield  \
# Price                                                -0.022095
# Market Cap (intraday)                                -0.008161
# Trailing P/E                                          0.002098
# Forward P/E                                           0.002531
# PEG Ratio (5 yr expected)                             0.064512
# Price/Sales                                          -0.006197
# Price/Book                                           -0.005462
# Enterprise Value/Revenue                             -0.003368
# Enterprise Value/EBITDA                               0.049835
# Profit Margin                                        -0.078698
# Operating Margin                                     -0.015059
# Return on Assets                                      0.000383
# Return on Equity                                     -0.002712
# Revenue                                              -0.007927
# Revenue Per Share                                    -0.013956
# Quarterly Revenue Growth                              0.000401
# Gross Profit                                         -0.001111
# EBITDA                                               -0.009856
# Diluted EPS                                          -0.020272
# EPS Beat Ratio                                       -0.003224
# Quarterly Earnings Growth                            -0.009268
# Total Cash                                           -0.002429
# Total Cash Per Share                                 -0.001344
# Total Debt                                           -0.004859
# Total Debt/Equity                                    -0.003379
# Current Ratio                                         0.009688
# Book Value Per Share                                 -0.020247
# Operating Cash Flow                                  -0.027859
# Levered Free Cash Flow                               -0.036866
# Beta (3Y Monthly)                                          NaN
# Shares Outstanding                                   -0.006658
# Forward Annual Dividend Rate                          0.063097
# Forward Annual Dividend Yield                         0.875579
# Trailing Annual Dividend Rate                         0.885704
# Trailing Annual Dividend Yield                        1.000000
# 5 Year Average Dividend Yield                         0.800190
# Payout Ratio                                         -0.002730
# Net Income Avi to Common                             -0.007118
# Enterprise Value                                     -0.000824
#
#                                 5 Year Average Dividend Yield  Payout Ratio  \
# Price                                               -0.337991     -0.008142
# Market Cap (intraday)                               -0.085814      0.006142
# Trailing P/E                                         0.034782      0.219480
# Forward P/E                                          0.016561      0.039958
# PEG Ratio (5 yr expected)                            0.067676      0.006396
# Price/Sales                                          0.053285     -0.005750
# Price/Book                                          -0.001445     -0.014705
# Enterprise Value/Revenue                             0.025029     -0.002332
# Enterprise Value/EBITDA                             -0.122036      0.003702
# Profit Margin                                        0.063904      0.038900
# Operating Margin                                     0.345135      0.005144
# Return on Assets                                     0.119549      0.015812
# Return on Equity                                     0.054292      0.015411
# Revenue                                             -0.068108      0.005772
# Revenue Per Share                                   -0.185245     -0.014364
# Quarterly Revenue Growth                            -0.120461     -0.004293
# Gross Profit                                        -0.001102      0.001010
# EBITDA                                              -0.011281      0.038088
# Diluted EPS                                         -0.293355      0.006827
# EPS Beat Ratio                                      -0.011059      0.007034
# Quarterly Earnings Growth                            0.023853     -0.001759
# Total Cash                                          -0.022964     -0.001018
# Total Cash Per Share                                 0.020395     -0.007004
# Total Debt                                           0.001201      0.011261
# Total Debt/Equity                                    0.069689      0.000939
# Current Ratio                                        0.020054      0.003416
# Book Value Per Share                                -0.210127      0.012423
# Operating Cash Flow                                 -0.036780      0.009428
# Levered Free Cash Flow                              -0.041829      0.022154
# Beta (3Y Monthly)                                         NaN           NaN
# Shares Outstanding                                  -0.008998      0.028514
# Forward Annual Dividend Rate                         0.051823      0.017291
# Forward Annual Dividend Yield                        0.843155      0.075006
# Trailing Annual Dividend Rate                        0.067603      0.016701
# Trailing Annual Dividend Yield                       0.800190     -0.002730
# 5 Year Average Dividend Yield                        1.000000      0.204332
# Payout Ratio                                         0.204332      1.000000
# Net Income Avi to Common                            -0.079730      0.001935
# Enterprise Value                                    -0.066735      0.002702
#
#                                 Net Income Avi to Common  Enterprise Value
# Price                                           0.223848         -0.003554
# Market Cap (intraday)                           0.881455          0.035420
# Trailing P/E                                   -0.020887         -0.002010
# Forward P/E                                     0.004581          0.011414
# PEG Ratio (5 yr expected)                       0.004396         -0.004466
# Price/Sales                                    -0.009285         -0.010234
# Price/Book                                      0.015323         -0.003020
# Enterprise Value/Revenue                       -0.007512         -0.007396
# Enterprise Value/EBITDA                         0.002899          0.004423
# Profit Margin                                   0.113325          0.006292
# Operating Margin                                0.008386          0.000798
# Return on Assets                                0.029532          0.001307
# Return on Equity                                0.091306          0.002916
# Revenue                                         0.600344          0.647785
# Revenue Per Share                               0.056477          0.068389
# Quarterly Revenue Growth                       -0.006406         -0.000761
# Gross Profit                                    0.816964         -0.000051
# EBITDA                                          0.862979          0.911341
# Diluted EPS                                     0.218554          0.001284
# EPS Beat Ratio                                 -0.001994         -0.006460
# Quarterly Earnings Growth                      -0.020668         -0.004441
# Total Cash                                      0.460160          0.098633
# Total Cash Per Share                            0.057588         -0.027894
# Total Debt                                      0.563034          0.303842
# Total Debt/Equity                              -0.002085          0.000170
# Current Ratio                                  -0.031709         -0.003044
# Book Value Per Share                            0.125737         -0.003874
# Operating Cash Flow                             0.547787          0.733489
# Levered Free Cash Flow                          0.764544          0.799635
# Beta (3Y Monthly)                                    NaN               NaN
# Shares Outstanding                              0.670649          0.340904
# Forward Annual Dividend Rate                    0.232755         -0.015686
# Forward Annual Dividend Yield                  -0.045316         -0.002189
# Trailing Annual Dividend Rate                   0.097209         -0.007648
# Trailing Annual Dividend Yield                 -0.007118         -0.000824
# 5 Year Average Dividend Yield                  -0.079730         -0.066735
# Payout Ratio                                    0.001935          0.002702
# Net Income Avi to Common                        1.000000          0.819302
# Enterprise Value                                0.819302          1.000000
#
# [39 rows x 39 columns]

# %%
import matplotlib.pyplot as plt
import hvplot.pandas
df.hvplot(x='Market Cap (intraday)', y='Price', kind='scatter')
# Out:
# :Scatter   [Market Cap (intraday)]   (Price)

# %%
df['log(Market Cap)'] = np.log(df['Market Cap (intraday)'])
df['log(Price)'] = np.log(df['Price'])
df.hvplot(x='log(Market Cap)', y='log(Price)', kind='scatter')
# Out:
# C:\Users\kevin\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas\core\series.py:853: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\kevin\Anaconda3\envs\tensorflow_env\lib\site-packages\holoviews\core\util.py:992: RuntimeWarning: invalid value encountered in double_scalars
#   lpad = span*(padding[0])
# C:\Users\kevin\Anaconda3\envs\tensorflow_env\lib\site-packages\holoviews\core\util.py:993: RuntimeWarning: invalid value encountered in double_scalars
#   upad = span*(padding[1])
# C:\Users\kevin\Anaconda3\envs\tensorflow_env\lib\site-packages\holoviews\core\util.py:992: RuntimeWarning: invalid value encountered in double_scalars
#   lpad = span*(padding[0])
# C:\Users\kevin\Anaconda3\envs\tensorflow_env\lib\site-packages\holoviews\core\util.py:993: RuntimeWarning: invalid value encountered in double_scalars
#   upad = span*(padding[1])
# :Scatter   [log(Market Cap)]   (log(Price))

# %%
import statsmodels.api as sm
df_no_na = df.dropna()
X = sm.add_constant(df_no_na[['log(Market Cap)']])
y = df_no_na['log(Price)']
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model
# Print out the statistics
print(model.summary())
# Out:
# C:\Users\kevin\Anaconda3\envs\tensorflow_env\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-ed5fc948a37d> in <module>
#       3 X = sm.add_constant(df_no_na[['log(Market Cap)']])
#       4 y = df_no_na['log(Price)']
# ----> 5 model = sm.OLS(y, X).fit()
#       6 predictions = model.predict(X) # make the predictions by the model
#       7 # Print out the statistics
#
# ~\Anaconda3\envs\tensorflow_env\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     836                  **kwargs):
#     837         super(OLS, self).__init__(endog, exog, missing=missing,
# --> 838                                   hasconst=hasconst, **kwargs)
#     839         if "weights" in self._init_keys:
#     840             self._init_keys.remove("weights")
#
# ~\Anaconda3\envs\tensorflow_env\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     682             weights = weights.squeeze()
#     683         super(WLS, self).__init__(endog, exog, missing=missing,
# --> 684                                   weights=weights, hasconst=hasconst, **kwargs)
#     685         nobs = self.exog.shape[0]
#     686         weights = self.weights
#
# ~\Anaconda3\envs\tensorflow_env\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, **kwargs)
#     194     """
#     195     def __init__(self, endog, exog, **kwargs):
# --> 196         super(RegressionModel, self).__init__(endog, exog, **kwargs)
#     197         self._data_attr.extend(['pinv_wexog', 'wendog', 'wexog', 'weights'])
#     198
#
# ~\Anaconda3\envs\tensorflow_env\lib\site-packages\statsmodels\base\model.py in __init__(self, endog, exog, **kwargs)
#     214
#     215     def __init__(self, endog, exog=None, **kwargs):
# --> 216         super(LikelihoodModel, self).__init__(endog, exog, **kwargs)
#     217         self.initialize()
#     218
#
# ~\Anaconda3\envs\tensorflow_env\lib\site-packages\statsmodels\base\model.py in __init__(self, endog, exog, **kwargs)
#      66         hasconst = kwargs.pop('hasconst', None)
#      67         self.data = self._handle_data(endog, exog, missing, hasconst,
# ---> 68                                       **kwargs)
#      69         self.k_constant = self.data.k_constant
#      70         self.exog = self.data.exog
#
# ~\Anaconda3\envs\tensorflow_env\lib\site-packages\statsmodels\base\model.py in _handle_data(self, endog, exog, missing, hasconst, **kwargs)
#      89
#      90     def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# ---> 91         data = handle_data(endog, exog, missing, hasconst, **kwargs)
#      92         # kwargs arrays could have changed, easier to just attach here
#      93         for key in kwargs:
#
# ~\Anaconda3\envs\tensorflow_env\lib\site-packages\statsmodels\base\data.py in handle_data(endog, exog, missing, hasconst, **kwargs)
#     633     klass = handle_data_class_factory(endog, exog)
#     634     return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
# --> 635                  **kwargs)
#
# ~\Anaconda3\envs\tensorflow_env\lib\site-packages\statsmodels\base\data.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#      78         self.const_idx = None
#      79         self.k_constant = 0
# ---> 80         self._handle_constant(hasconst)
#      81         self._check_integrity()
#      82         self._cache = {}
#
# ~\Anaconda3\envs\tensorflow_env\lib\site-packages\statsmodels\base\data.py in _handle_constant(self, hasconst)
#     122             # detect where the constant is
#     123             check_implicit = False
# --> 124             ptp_ = np.ptp(self.exog, axis=0)
#     125             if not np.isfinite(ptp_).all():
#     126                 raise MissingDataError('exog contains inf or nans')
#
# ~\Anaconda3\envs\tensorflow_env\lib\site-packages\numpy\core\fromnumeric.py in ptp(a, axis, out, keepdims)
#    2388         else:
#    2389             return ptp(axis=axis, out=out, **kwargs)
# -> 2390     return _methods._ptp(a, axis=axis, out=out, **kwargs)
#    2391
#    2392
#
# ~\Anaconda3\envs\tensorflow_env\lib\site-packages\numpy\core\_methods.py in _ptp(a, axis, out, keepdims)
#     151 def _ptp(a, axis=None, out=None, keepdims=False):
#     152     return um.subtract(
# --> 153         umr_maximum(a, axis, None, out, keepdims),
#     154         umr_minimum(a, axis, None, None, keepdims),
#     155         out
#
# ValueError: zero-size array to reduction operation maximum which has no identity

# %%
df['log(Book Value Per Share)'] = np.log(df['Book Value Per Share'])
df.hvplot(x='log(Book Value Per Share)', y='log(Price)', kind='scatter')
# Out:
# C:\Users\kevin\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas\core\series.py:853: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\kevin\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas\core\series.py:853: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\kevin\Anaconda3\envs\tensorflow_env\lib\site-packages\holoviews\core\util.py:992: RuntimeWarning: invalid value encountered in double_scalars
#   lpad = span*(padding[0])
# C:\Users\kevin\Anaconda3\envs\tensorflow_env\lib\site-packages\holoviews\core\util.py:993: RuntimeWarning: invalid value encountered in double_scalars
#   upad = span*(padding[1])
# C:\Users\kevin\Anaconda3\envs\tensorflow_env\lib\site-packages\holoviews\core\util.py:992: RuntimeWarning: invalid value encountered in double_scalars
#   lpad = span*(padding[0])
# C:\Users\kevin\Anaconda3\envs\tensorflow_env\lib\site-packages\holoviews\core\util.py:993: RuntimeWarning: invalid value encountered in double_scalars
#   upad = span*(padding[1])
# :Scatter   [log(Book Value Per Share)]   (log(Price))

# %%
df_no_na = df.dropna()
X = sm.add_constant(df_no_na[['log(Book Value Per Share)']])
y = df_no_na['log(Price)']
model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             log(Price)   R-squared:                       0.199
# Model:                            OLS   Adj. R-squared:                  0.190
# Method:                 Least Squares   F-statistic:                     21.65
# Date:                Tue, 12 Nov 2019   Prob (F-statistic):           1.16e-05
# Time:                        20:09:04   Log-Likelihood:                -109.20
# No. Observations:                  89   AIC:                             222.4
# Df Residuals:                      87   BIC:                             227.4
# Df Model:                           1
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         2.3674      0.376      6.298      0.000       1.620       3.114
# log(Book Value Per Share)     0.6335      0.136      4.653      0.000       0.363       0.904
# ==============================================================================
# Omnibus:                       10.234   Durbin-Watson:                   1.668
# Prob(Omnibus):                  0.006   Jarque-Bera (JB):               10.779
# Skew:                          -0.671   Prob(JB):                      0.00456
# Kurtosis:                       4.052   Cond. No.                         13.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# C:\Users\kevin\Anaconda3\envs\tensorflow_env\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
df.hvplot(x='log(Levered Free Cash Flow(TTM))', y='log(Price)', kind='scatter')
# Out:
# :Scatter   [Levered Free Cash Flow(TTM)]   (Price)

# %%
df['log(Levered Free Cash Flow(TTM))'] = np.log(df['Levered Free Cash Flow(TTM)'])
df.hvplot(x='log(Levered Free Cash Flow(TTM))', y='log(Price)', kind='scatter')
# Out:
# C:\Users\kevin\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas\core\series.py:853: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# :Scatter   [log(Levered Free Cash Flow(TTM))]   (log(Price))

# %%
df_no_na = df.dropna()
X = sm.add_constant(df_no_na[['log(Levered Free Cash Flow(TTM))']])
y = df_no_na['log(Price)']
model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             log(Price)   R-squared:                       0.231
# Model:                            OLS   Adj. R-squared:                  0.221
# Method:                 Least Squares   F-statistic:                     24.31
# Date:                Tue, 12 Nov 2019   Prob (F-statistic):           4.30e-06
# Time:                        20:31:33   Log-Likelihood:                -101.72
# No. Observations:                  83   AIC:                             207.4
# Df Residuals:                      81   BIC:                             212.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# const                               -0.5145      0.937     -0.549      0.584      -2.378       1.349
# log(Levered Free Cash Flow(TTM))     0.2403      0.049      4.930      0.000       0.143       0.337
# ==============================================================================
# Omnibus:                        3.816   Durbin-Watson:                   1.698
# Prob(Omnibus):                  0.148   Jarque-Bera (JB):                3.049
# Skew:                          -0.389   Prob(JB):                        0.218
# Kurtosis:                       3.527   Cond. No.                         197.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# C:\Users\kevin\Anaconda3\envs\tensorflow_env\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
df_no_na = df.dropna()
X = sm.add_constant(df_no_na[['log(Levered Free Cash Flow(TTM))', 'log(Book Value Per Share)']])
y = df_no_na['log(Price)']
model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             log(Price)   R-squared:                       0.406
# Model:                            OLS   Adj. R-squared:                  0.391
# Method:                 Least Squares   F-statistic:                     27.33
# Date:                Tue, 12 Nov 2019   Prob (F-statistic):           8.98e-10
# Time:                        20:32:17   Log-Likelihood:                -91.000
# No. Observations:                  83   AIC:                             188.0
# Df Residuals:                      80   BIC:                             195.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# const                               -1.8893      0.875     -2.158      0.034      -3.631      -0.147
# log(Levered Free Cash Flow(TTM))     0.2268      0.043      5.251      0.000       0.141       0.313
# log(Book Value Per Share)            0.6163      0.127      4.856      0.000       0.364       0.869
# ==============================================================================
# Omnibus:                        8.825   Durbin-Watson:                   1.667
# Prob(Omnibus):                  0.012   Jarque-Bera (JB):                9.775
# Skew:                          -0.559   Prob(JB):                      0.00754
# Kurtosis:                       4.256   Cond. No.                         210.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
df['log(Forward Annual Dividend Rate)'] = np.log(df['Forward Annual Dividend Rate'])
df.hvplot(x='log(Forward Annual Dividend Rate)', y='log(Price)', kind='scatter')
# Out:
# :Scatter   [log(Forward Annual Dividend Rate)]   (log(Price))

# %%
df_no_na = df.dropna()
X = sm.add_constant(df_no_na[['log(Forward Annual Dividend Rate)']])
y = df_no_na['log(Price)']
model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             log(Price)   R-squared:                       0.488
# Model:                            OLS   Adj. R-squared:                  0.482
# Method:                 Least Squares   F-statistic:                     77.34
# Date:                Tue, 12 Nov 2019   Prob (F-statistic):           2.02e-13
# Time:                        20:39:31   Log-Likelihood:                -84.793
# No. Observations:                  83   AIC:                             173.6
# Df Residuals:                      81   BIC:                             178.4
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# const                                 4.0376      0.075     53.947      0.000       3.889       4.186
# log(Forward Annual Dividend Rate)     0.7735      0.088      8.795      0.000       0.598       0.948
# ==============================================================================
# Omnibus:                        6.150   Durbin-Watson:                   1.748
# Prob(Omnibus):                  0.046   Jarque-Bera (JB):                5.476
# Skew:                          -0.530   Prob(JB):                       0.0647
# Kurtosis:                       3.679   Cond. No.                         1.19
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# C:\Users\kevin\Anaconda3\envs\tensorflow_env\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
df_no_na = df.dropna()
X = sm.add_constant(df_no_na[['log(Levered Free Cash Flow(TTM))', 'log(Book Value Per Share)', 'log(Forward Annual Dividend Rate)']])
y = df_no_na['log(Price)']
model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             log(Price)   R-squared:                       0.598
# Model:                            OLS   Adj. R-squared:                  0.583
# Method:                 Least Squares   F-statistic:                     39.14
# Date:                Tue, 12 Nov 2019   Prob (F-statistic):           1.32e-15
# Time:                        20:40:19   Log-Likelihood:                -74.814
# No. Observations:                  83   AIC:                             157.6
# Df Residuals:                      79   BIC:                             167.3
# Df Model:                           3
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# const                                 0.7902      0.846      0.934      0.353      -0.894       2.474
# log(Levered Free Cash Flow(TTM))      0.1108      0.040      2.739      0.008       0.030       0.191
# log(Book Value Per Share)             0.4301      0.109      3.933      0.000       0.212       0.648
# log(Forward Annual Dividend Rate)     0.5702      0.093      6.139      0.000       0.385       0.755
# ==============================================================================
# Omnibus:                        8.685   Durbin-Watson:                   1.716
# Prob(Omnibus):                  0.013   Jarque-Bera (JB):                8.846
# Skew:                          -0.607   Prob(JB):                       0.0120
# Kurtosis:                       4.042   Cond. No.                         246.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
df['log(Diluted EPS(TTM))'] = np.log(df['Diluted EPS(TTM)'])
df.hvplot(x='log(Diluted EPS(TTM))', y='log(Price)', kind='scatter')
# Out:
# C:\Users\kevin\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas\core\series.py:853: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\kevin\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas\core\series.py:853: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\kevin\Anaconda3\envs\tensorflow_env\lib\site-packages\holoviews\core\util.py:992: RuntimeWarning: invalid value encountered in double_scalars
#   lpad = span*(padding[0])
# C:\Users\kevin\Anaconda3\envs\tensorflow_env\lib\site-packages\holoviews\core\util.py:993: RuntimeWarning: invalid value encountered in double_scalars
#   upad = span*(padding[1])
# C:\Users\kevin\Anaconda3\envs\tensorflow_env\lib\site-packages\holoviews\core\util.py:992: RuntimeWarning: invalid value encountered in double_scalars
#   lpad = span*(padding[0])
# C:\Users\kevin\Anaconda3\envs\tensorflow_env\lib\site-packages\holoviews\core\util.py:993: RuntimeWarning: invalid value encountered in double_scalars
#   upad = span*(padding[1])
# :Scatter   [log(Diluted EPS(TTM))]   (log(Price))

# %%
df_no_na = df.dropna()
X = sm.add_constant(df_no_na[['log(Diluted EPS(TTM))']])
y = df_no_na['log(Price)']
model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             log(Price)   R-squared:                       0.535
# Model:                            OLS   Adj. R-squared:                  0.529
# Method:                 Least Squares   F-statistic:                     93.04
# Date:                Wed, 13 Nov 2019   Prob (F-statistic):           4.22e-15
# Time:                        21:03:18   Log-Likelihood:                -76.815
# No. Observations:                  83   AIC:                             157.6
# Df Residuals:                      81   BIC:                             162.5
# Df Model:                           1
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     3.4739      0.096     36.313      0.000       3.284       3.664
# log(Diluted EPS(TTM))     0.6840      0.071      9.646      0.000       0.543       0.825
# ==============================================================================
# Omnibus:                        2.537   Durbin-Watson:                   1.934
# Prob(Omnibus):                  0.281   Jarque-Bera (JB):                1.898
# Skew:                          -0.222   Prob(JB):                        0.387
# Kurtosis:                       3.593   Cond. No.                         2.56
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# C:\Users\kevin\Anaconda3\envs\tensorflow_env\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
df_no_na = df.dropna(subset=['log(Levered Free Cash Flow(TTM))', 'log(Book Value Per Share)', 'log(Forward Annual Dividend Rate)', 
                              'log(Diluted EPS(TTM))', 'log(Price)'])
X = sm.add_constant(df_no_na[['log(Levered Free Cash Flow(TTM))', 'log(Book Value Per Share)', 'log(Forward Annual Dividend Rate)', 
                              'log(Diluted EPS(TTM))']])
# print([i for i in y if i == float('nan')])
y = df_no_na['log(Price)']
model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-640635e5ebc6> in <module>
# ----> 1 df_no_na = df.dropna(subset=['log(Levered Free Cash Flow(TTM))', 'log(Book Value Per Share)', 'log(Forward Annual Dividend Rate)',
#       2                               'log(Diluted EPS(TTM))', 'log(Price)'])
#       3 X = sm.add_constant(df_no_na[['log(Levered Free Cash Flow(TTM))', 'log(Book Value Per Share)', 'log(Forward Annual Dividend Rate)',
#       4                               'log(Diluted EPS(TTM))']])
#       5 # print([i for i in y if i == float('nan')])
#
# NameError: name 'df' is not defined

# %%
x = [1, np.log(str_to_num('6.08B')), np.log(10.83), np.log(1.64), np.log(3.46)]
print(x)
predicted_price = model.predict(x)
# Out:
# [1, 22.528270532924488, 2.382320061012899, 0.494696241836107, 1.2412685890696329]

# %%
np.e**predicted_price[0]
# Out:
# 88.91771198475706

# %%
for index, row in df_no_na.iterrows():
    actual_price = row['Price']
    x = [1, row['log(Levered Free Cash Flow(TTM))'], 
         row['log(Book Value Per Share)'],
        row['log(Forward Annual Dividend Rate)'],
        row['log(Diluted EPS(TTM))']]
    predicted_price = np.e**model.predict(x)[0]
    ticker = row['Ticker']
    print(ticker + '. Actual Price: ' + str(actual_price) + '. Predicted Price: ' + str(round(predicted_price, 2)))
# Out:
# ARLP. Actual Price: 11.58. Predicted Price: 71.88
# AMGN. Actual Price: 220.24. Predicted Price: 258.77
# AAPL. Actual Price: 258.3. Predicted Price: 240.49
# AMAT. Actual Price: 55.77. Predicted Price: 60.82
# BBSI. Actual Price: 91.66. Predicted Price: 90.65
# BBGI. Actual Price: 2.82. Predicted Price: 13.28
# BGFV. Actual Price: 3.2. Predicted Price: 8.86
# BLKB. Actual Price: 80.29. Predicted Price: 18.79
# AVGO. Actual Price: 311.2. Predicted Price: 360.91
# BRKS. Actual Price: 46.19. Predicted Price: 63.05
# CHRW. Actual Price: 77.53. Predicted Price: 96.52
# CASY. Actual Price: 166.88. Predicted Price: 114.43
# CDW. Actual Price: 132.98. Predicted Price: 72.76
# PLCE. Actual Price: 81.64. Predicted Price: 76.19
# CTAS. Actual Price: 259.95. Predicted Price: 169.84
# CSCO. Actual Price: 48.01. Predicted Price: 71.94
# COLM. Actual Price: 93.39. Predicted Price: 79.4
# CMCO. Actual Price: 38.99. Predicted Price: 37.58
# CPSI. Actual Price: 26.71. Predicted Price: 27.89
# CNMD. Actual Price: 109.86. Predicted Price: 42.14
# CBRL. Actual Price: 165.18. Predicted Price: 188.84
# CSGS. Actual Price: 55.02. Predicted Price: 51.85
# CY. Actual Price: 23.29. Predicted Price: 22.13
# DAKT. Actual Price: 6.86. Predicted Price: 3.25
# XRAY. Actual Price: 57.11. Predicted Price: 32.89
# FAST. Actual Price: 36.82. Predicted Price: 32.31
# FLIR. Actual Price: 53.09. Predicted Price: 47.71
# GRMN. Actual Price: 96.08. Predicted Price: 111.7
# HAYN. Actual Price: 36.66. Predicted Price: 30.57
# HCSG. Actual Price: 25.16. Predicted Price: 27.69
# HSII. Actual Price: 30.31. Predicted Price: 46.71
# IPHS. Actual Price: 32.1. Predicted Price: 49.37
# ITRN. Actual Price: 24.01. Predicted Price: 41.16
# JJSF. Actual Price: 181.08. Predicted Price: 123.08
# JKHY. Actual Price: 148.98. Predicted Price: 83.55
# KFRC. Actual Price: 40.99. Predicted Price: 55.79
# KLAC. Actual Price: 173.63. Predicted Price: 143.11
# LRCX. Actual Price: 269.66. Predicted Price: 271.54
# LAMR. Actual Price: 81.51. Predicted Price: 101.77
# LSTR. Actual Price: 116.26. Predicted Price: 83.46
# LPLA. Actual Price: 86.52. Predicted Price: 83.41
# MANT. Actual Price: 75.36. Predicted Price: 76.21
# MKTX. Actual Price: 346.67. Predicted Price: 102.99
# MATW. Actual Price: 36.58. Predicted Price: 55.87
# MXIM. Actual Price: 59.06. Predicted Price: 62.49
# MGRC. Actual Price: 73.56. Predicted Price: 78.35
# MCHP. Actual Price: 95.28. Predicted Price: 72.52
# MSFT. Actual Price: 145.34. Predicted Price: 135.83
# MPWR. Actual Price: 163.41. Predicted Price: 64.72
# MNRO. Actual Price: 70.75. Predicted Price: 58.67
# NATI. Actual Price: 43.27. Predicted Price: 37.46
# NTAP. Actual Price: 59.22. Predicted Price: 61.39
# NVDA. Actual Price: 207.75. Predicted Price: 76.11
# ZEUS. Actual Price: 14.18. Predicted Price: 13.63
# OTEX. Actual Price: 41.59. Predicted Price: 43.21
# PAYX. Actual Price: 82.97. Predicted Price: 74.43
# PAHC. Actual Price: 23.12. Predicted Price: 19.68
# POOL. Actual Price: 200.55. Predicted Price: 95.67
# POWI. Actual Price: 93.22. Predicted Price: 45.15
# PFG. Actual Price: 54.74. Predicted Price: 164.59
# RECN. Actual Price: 14.69. Predicted Price: 26.56
# RCKY. Actual Price: 31.13. Predicted Price: 39.58
# ROST. Actual Price: 111.66. Predicted Price: 71.64
# RUTH. Actual Price: 25.28. Predicted Price: 20.89
# SABR. Actual Price: 22.51. Predicted Price: 22.15
# SAFT. Actual Price: 98.56. Predicted Price: 166.8
# SCHN. Actual Price: 21.66. Predicted Price: 51.91
# STX. Actual Price: 58.58. Predicted Price: 97.65
# SEIC. Actual Price: 62.37. Predicted Price: 52.8
# SCVL. Actual Price: 35.94. Predicted Price: 43.03
# SLGN. Actual Price: 30.84. Predicted Price: 34.53
# SAMG. Actual Price: 12.88. Predicted Price: 24.78
# SSNC. Actual Price: 57.39. Predicted Price: 42.16
# STLD. Actual Price: 31.32. Predicted Price: 79.66
# TROW. Actual Price: 119.04. Predicted Price: 183.96
# TTEK. Actual Price: 86.12. Predicted Price: 57.41
# TXRH. Actual Price: 58.75. Predicted Price: 55.5
# CG. Actual Price: 27.2. Predicted Price: 61.81
# CAKE. Actual Price: 42.93. Predicted Price: 55.89
# TSCO. Actual Price: 94.72. Predicted Price: 81.73
# UFPI. Actual Price: 49.99. Predicted Price: 49.57
# WDFC. Actual Price: 182.88. Predicted Price: 75.23
# XLNX. Actual Price: 94.96. Predicted Price: 76.58

# %%
get_summary_statistics('TSLA')
# Out:
# {'Market Cap (intraday)': '63.07B',
#  'Enterprise Value': '72.94B',
#  'Trailing P/E': 'N/A',
#  'Forward P/E': '64.92',
#  'PEG Ratio (5 yr expected)': '-4.71',
#  'Price/Sales': '2.58',
#  'Price/Book': '10.43',
#  'Enterprise Value/Revenue': '2.99',
#  'Enterprise Value/EBITDA': '33.48',
#  'Beta (3Y Monthly)': '0.59',
#  '52-Week Change': '0.32%',
#  'S&P500 52-Week Change': '14.27%',
#  '52 Week High': '379.49',
#  '52 Week Low': '176.99',
#  '50-Day Moving Average': '276.28',
#  '200-Day Moving Average': '240.19',
#  'Avg Vol (3 month)': '8M',
#  'Avg Vol (10 day)': '8.79M',
#  'Shares Outstanding': '180.24M',
#  'Float': '142.11M',
#  '% Held by Insiders': '24.98%',
#  '% Held by Institutions': '62.93%',
#  'Shares Short (Oct 31, 2019)': '31.78M',
#  'Short Ratio (Oct 31, 2019)': '3.16',
#  'Short % of Float (Oct 31, 2019)': '23.57%',
#  'Short % of Shares Outstanding (Oct 31, 2019)': '17.63%',
#  'Shares Short (prior month Sep 30, 2019)': '36.06M',
#  'Forward Annual Dividend Rate': 'N/A',
#  'Forward Annual Dividend Yield': 'N/A',
#  'Trailing Annual Dividend Rate': 'N/A',
#  'Trailing Annual Dividend Yield': 'N/A',
#  '5 Year Average Dividend Yield': 'N/A',
#  'Payout Ratio': '0.00%',
#  'Dividend Date': 'N/A',
#  'Ex-Dividend Date': 'N/A',
#  'Last Split Factor (new per old)': 'N/A',
#  'Last Split Date': 'N/A',
#  'Fiscal Year Ends': 'Dec 31, 2018',
#  'Most Recent Quarter': 'Sep 30, 2019',
#  'Profit Margin': '-3.39%',
#  'Operating Margin': '0.62%',
#  'Return on Assets': '0.31%',
#  'Return on Equity': '-10.45%',
#  'Revenue': '24.42B',
#  'Revenue Per Share': '139.52',
#  'Quarterly Revenue Growth': '-7.60%',
#  'Gross Profit': '4.04B',
#  'EBITDA': '2.18B',
#  'Net Income Avi to Common': '-835.09M',
#  'Diluted EPS': '-4.77',
#  'Quarterly Earnings Growth': '-54.00%',
#  'Total Cash': '5.34B',
#  'Total Cash Per Share': '29.61',
#  'Total Debt': '14.64B',
#  'Total Debt/Equity': '195.62',
#  'Current Ratio': '1.08',
#  'Book Value Per Share': '33.56',
#  'Operating Cash Flow': '2.21B',
#  'Levered Free Cash Flow': '993.67M'}

# %%
master_list = ['Market Cap (intraday)',
 'Enterprise Value',
 'Trailing P/E',
 'Forward P/E',
 'PEG Ratio (5 yr expected)',
 'Price/Sales',
 'Price/Book',
 'Enterprise Value/Revenue',
 'Enterprise Value/EBITDA',
 'Beta (3Y Monthly)',
 '52-Week Change',
 'S&P500 52-Week Change',
 '52 Week High',
 '52 Week Low',
 '50-Day Moving Average',
 '200-Day Moving Average',
 'Avg Vol (3 month)',
 'Avg Vol (10 day)',
 'Shares Outstanding',
 'Float',
 '% Held by Insiders',
 '% Held by Institutions',
 'Shares Short (Oct 31, 2019)',
 'Short Ratio (Oct 31, 2019)',
 'Short % of Float (Oct 31, 2019)',
 'Short % of Shares Outstanding (Oct 31, 2019)',
 'Shares Short (prior month Sep 30, 2019)',
 'Forward Annual Dividend Rate',
 'Forward Annual Dividend Yield',
 'Trailing Annual Dividend Rate',
 'Trailing Annual Dividend Yield',
 '5 Year Average Dividend Yield',
 'Payout Ratio',
 'Dividend Date',
 'Ex-Dividend Date',
 'Last Split Factor (new per old)',
 'Last Split Date',
 'Fiscal Year Ends',
 'Most Recent Quarter',
 'Profit Margin',
 'Operating Margin',
 'Return on Assets',
 'Return on Equity',
 'Revenue',
 'Revenue Per Share',
 'Quarterly Revenue Growth',
 'Gross Profit',
 'EBITDA',
 'Net Income Avi to Common',
 'Diluted EPS',
 'Quarterly Earnings Growth',
 'Total Cash',
 'Total Cash Per Share',
 'Total Debt',
 'Total Debt/Equity',
 'Current Ratio',
 'Book Value Per Share',
 'Operating Cash Flow',
 'Levered Free Cash Flow']

# %%
x = [1, np.log(str_to_num('83.7M')), np.log(7.25), np.log(.42), np.log(1.34)]
predicted_price = model.predict(x)
np.e**predicted_price[0]
# Out:
# [1, 18.242749535459705, 1.9810014688665833, -0.8675005677047231, 0.29266961396282004]
# 26.671233206184148

# %%
tickers = set(get_tickers())
print(len(tickers))
import pandas_datareader
nasdaq_tickers = list(pandas_datareader.nasdaq_trader.get_nasdaq_symbols(retry_count=3, timeout=30, pause=None).index)
print(len(nasdaq_tickers))
combined = list(tickers.union(nasdaq_tickers))
print(len(combined))
# Out:
# 2114
# 8915
# 8977

# %%
from market_tests import *
test_market_suite()
# Out:
# Tests for market.py PASSED!
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-1d97643aff40> in <module>
#       1 from market_tests import *
# ----> 2 test_market_suite()
#
# ~\Documents\Projects\Coding Projects\Stock Market\Stock-Market-Analysis\market_tests.py in test_market_suite()
#       7 def test_market_suite():
#       8         test_market()
# ----> 9         test_market_ml()
#      10         test_market_trading()
#      11
#
# ~\Documents\Projects\Coding Projects\Stock Market\Stock-Market-Analysis\market_tests.py in test_market_ml()
#      23 def test_market_ml():
#      24         '''Call test functions for market_ml.py. TODO'''
# ---> 25         test_ml_training_and_prediction()
#      26         print('Tests for market_ml.py PASSED!')
#      27
#
# ~\Documents\Projects\Coding Projects\Stock Market\Stock-Market-Analysis\market_tests.py in test_ml_training_and_prediction()
#      51 def test_ml_training_and_prediction():
#      52         # Make sure training and getting model works
# ---> 53         model = train_and_get_model()
#      54         assert type(model) == xgb.sklearn.XGBRegressor, 'Model outputted by train_and_get_model() is not xgb.sklearn.XGBRegressor'
#      55         pred = predict_price('AAPL', model=model)
#
# ~\Documents\Projects\Coding Projects\Stock Market\Stock-Market-Analysis\market_ml.py in train_and_get_model(filename, verbose, save_to_file, saved_model_name, path)
#      51     Y = financial_data['Price']
#      52     # Get training and testing sets
# ---> 53     X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=123)
#      54     # Hyperparameter tune an XGBoost model
#      55     param_test = {
#
# ~\Anaconda3\envs\tensorflow_env\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(*arrays, **options)
#    2098     n_samples = _num_samples(arrays[0])
#    2099     n_train, n_test = _validate_shuffle_split(n_samples, test_size, train_size,
# -> 2100                                               default_test_size=0.25)
#    2101
#    2102     if shuffle is False:
#
# ~\Anaconda3\envs\tensorflow_env\lib\site-packages\sklearn\model_selection\_split.py in _validate_shuffle_split(n_samples, test_size, train_size, default_test_size)
#    1780             'resulting train set will be empty. Adjust any of the '
#    1781             'aforementioned parameters.'.format(n_samples, test_size,
# -> 1782                                                 train_size)
#    1783         )
#    1784
#
# ValueError: With n_samples=0, test_size=0.3 and train_size=None, the resulting train set will be empty. Adjust any of the aforementioned parameters.
