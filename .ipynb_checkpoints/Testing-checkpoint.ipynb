# %%
from market_tests import *

# %%
# run tests
test_market_suite()
# Out:
# Tests for market.py PASSED!
# C:\Users\kevin\Anaconda3\envs\tensorflow_env\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# Tests for market_ml.py PASSED!
# C:\Users\kevin\Anaconda3\envs\tensorflow_env\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# C:\Users\kevin\Anaconda3\envs\tensorflow_env\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# Tests for market_trading.py PASSED!

# %%
tickers = list(get_tickers())
selection = [tickers[i] for i in range(len(tickers)) if i % 100 == 0] # Test trading
portfolio = {} #get_portfolio_from_csv()
transactions = run_trading_algo(selection, portfolio, time_averaged=True, time_averaged_period=5,
                                min_price_thresh=10, buy_alpha=0.05, short_alpha=0.00001,
                                append_to_csv=True, file_name='transactions_alpha0_05_0_00001.csv')
# Out:
# C:\Users\kevin\Anaconda3\envs\tensorflow_env\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# PIH's price is under the minimun price thresh of 10
# Failed to parse json response for ALQA
# Failed to parse json response for ALQA
# Failed to parse json response for ALQA
# Failed to parse json response for ALQA
# Failed to parse json response for ALQA
# Failed to parse json response for ALQA
# Failed to parse json response for ASNS
# Failed to parse json response for ASNS
# Failed to parse json response for ASNS
# Failed to parse json response for ASNS
# Failed to parse json response for ASNS
# Failed to parse json response for ASNS
# BASI's price is under the minimun price thresh of 10
# CARV's price is under the minimun price thresh of 10
# CMFN's price is under the minimun price thresh of 10
# CUTR is undervalued by 3.28, or 9.7%.
# The predicted value of 100.9349 for EA is too close to actual price of 96.91. We assume correct valuation for the given alpha values.
# The predicted value of 31.225275 for FDEF is too close to actual price of 31.27. We assume correct valuation for the given alpha values.
# The predicted value of 32.813023 for GIII is too close to actual price of 29.32. We assume correct valuation for the given alpha values.
# The predicted value of 17.047749 for HOLI is too close to actual price of 15.56. We assume correct valuation for the given alpha values.
# The predicted value of 14.238179 for IMXI is too close to actual price of 15.14. We assume correct valuation for the given alpha values.
# The predicted value of 18.152979 for LAUR is too close to actual price of 16.82. We assume correct valuation for the given alpha values.
# The predicted value of 151.1571 for MASI is too close to actual price of 141.01. We assume correct valuation for the given alpha values.
# MYGN is undervalued by 4.51, or 19.24%.
# Failed to parse json response for OASM
# Failed to parse json response for OASM
# Failed to parse json response for OASM
# Failed to parse json response for OASM
# Failed to parse json response for OASM
# Failed to parse json response for OASM
# PDCE is undervalued by 2.44, or 9.67%.
# The predicted value of 30.822016 for QGEN is too close to actual price of 31.27. We assume correct valuation for the given alpha values.
# The predicted value of 33.337433 for SABR is too close to actual price of 22.46. We assume correct valuation for the given alpha values.
# SLGL's price is under the minimun price thresh of 10
# The predicted value of 109.59666 for TTWO is too close to actual price of 117.69. We assume correct valuation for the given alpha values.
# TPCO's price is under the minimun price thresh of 10
# The predicted value of 199.72507 for VRTX is too close to actual price of 197.08. We assume correct valuation for the given alpha values.
# Here is a list of transactions that were made:
# [['CUTR', 33.86, 10.0, 'buy'], ['MYGN', 23.45, 19.0, 'buy'], ['PDCE', 25.25, 10.0, 'buy']]

# %%
'''This code takes all tickers and compares the real price to the 1y estimated yahoo finance price'''

tickers = get_tickers()
price_targets = []
for ticker in tickers:
    print(ticker)
    summ = parse(ticker)
    if 'error' in summ.keys():
        continue
    try:
        est = summ['1y Target Est']
        price = str_to_num(summ['Open'])
        price_targets.append([ticker, price, est])
    except:
        print(ticker + ' failed.')

for x in price_targets:
    if est - price > 0 and (est - price) / price > .25:
        print(x)
# Out:
# PIH
# TURN
# FLWS
# FCCY
# SRCE
# VNET
# TWOU
# TPNL
# Failed to parse json response for TPNL
# JOBS
# EGHT
# AAON
# ABEO
# ABIL
# ABMD
# AXAS
# ACIU
# ACIA
# ACTG
# ACHC
# ACAD
# ACST
# AXDX
# XLRN
# ARAY
# ACRX
# ACER
# ACET
# Failed to parse json response for ACET
# AKAO
# Failed to parse json response for AKAO
# ACHV
# ACHN
# ACIW
# ACRS
# ACMR
# ACOR
# ATVI
# ADMS
# ADMP
# ADAP
# ADUS
# AEY
# IOTS
# ADIL
# ADMA
# ADBE
# ADOM
# ADTN
# ADRO
# ADES
# AEIS
# AMD
# ADXS
# ADVM
# AEGN
# AGLE
# AEHR
# AMTX
# AERI
# AVAV
# ARPO
# AEZS
# AEMD
# GNMX
# AFMD
# AGEN
# AGRX
# AGYS
# AGIO
# AGNC
# AGFS
# ALRN
# AIMT
# ATSG
# AIRG
# AMCN
# Failed to parse json response for AMCN
# AKAM
# AKTX
# AKCA
# AKBA
# AKER
# AKRX
# AKTS
# ALRM
# ALSK
# ALBO
# ABDC
# ALDR
# Failed to parse json response for ALDR
# ALDX
# ALXN
# ALCO
# ALGN
# ALIM
# ALYA
# ALKS
# ALLK
# ABTX
# ALGT
# ALNA
# ARLP
# AHPI
# AMOT
# ALQA
# Failed to parse json response for ALQA
# ALLT
# MDRX
# ALNY
# AOSL
# ATEC
# ALPN
# AMR
# Failed to parse json response for AMR
# AABA
# Failed to parse json response for AABA
# ALTR
# ALT
# ASPS
# AIMC
# AMAG
# AMAL
# AMRN
# AMRK
# AMBC
# AMBA
# AMCX
# DOX
# AMED
# UHAL
# AMRH
# ATAX
# AAL
# AETI
# Failed to parse json response for AETI
# AFIN
# AMNB
# ANAT
# AOBC
# APEI
# AMRB
# AMSWA
# AMSC
# AMWD
# CRMT
# ABCB
# AMSF
# ASRV
# AMGN
# FOLD
# AMKR
# AMPH
# ASYS
# AMRS
# ADI
# ANAB
# AVXL
# ANGI
# ANGO
# ANIP
# ANIK
# ANIX
# ANSS
# ATRS
# APLS
# APOG
# APEN
# AINV
# AMEH
# APPF
# APPN
# AAPL
# ARCI
# Failed to parse json response for ARCI
# APDN
# AGTC
# AMAT
# AAOI
# AREX
# APVO
# APTX
# APTO
# AQMS
# AQB
# AQST
# AQXP
# Failed to parse json response for AQXP
# PETX
# Failed to parse json response for PETX
# ARAV
# ABUS
# ARCW
# ABIO
# RKDA
# ARCB
# ACGL
# FUV
# ARCE
# ARCT
# ARDX
# ARNA
# ARCC
# ARGX
# ARDS
# ARKR
# ARTX
# ARQL
# ARRY
# Failed to parse json response for ARRY
# ARRS
# Failed to parse json response for ARRS
# AROW
# ARWR
# ASNS
# Failed to parse json response for ASNS
# ARTNA
# ARTW
# ARVN
# ASNA
# ASND
# ASCMA
# Failed to parse json response for ASCMA
# ASLN
# ASML
# ASPU
# AZPN
# ASMB
# ASRT
# ASFI
# ASTE
# ATRO
# ALOT
# ASTC
# ASUR
# ASV
# Failed to parse json response for ASV
# ATAI
# Failed to parse json response for ATAI
# ATRA
# ATNX
# ATHX
# ACBI
# AY
# ATLC
# AAWW
# AFH
# TEAM
# ATNI
# ATOM
# ATOS
# ATRC
# ATRI
# ATIS
# ATTU
# Failed to parse json response for ATTU
# LIFE
# BOLD
# AUDC
# AEYE
# AUPH
# EARS
# JG
# ADSK
# AUTL
# ADP
# AUTO
# AVDL
# ATXI
# AVEO
# CDMO
# AVID
# AVGR
# CAR
# AVT
# AVRO
# AWRE
# ACLS
# AXGN
# AAXN
# AXNX
# AXSM
# AXTI
# AYTU
# AZRX
# BCOM
# RILY
# BIDU
# BCPC
# BLDP
# BANF
# BAND
# BFC
# BOCH
# BMRC
# OZK
# BSVN
# BFIN
# BWFG
# BANR
# BZUN
# BBSI
# BSET
# BCML
# BCBP
# BECN
# BBGI
# BBBY
# BGNE
# BELFB
# BLPH
# BLCM
# BNFT
# BNTC
# BRY
# BYSI
# BGCP
# BGFV
# BILI
# BASI
# ORPN
# Failed to parse json response for ORPN
# BIOC
# BCRX
# BDSI
# BFRA
# BIIB
# BHTG
# BKYI
# BIOL
# BLFS
# BLRX
# BMRN
# BMRA
# BNGO
# BVXV
# BPTH
# BIOS
# BSGM
# BSTC
# TECH
# BEAT
# BTAI
# BJRI
# BLKB
# BL
# BKCC
# TCPC
# BLNK
# BLMN
# BCOR
# BLBD
# BHBK
# Failed to parse json response for BHBK
# BLUE
# BKEP
# BPMC
# BMCH
# WIFI
# BOKF
# BNSO
# BRQS
# BPFH
# EPAY
# BOXL
# BCLI
# BDGE
# BWB
# BRID
# BCOV
# BHF
# AVGO
# BVSN
# BWEN
# BPY
# BRKL
# BRKS
# BRKR
# BMTC
# BSQR
# BLDR
# BFST
# CHRW
# CCMP
# CDNS
# CDZI
# CZR
# CSTE
# CAMP
# CVGW
# CALA
# CALM
# CLMT
# CLXT
# CAC
# CAMT
# CSIQ
# CGIX
# CPHC
# CBNK
# CCBG
# CPLP
# CSWC
# CPTA
# CFFN
# CAPR
# CSTR
# CPST
# CARA
# CBLK
# Failed to parse json response for CBLK
# CARB
# CSII
# CDLX
# CATM
# CDNA
# CECO
# CTRE
# CARG
# CARO
# CRZO
# TAST
# CARV
# CASM
# Failed to parse json response for CASM
# CASA
# CWST
# CASY
# CASI
# CATB
# CBIO
# CPRX
# CATS
# CATY
# CVCO
# CBFV
# CBTX
# CDK
# CDW
# CECE
# CELC
# CELG
# CLDX
# APOP
# CLRB
# CLLS
# CBMG
# CLSN
# CELH
# CYAD
# CETX
# CDEV
# CSFL
# CETV
# CFBK
# Failed to parse json response for CFBK
# CENT
# CENTA
# CVCY
# CTRC
# CENX
# CNBKA
# CNTY
# CRNT
# CERC
# CERN
# CERS
# KOOL
# Failed to parse json response for KOOL
# CEVA
# CSBR
# CYOU
# BURG
# CTHR
# GTLS
# CHTR
# CHKP
# CHEK
# CKPT
# CEMI
# CHFC
# Failed to parse json response for CHFC
# CCXI
# CHMG
# CHKE
# Failed to parse json response for CHKE
# CHFS
# CHMA
# CSSE
# PLCE
# CMRX
# CADC
# Failed to parse json response for CADC
# CAAS
# CBPO
# JRJC
# CJJD
# CNTF
# Failed to parse json response for CNTF
# CCIH
# Failed to parse json response for CCIH
# CNET
# IMOS
# CDXC
# CHDN
# CHUY
# CDTX
# CMCT
# CMPR
# CINF
# CIDM
# CTAS
# CRUS
# CSCO
# CTRN
# CTXR
# CZNC
# CZWI
# CIZN
# CTXS
# CHCO
# CIVB
# CLAR
# CLNE
# CLFD
# CLRO
# CLSD
# CMTA
# Failed to parse json response for CMTA
# CBLI
# CLVS
# CMFN
# Failed to parse json response for CMFN
# CME
# CCNE
# CCB
# COKE
# COCP
# CODA
# CDXS
# JVA
# CCOI
# CGNX
# CTSH
# COHR
# CHRS
# COHU
# CLCT
# COLL
# CIGI
# CLGN
# CBAN
# COLB
# CLBK
# COLM
# CMCO
# CMCSA
# CCNI
# Failed to parse json response for CCNI
# CBSH
# CVGI
# COMM
# JCS
# ESXB
# CTBI
# CVLT
# CGEN
# CPSI
# CTG
# SCOR
# CHCI
# CMTL
# CNAT
# CNCE
# CDOR
# CFMS
# CNFR
# CNMD
# CTWS
# Failed to parse json response for CTWS
# CNOB
# CONN
# CNSL
# CWCO
# CNST
# ROAD
# CPSS
# CFRX
# CTRV
# Failed to parse json response for CTRV
# CTRL
# Failed to parse json response for CTRL
# AWSM
# CPRT
# CRBP
# CORT
# CORE
# CSOD
# CORV
# CRVL
# CRVS
# CSGP
# COST
# CPAH
# ICBK
# COUP
# CVTI
# COWN
# PMTS
# CRAI
# CBRL
# BREW
# CRAY
# Failed to parse json response for CRAY
# CACC
# CREE
# CRESY
# CRNX
# CRSP
# CRTO
# CROX
# CCRN
# CRWS
# CYRX
# CSGS
# CCLP
# CSPI
# CSWI
# CSX
# CTIC
# CTIB
# CTRP
# CUE
# CUI
# CPIX
# CMLS
# CRIS
# CUTR
# CVBF
# CVV
# CYAN
# CYBR
# CYBE
# CYCC
# CBAY
# CY
# CYRN
# CONE
# CYTK
# CTMX
# CYTX
# Failed to parse json response for CYTX
# CTSO
# CYTR
# DAKT
# DARE
# DRIO
# DZSI
# DSKE
# DAIO
# PLAY
# DTEA
# DWSN
# DBVT
# DCPH
# DFRG
# Failed to parse json response for DFRG
# TACO
# DMPI
# DNLI
# DENN
# XRAY
# DERM
# DEST
# Failed to parse json response for DEST
# DXLG
# DSWL
# DTRM
# Failed to parse json response for DTRM
# DXCM
# FANG
# DCIX
# DRNA
# DFFN
# DGII
# DMRC
# DRAD
# DGLY
# APPS
# DCOM
# DIOD
# DISCA
# DISCB
# DISCK
# DISH
# DVCR
# SAUC
# DLHC
# BOOM
# DNBF
# DOCU
# DLTR
# DLPN
# DOMO
# DGICA
# DORM
# DOVA
# DBX
# DCAR
# DSPG
# DLTH
# DNKN
# DRRX
# DXPE
# DYSL
# DYNT
# DVAX
# ETFC
# SSP
# EBMT
# EGBN
# EGRX
# EWBC
# EAST
# EBAY
# EBIX
# ECHO
# SATS
# ESES
# EDAP
# EDGE
# Failed to parse json response for EDGE
# EDIT
# EGAN
# EHTH
# EIDX
# EIGR
# EKSO
# LOCO
# ESLT
# ERI
# ECOR
# EA
# EFII
# Failed to parse json response for EFII
# ELOX
# EMCI
# Failed to parse json response for EMCI
# EMKR
# EMMS
# NYNY
# ENTA
# ECPG
# WIRE
# ENDP
# ELGX
# EIGI
# WATT
# EFOI
# ERII
# ENPH
# ESGR
# ENFC
# ENTG
# ENTX
# EFSC
# EPZM
# PLUS
# EQ
# EQIX
# EQBK
# ERIC
# ERIE
# ERYP
# ESCA
# ESPR
# ESQ
# ESSA
# ESTA
# ESTR
# ETSY
# EDRY
# EEFT
# ESEA
# EVLO
# EVBG
# EVER
# MRAM
# EVLV
# Failed to parse json response for EVLV
# EVOP
# EVFM
# EVGN
# EVOK
# EOLS
# EVOL
# EXAS
# XELA
# EXEL
# EXFO
# EXLS
# EXPI
# EXPE
# EXPD
# EXPO
# STAY
# XOG
# EXTR
# EYEG
# EYEN
# EYPT
# EZPW
# FFIV
# FB
# FLMN
# DAVE
# Failed to parse json response for DAVE
# FANH
# Failed to parse json response for FANH
# FARM
# FMAO
# FMNB
# FARO
# FAST
# FAT
# FATE
# FBSS
# FNHC
# FENC
# GSM
# FCSC
# FGEN
# LION
# Failed to parse json response for LION
# FDUS
# FRGI
# FITB
# FISI
# FNSR
# Failed to parse json response for FNSR
# FNJN
# FEYE
# FBNC
# FRBA
# BUSE
# FBIZ
# FCBP
# FCBC
# FCCO
# FDEF
# FFBC
# FFIN
# THFF
# FFNW
# FFWM
# FGBI
# FHB
# INBK
# FIBK
# FRME
# FMBH
# FMBI
# FSFG
# FSLR
# FUNC
# MYFW
# FCFS
# SVVC
# FSV
# FISV
# FIVE
# FPRX
# FVE
# FIVN
# FLEX
# FLKS
# Failed to parse json response for FLKS
# FLXN
# FLXS
# FLIR
# FLNT
# FLDM
# FFIC
# FOMX
# FOCS
# FSCT
# FRSX
# FORM
# FORR
# FRTA
# FTNT
# FBIO
# FTSV
# FWRD
# FORD
# FWP
# FOSL
# FOXF
# FRAN
# FELE
# FRED
# Failed to parse json response for FRED
# RAIL
# FEIM
# FRPT
# FTDR
# FTEO
# FTR
# FRPH
# FSBW
# FTD
# Failed to parse json response for FTD
# FTEK
# FCEL
# FLGT
# FLL
# FULT
# FNKO
# FSNN
# Failed to parse json response for FSNN
# FTFT
# FFHL
# FVCB
# WILC
# GTHX
# GAIA
# GLPG
# GALT
# GLMD
# GMDA
# GLPI
# GPIC
# Failed to parse json response for GPIC
# GRMN
# GARS
# GLIBA
# GDS
# GEMP
# GENC
# GFN
# GENE
# GNUS
# GNMK
# GNCA
# GHDX
# GNPX
# GNTX
# THRM
# GEOS
# GABC
# GERN
# GEVO
# ROCK
# GIGM
# GIII
# GILT
# GILD
# GBCI
# GLAD
# GOOD
# GAIN
# LAND
# GBT
# ENT
# GBLI
# SELF
# GWRS
# GLBS
# GLUU
# GLYC
# GOGO
# GLNG
# GMLP
# GDEN
# GOGL
# GBDC
# GTIM
# GSHD
# GPRO
# LOPE
# GRVY
# GECC
# GEC
# GLDD
# GSBC
# GRBK
# GPP
# GPRE
# GLRE
# GRNQ
# GSKY
# GSUM
# GRFS
# GRIN
# GRTS
# GRPN
# OMAB
# GGAL
# Failed to parse json response for GGAL
# GVP
# GSIT
# GSVC
# Failed to parse json response for GSVC
# GTXI
# Failed to parse json response for GTXI
# GNTY
# GFED
# GH
# GIFI
# GURE
# GPOR
# GWPH
# GWGH
# HEES
# HNRG
# HALL
# HALO
# HLNE
# HWC
# HAFC
# HONE
# HLIT
# HBIO
# HCAP
# HAS
# HA
# HWKN
# HYAC
# Failed to parse json response for HYAC
# HAYN
# HDS
# HIIQ
# HCSG
# HQY
# HSTM
# HTLD
# HTLF
# HTBX
# HSII
# HELE
# HMNY
# HSDT
# HMTV
# HNNA
# HSIC
# HTBK
# HFWA
# HCCI
# MLHR
# HRTX
# HSKA
# HX
# HIBB
# HPJ
# Failed to parse json response for HPJ
# HIMX
# HSGX
# Failed to parse json response for HSGX
# HMNF
# HMSY
# HOLI
# HOLX
# HBCP
# HOMB
# HMST
# HTBI
# FIXX
# HOFT
# HOPE
# HFBC
# Failed to parse json response for HFBC
# HBNC
# HZNP
# HRZN
# HPT
# Failed to parse json response for HPT
# TWNK
# HMHC
# HWCC
# HBMD
# HTGM
# HTHT
# HUBG
# HDSN
# HBAN
# HURC
# HURN
# HCM
# HBP
# HYGS
# Failed to parse json response for HYGS
# HYRE
# IDSY
# Failed to parse json response for IDSY
# IIIV
# IAC
# IBKC
# ICAD
# IEP
# ICFI
# ICHR
# ICLK
# ICLR
# ICON
# ICUI
# IPWR
# INVE
# IDRA
# IDXX
# IESC
# INFO
# IIVI
# ILMN
# ISNS
# IMMR
# IMDZ
# Failed to parse json response for IMDZ
# IMGN
# IMMU
# IMMP
# PI
# INCY
# INDB
# IBCP
# IBTX
# ILPT
# IDSA
# Failed to parse json response for IDSA
# INFN
# INFI
# IFRX
# III
# Failed to parse json response for III
# IEA
# INWK
# INOD
# IPHS
# IOSP
# INNT
# ISSC
# INVA
# INGN
# INOV
# INO
# INPX
# INSG
# NSIT
# ISIG
# INSM
# INSE
# IIIN
# PODD
# INSY
# Failed to parse json response for INSY
# NTEC
# IART
# IDTI
# Failed to parse json response for IDTI
# INTC
# NTLA
# IPCI
# Failed to parse json response for IPCI
# IPAR
# ICPT
# IDCC
# TILE
# LINK
# IMI
# Failed to parse json response for IMI
# INAP
# IBOC
# IMXI
# ISCA
# Failed to parse json response for ISCA
# IGLD
# IIJI
# Failed to parse json response for IIJI
# IDXG
# XENT
# IVAC
# INTL
# ITCI
# XON
# IIN
# INTU
# ISRG
# ISTR
# ISBC
# ITIC
# NVIV
# IONS
# IOVA
# IPGP
# IPIC
# Failed to parse json response for IPIC
# IQ
# IRMD
# IRTC
# IRIX
# IRDM
# IRBT
# IRWD
# IRCP
# ISRL
# Failed to parse json response for ISRL
# ITI
# ITRM
# ITRI
# ITRN
# IZEA
# JJSF
# JBHT
# JCOM
# JKHY
# JACK
# JAGX
# JAKK
# JRVR
# JASN
# JAZZ
# JD
# JRSH
# JBLU
# JBSS
# JOUT
# JNCE
# KALU
# KALA
# KALV
# KMDA
# KNDI
# KPTI
# KZIA
# KCAP
# Failed to parse json response for KCAP
# KRNY
# KELYA
# KMPH
# KEQU
# KTCC
# KZR
# KFRC
# KE
# KBAL
# KIN
# KINS
# KNSA
# KNSL
# KIRK
# KTOV
# KLAC
# KLXE
# KOD
# KONA
# Failed to parse json response for KONA
# KOPN
# KRNT
# KTOS
# KRYS
# KLIC
# KURA
# KVHI
# FSTR
# LJPC
# LBAI
# LKFN
# LAKE
# LRCX
# LAMR
# LANC
# LNDC
# LMRK
# LE
# LSTR
# LNTH
# LTRX
# LSCC
# LAUR
# LAWS
# LAZY
# LCNB
# LPTX
# LGCY
# Failed to parse json response for LGCY
# LTXB
# Failed to parse json response for LTXB
# LMAT
# TREE
# LEVL
# LXRX
# LX
# LGIH
# LHCG
# LBRDA
# LBRDK
# LEXEA
# Failed to parse json response for LEXEA
# LBTYA
# LBTYK
# LILA
# LILAK
# BATRA
# BATRK
# BATRK failed.
# FWONA
# FWONK
# LSXMA
# LSXMK
# LTRPA
# LCUT
# LFVN
# LWAY
# LGND
# LTBR
# LPTH
# LLEX
# LMB
# LLNW
# LMST
# LMNR
# LINC
# LECO
# LIND
# LPCN
# YVR
# LQDA
# LQDT
# LFUS
# LIVN
# LOB
# LIVE
# LPSN
# LIVX
# LKQ
# LOGC
# LOGI
# LOGM
# LONE
# LORL
# LPLA
# LRAD
# Failed to parse json response for LRAD
# LYTS
# LULU
# LITE
# LMNX
# LUNA
# LBC
# MBTF
# Failed to parse json response for MBTF
# MCBC
# MFNC
# MTSI
# MGNX
# MDGL
# MGLN
# MGTA
# MGIC
# MGYR
# MHLD
# MMYT
# MBUU
# MLVF
# MAMS
# Failed to parse json response for MAMS
# TUSK
# MANH
# LOAN
# MNTX
# MTEX
# Failed to parse json response for MTEX
# MNKD
# MANT
# MARA
# MCHX
# MRIN
# MRNS
# MRKR
# MKTX
# MRLN
# MAR
# MBII
# MRTN
# MMLP
# MRVL
# MASI
# MTCH
# MTLS
# MTRX
# MAT
# MATW
# MXIM
# MXWL
# Failed to parse json response for MXWL
# MBFI
# Failed to parse json response for MBFI
# MCFT
# MGRC
# MDCA
# MFIN
# MTBC
# MNOV
# MDSO
# Failed to parse json response for MDSO
# MDWD
# MEDP
# MEIP
# MGTX
# MLCO
# MLNT
# MLNX
# MELR
# MNLO
# MELI
# AMTB
# MBWM
# MERC
# MBIN
# MRCY
# EBSB
# VIVO
# MRBK
# MMSI
# MACK
# MRSN
# MRUS
# MESA
# MLAB
# MESO
# CASH
# MEOH
# MGEE
# MGPI
# MBOT
# MCHP
# MU
# Failed to parse json response for MU
# MSFT
# MSTR
# MVIS
# MICT
# Failed to parse json response for MICT
# MCEP
# MBCN
# MSEX
# MSBI
# MOFG
# MIME
# MDXG
# NERV
# MGEN
# MRTX
# MSON
# MIND
# MITK
# MMAC
# MINI
# MOBL
# MTEM
# MBRX
# MNTA
# MOMO
# MKGI
# MCRI
# MDLZ
# MGI
# MDB
# MPWR
# TYPE
# Failed to parse json response for TYPE
# MNRO
# MRCC
# MNST
# MORN
# MOSY
# MTFB
# MPAA
# MOTS
# MPVD
# COOP
# MTSC
# LABL
# Failed to parse json response for LABL
# MBIO
# MFSF
# MVBF
# MYSZ
# MYL
# MYND
# Failed to parse json response for MYND
# MYOK
# MYOS
# MYRG
# MYGN
# NBRV
# NNDM
# NANO
# Failed to parse json response for NANO
# NSTG
# NAOV
# NH
# NK
# NSSC
# NDAQ
# NTRA
# NAUH
# NKSH
# FIZZ
# NCMI
# NCOM
# Failed to parse json response for NCOM
# NESR
# NGHC
# NATI
# EYE
# NHTC
# NATR
# BABY
# Failed to parse json response for BABY
# NAVI
# NBTB
# NCSM
# NKTR
# NEOG
# NEO
# NTGN
# NEON
# NEOS
# NVCN
# NEPT
# Failed to parse json response for NEPT
# UEPS
# NETE
# NTAP
# NTES
# Failed to parse json response for NTES
# NFLX
# NTGR
# NTCT
# NTWK
# CUR
# Failed to parse json response for CUR
# NBIX
# NURO
# STIM
# NTRP
# NBEV
# NYMT
# NLNK
# NMRK
# NWSA
# NEWT
# NXEO
# Failed to parse json response for NXEO
# NXST
# NEXT
# NXGN
# EGOV
# NICE
# NICK
# NCBS
# NITE
# Failed to parse json response for NITE
# NIHD
# NIU
# LASR
# NMIH
# NNBR
# NDSN
# NBN
# NTIC
# NTRS
# NFBK
# NRIM
# NWBI
# NWPX
# NCLH
# NWFL
# NVMI
# NOVN
# NOVT
# NVAX
# NVLN
# Failed to parse json response for NVLN
# NVCR
# NVMM
# Failed to parse json response for NVMM
# NVUS
# NUAN
# NCNA
# NTNX
# NTRI
# Failed to parse json response for NTRI
# NUVA
# NVTR
# NVEE
# NVEC
# NVDA
# NXPI
# NXTD
# NYMX
# Failed to parse json response for NYMX
# OIIM
# OCSL
# OCSI
# OASM
# Failed to parse json response for OASM
# OBLN
# OBSV
# OPTT
# OCFC
# OCUL
# ODT
# OMEX
# ODP
# OFS
# OHAI
# OHRP
# Failed to parse json response for OHRP
# OKTA
# ODFL
# OLBK
# ONB
# OSBC
# OLLI
# ZEUS
# OMER
# OMCL
# ON
# OTIV
# Failed to parse json response for OTIV
# OMED
# Failed to parse json response for OMED
# ONTX
# ONCS
# OHGI
# Failed to parse json response for OHGI
# OSS
# OSPN
# OPBK
# OTEX
# OPRA
# OPGN
# OPHT
# Failed to parse json response for OPHT
# OPNT
# OPK
# OBAS
# OPRX
# OPTN
# OPB
# ORMP
# OSUR
# ORBC
# ORTX
# ORLY
# ONVO
# ORGS
# SEED
# OBNK
# OESX
# ORIT
# ORRF
# OFIX
# KIDS
# OSIS
# OSIR
# Failed to parse json response for OSIR
# OSMT
# OTIC
# OTTR
# OSTK
# OVID
# OXBR
# OXFD
# OXLC
# OXSQ
# PTSI
# PCAR
# PACB
# PCB
# PEIX
# PMBC
# PPBI
# PCRX
# PACW
# PTIE
# Failed to parse json response for PTIE
# PAAS
# PANL
# PZZA
# FRSH
# Failed to parse json response for FRSH
# PRTK
# TEUM
# PCYG
# PKBK
# PKOH
# PTNR
# PATK
# PNBK
# PATI
# PEGI
# PDCO
# PTEN
# PAVM
# PAYX
# PCTY
# PYDS
# Failed to parse json response for PYDS
# PYPL
# CNXN
# PCMI
# Failed to parse json response for PCMI
# PCSB
# PCTI
# PDCE
# PDFS
# PDLI
# PDLB
# PDVW
# Failed to parse json response for PDVW
# SKIS
# Failed to parse json response for SKIS
# PGC
# PEGA
# PENN
# PVAC
# PFLT
# PNNT
# WRLS
# Failed to parse json response for WRLS
# PEBO
# PEBK
# PBCT
# PUB
# PEP
# PRCP
# PRFT
# PFMT
# PESI
# PPIH
# PTX
# Failed to parse json response for PTX
# PGLC
# Failed to parse json response for PGLC
# PETQ
# PETS
# PFSW
# PGTI
# PHAS
# PAHC
# PLAB
# PICO
# PIRS
# PPC
# PDD
# PME
# PNFP
# PPSI
# PXLW
# PLYA
# PLXS
# PLUG
# PS
# PSTI
# PLXP
# PNTR
# Failed to parse json response for PNTR
# PCOM
# POLA
# PTE
# POOL
# POPE
# BPOP
# PTLA
# PBPB
# PCH
# POWL
# POWI
# PRAA
# PRAH
# PRAN
# Failed to parse json response for PRAN
# PRPO
# PFBC
# PFBI
# PINC
# LENS
# Failed to parse json response for LENS
# PSDO
# PRGX
# PSMT
# PRMW
# PRIM
# PFG
# PRNB
# PDEX
# IPDN
# PFIE
# PGNX
# PRGS
# PFPT
# PRPH
# PRQR
# PSEC
# PTGX
# PTVCB
# PRTO
# PTI
# PRTA
# PRVB
# PROV
# PMD
# PTC
# PTCT
# PULM
# PBYI
# PCYO
# PRPL
# PXS
# QADA
# QADB
# QCRH
# QGEN
# QIWI
# QRVO
# QCOM
# QBAK
# QLYS
# QTNA
# Failed to parse json response for QTNA
# QTRX
# QTRH
# QRHC
# QUIK
# QDEL
# QNST
# QUMU
# QTNT
# QRTEA
# QTT
# RRD
# RCM
# RARX
# RADA
# RDCM
# RDUS
# RDNT
# RDWR
# METC
# RMBS
# GOLD
# RNDB
# RPD
# RAVE
# RAVN
# RBB
# ROLL
# RICK
# RCMT
# RDI
# RGSE
# RNWK
# RP
# RETA
# RCON
# REPH
# RRGB
# RRR
# RDFN
# RDHL
# REGN
# RGNX
# RGLS
# RBNC
# RELV
# MARK
# RNST
# REGI
# RCII
# RGEN
# REPL
# RBCAA
# RBCAA failed.
# FRBK
# REFR
# RSLS
# RESN
# RECN
# HAIR
# TORC
# ROIC
# RTRX
# RVNC
# RVLT
# RWLK
# RGCO
# RYTM
# RBBN
# RIBT
# RIGL
# RNET
# RMNI
# RIOT
# REDU
# RTTR
# RVSB
# RCKT
# RMTI
# RCKY
# RMCF
# ROKU
# ROSE
# ROST
# RGLD
# RTIX
# RBCN
# RUBY
# RMBL
# RUSHA
# RUTH
# RYAAY
# STBA
# SANW
# SBRA
# SABR
# SAEX
# SAFT
# SGA
# Failed to parse json response for SGA
# SAGE
# SAIA
# SALM
# SAL
# SAFM
# SASR
# SGMO
# SANM
# SPNS
# SRPT
# SVRA
# SBFG
# SBBX
# SBAC
# SCSC
# SCHN
# SRRK
# SCHL
# SGMS
# SCPH
# SCYX
# SEAC
# SBCF
# STX
# SHIP
# SPNE
# SGEN
# EYES
# SECO
# SCWX
# SEIC
# SLCT
# SIC
# SELB
# SIGI
# SLS
# LEDS
# SMTC
# SNES
# SNH
# SRTS
# SQBG
# MCRB
# SREV
# SFBS
# SESN
# SGBX
# SMED
# SHSP
# SHEN
# SHLO
# SCVL
# SHBI
# SSTI
# SFLY
# Failed to parse json response for SFLY
# SIBN
# SNNA
# SIEN
# BSRR
# SRRA
# SWIR
# SIFY
# SIGA
# SGLB
# SBNY
# SLGN
# SILC
# SLAB
# SIMO
# SAMG
# SSNT
# SFNC
# SLP
# SINA
# SBGI
# SINO
# SVA
# SIRI
# SITO
# SKYS
# SKYW
# SWKS
# SNBR
# SLM
# SGH
# SND
# SMBK
# SMSI
# SMTX
# SRAX
# SCKT
# SOHU
# SLRC
# SUNS
# SEDG
# SLNO
# SLGL
# SLDB
# SNGX
# SOFO
# SNOA
# SONO
# SPHS
# SORL
# SRNE
# SOHO
# SSB
# SFST
# SMBC
# SONA
# SBSI
# SP
# SPKE
# ONCE
# SPTN
# SPPI
# SPRO
# ANY
# SPEX
# SAVE
# STXB
# SPLK
# SPOK
# SPWH
# SBPH
# SFM
# SPSC
# SSNC
# SSRM
# STAA
# STAF
# STMP
# SBLK
# SBUX
# STFC
# GASS
# STCN
# STLD
# SMRT
# SBOT
# Failed to parse json response for SBOT
# STML
# SRCL
# SBT
# STRL
# SHOO
# SFIX
# SYBT
# BANX
# STNE
# SSKN
# SSYS
# STRA
# STRT
# STRM
# SBBP
# SUMR
# SMMF
# SSBI
# SMMT
# WISA
# SNHY
# Failed to parse json response for SNHY
# SNDE
# SNSS
# STKL
# SPWR
# RUN
# SUNW
# SPCB
# SCON
# SGC
# SUPN
# SPRT
# SURF
# SGRY
# SRDX
# STRO
# SIVB
# SVMK
# SYKE
# SYMC
# SYNC
# SYNL
# SYNA
# SNCR
# SNDX
# SYNH
# SGYP
# Failed to parse json response for SGYP
# SYBX
# SNPS
# SES
# SYPR
# SYRS
# TROW
# TTOO
# TRHC
# TCMD
# TTWO
# TLND
# TNDM
# TLF
# TAOP
# TEDU
# CGBD
# AMTD
# TECD
# TTGT
# TGLS
# TGEN
# TNAV
# TLGT
# TELL
# TENB
# TENX
# TERP
# TBNK
# TSLA
# TESS
# TTEK
# TTPH
# TCBI
# TXN
# TXRH
# TFSL
# TGTX
# ANDE
# TBBK
# BPRN
# CG
# CAKE
# CHEF
# TCFC
# DSGX
# DXYN
# ENSG
# XONE
# FBMS
# FLIC
# GT
# HABT
# HCKT
# HAIN
# CUBA
# JYNT
# KEYW
# Failed to parse json response for KEYW
# KHC
# LOVE
# MSG
# MDCO
# MEET
# MIK
# MIDD
# NAVG
# Failed to parse json response for NAVG
# STKS
# PRSC
# RMR
# SMPL
# TSG
# TTD
# ULTI
# Failed to parse json response for ULTI
# YORW
# NCTY
# Failed to parse json response for NCTY
# TXMD
# TRPX
# TBPH
# TST
# Failed to parse json response for TST
# TCRD
# TTS
# TLRY
# TSBK
# TITN
# TTNP
# TVTY
# TIVO
# TLSA
# TMUS
# TOCA
# TNXP
# TISA
# Failed to parse json response for TISA
# TOPS
# TRCH
# TRMD
# TSEM
# CLUB
# TOWN
# TPIC
# TCON
# TSCO
# TWMC
# TACT
# TRNS
# TGA
# TBIO
# TA
# TZOO
# TRMT
# TRVN
# TPCO
# TCDA
# TCBK
# TRIL
# TRS
# TRMB
# TRIB
# TRIP
# TSC
# TBK
# TRVG
# TROV
# TRUE
# THST
# TRUP
# TRST
# TRMK
# TTEC
# TTMI
# TCX
# TUES
# TOUR
# HEAR
# FOX
# FOXA
# TWIN
# TWST
# TRCB
# TYME
# USCR
# PRTS
# USEG
# USAU
# UBNT
# Failed to parse json response for UBNT
# UFPT
# ULTA
# UCTT
# UPL
# Failed to parse json response for UPL
# RARE
# ULBI
# Failed to parse json response for ULBI
# UMBF
# UMPQ
# UBSH
# Failed to parse json response for UBSH
# QURE
# UBCP
# UBSI
# UCBI
# UCFC
# UAL
# UBNK
# UFCS
# UIHC
# UNFI
# UBFO
# UTHR
# UNIT
# UNTY
# UBX
# OLED
# UEIC
# UFPI
# ULH
# USAP
# UVSP
# UMRX
# UPLD
# UPWK
# UONEK
# URBN
# URGN
# UROV
# ECOL
# USAT
# USAK
# UTSI
# UXIN
# VCNX
# VLRX
# VLY
# VNDA
# VREX
# VRNS
# VBLT
# VXRT
# VBIV
# VECO
# VEON
# VRA
# VCYT
# VSTM
# VCEL
# VRNT
# VRSN
# VRSK
# VBTX
# VERI
# VRML
# VRNA
# VRCA
# VTNR
# VRTX
# VERU
# VIA
# VIAB
# VSAT
# VIAV
# VICL
# Failed to parse json response for VICL
# VICR
# VCTR
# VRAY
# VKTX
# VIOT
# VNOM
# VIRC
# VTSI
# VIRT
# VRTS
# VRTU
# VTGN
# VC
# VTL
# Failed to parse json response for VTL
# VIVE
# VVUS
# VOD
# VOXX
# VYGR
# VTVT
# VUZI
# WBA
# WAFD
# WASH
# WSBF
# WVE
# WSTG
# WDFC
# WB
# WTW
# Failed to parse json response for WTW
# WEN
# WERN
# WSBC
# WTBA
# WABC
# WSTL
# WDC
# WNEB
# WPRT
# WWR
# WEYS
# WHLR
# WHF
# WHLM
# WLDN
# WLFC
# WLTW
# WSC
# WIN
# Failed to parse json response for WIN
# WING
# WTFC
# WETF
# WIX
# WWD
# WDAY
# WKHS
# WRLD
# WMGI
# WSFS
# WYNN
# XBIT
# XELB
# XEL
# XNCR
# XBIO
# XENE
# XERS
# XGTI
# Failed to parse json response for XGTI
# XLNX
# XOMA
# XPER
# XSPA
# XTLB
# XNET
# YNDX
# YTRA
# ['PIH', 4.76, 7.0]
# ['TURN', 2.23, 4.0]
# ['FLWS', 13.26, 25.0]
# ['FCCY', 19.28, 21.5]
# ['SRCE', 52.33, 50.67]
# ['VNET', 8.16, 17.26]
# ['TWOU', 20.74, 26.6]
# ['JOBS', 79.16, 69.62]
# ['EGHT', 20.06, 25.96]
# ['AAON', 49.99, 40.0]
# ['ABEO', 2.63, 10.2]
# ['ABIL', 0.46, 1.3]
# ['ABMD', 216.07, 248.33]
# ['AXAS', 0.2799, 1.81]
# ['ACIU', 5.49, 10.36]
# ['ACIA', 65.95, 68.78]
# ['ACTG', 2.49, 6.5]
# ['ACHC', 30.56, 35.57]
# ['ACAD', 40.9, 53.64]
# ['ACST', 2.01, 2.52]
# ['AXDX', 15.94, 17.67]
# ['XLRN', 40.7, 58.42]
# ['ARAY', 2.88, 6.88]
# ['ACRX', 2.04, 7.0]
# ['ACER', 3.24, 8.0]
# ['ACHV', 1.07, 13.0]
# ['ACHN', 6.35, 6.3]
# ['ACIW', 33.2, 40.0]
# ['ACRS', 1.65, 4.5]
# ['ACMR', 15.6, 22.6]
# ['ACOR', 2.5, 5.58]
# ['ATVI', 56.75, 58.52]
# ['ADMS', 4.5, 22.22]
# ['ADMP', 0.9012, 4.5]
# ['ADAP', 0.92, 5.25]
# ['ADUS', 89.1, 98.5]
# ['AEY', 2.42, 7.6]
# ['IOTS', 7.64, 12.0]
# ['ADIL', 1.62, 5.0]
# ['ADMA', 5.04, 12.19]
# ['ADBE', 288.3, 316.76]
# ['ADOM', 0.1689, 1.88]
# ['ADTN', 9.18, 10.55]
# ['ADRO', 1.12, 7.0]
# ['ADES', 13.5, 20.0]
# ['AEIS', 63.98, 63.5]
# ['AMD', 36.52, 34.71]
# ['ADXS', 0.32, 4.65]
# ['ADVM', 7.99, 10.4]
# ['AEGN', 22.18, 21.6]
# ['AGLE', 8.15, 17.0]
# ['AEHR', 1.62, 3.0]
# ['AMTX', 1.0, 2.0]
# ['AERI', 19.02, 41.56]
# ['AVAV', 60.54, 68.6]
# ['ARPO', 0.5401, 2.67]
# ['AEZS', 1.03, 5.5]
# ['AEMD', 3.6, 3.0]
# ['GNMX', 0.14, 4.58]
# ['AFMD', 3.05, 7.13]
# ['AGEN', 3.61, 5.0]
# ['AGRX', 2.2, 4.4]
# ['AGYS', 23.8, 34.0]
# ['AGIO', 31.78, 65.4]
# ['AGNC', 17.16, 17.25]
# ['AGFS', 2.4, 5.5]
# ['ALRN', 0.5022, 6.33]
# ['AIMT', 28.13, 48.3]
# ['ATSG', 22.5, 27.2]
# ['AIRG', 11.34, 17.0]
# ['AKAM', 87.58, 96.11]
# ['AKTX', 1.79, 7.5]
# ['AKCA', 19.84, 32.75]
# ['AKBA', 3.8, 16.81]
# ['AKER', 0.36, 1.86]
# ['AKRX', 4.64, 6.8]
# ['AKTS', 7.41, 10.05]
# ['ALRM', 46.77, 62.67]
# ['ALSK', 1.74, 3.0]
# ['ALBO', 19.22, 54.43]
# ['ABDC', 8.78, 9.75]
# ['ALDX', 6.09, 27.71]
# ['ALXN', 106.91, 150.74]
# ['ALCO', 32.96, 38.0]
# ['ALGN', 257.92, 267.27]
# ['ALIM', 0.3, 1.85]
# ['ALYA', 2.75, 4.56]
# ['ALKS', 19.89, 25.08]
# ['ALLK', 69.16, 99.33]
# ['ABTX', 35.47, 34.33]
# ['ALGT', 168.5, 178.64]
# ['ALNA', 5.15, 20.86]
# ['ARLP', 12.25, 18.0]
# ['AHPI', 1.14, 9.02]
# ['AMOT', 46.1, 57.25]
# ['ALLT', 8.89, 10.5]
# ['MDRX', 11.3, 12.24]
# ['ALNY', 91.14, 115.06]
# ['AOSL', 12.31, 16.0]
# ['ATEC', 6.87, 8.75]
# ['ALPN', 2.87, 13.5]
# ['ALTR', 38.01, 36.8]
# ['ALT', 1.87, 7.2]
# ['ASPS', 17.92, 24.0]
# ['AIMC', 33.83, 46.5]
# ['AMAG', 9.06, 11.0]
# ['AMAL', 18.66, 19.6]
# ['AMRN', 17.65, 29.11]
# ['AMRK', 11.14, 15.0]
# ['AMBC', 20.85, 23.0]
# ['AMBA', 55.87, 57.44]
# ['AMCX', 41.13, 52.23]
# ['DOX', 66.49, 72.0]
# ['AMED', 146.93, 152.27]
# ['UHAL', 393.0, 400.0]
# ['AMRH', 0.16, 0.5]
# ['ATAX', 7.71, 7.5]
# ['AAL', 31.21, 36.67]
# ['AFIN', 14.11, 14.0]
# ['AMNB', 37.57, 37.5]
# ['ANAT', 121.29, 87.04]
# ['AOBC', 7.76, 10.13]
# ['APEI', 23.09, 31.5]
# ['AMRB', 14.65, 17.0]
# ['AMSWA', 16.39, 17.0]
# ['AMSC', 8.18, 15.33]
# ['AMWD', 100.35, 91.33]
# ['CRMT', 95.28, 109.6]
# ['ABCB', 44.29, 47.79]
# ['AMSF', 71.7, 73.0]
# ['ASRV', 4.18, 5.19]
# ['AMGN', 216.91, 220.67]
# ['FOLD', 8.8, 17.95]
# ['AMKR', 13.25, 11.88]
# ['AMPH', 19.2, 25.0]
# ['ASYS', 5.63, 6.75]
# ['AMRS', 3.99, 11.0]
# ['ADI', 113.77, 118.57]
# ['ANAB', 37.88, 101.4]
# ['AVXL', 2.55, 10.0]
# ['ANGI', 7.87, 11.7]
# ['ANGO', 15.14, 18.33]
# ['ANIP', 59.53, 75.0]
# ['ANIK', 60.92, 49.75]
# ['ANIX', 4.0, 11.25]
# ['ANSS', 210.0, 234.77]
# ['ATRS', 3.75, 6.44]
# ['APLS', 30.74, 44.83]
# ['APOG', 38.88, 45.25]
# ['APEN', 2.84, 8.25]
# ['AINV', 16.69, 16.98]
# ['AMEH', 15.29, 25.0]
# ['APPF', 95.5, 77.0]
# ['APPN', 41.66, 41.83]
# ['AAPL', 258.74, 256.19]
# ['APDN', 5.96, 4.0]
# ['AGTC', 3.01, 12.42]
# ['AMAT', 56.31, 54.64]
# ['AAOI', 10.45, 10.07]
# ['AREX', 0.09, 0.25]
# ['APVO', 0.648, 6.17]
# ['APTX', 3.22, 11.5]
# ['APTO', 2.32, 4.72]
# ['AQMS', 1.47, 7.33]
# ['AQB', 2.24, 4.38]
# ['AQST', 5.37, 18.33]
# ['ARAV', 6.57, 15.67]
# ['ABUS', 1.45, 9.32]
# ['ARCW', 0.18, 3.5]
# ['ABIO', 5.35, 9.0]
# ['RKDA', 4.5, 15.0]
# ['ARCB', 31.69, 31.3]
# ['ACGL', 41.28, 43.08]
# ['FUV', 2.07, 8.0]
# ['ARCE', 40.83, 52.63]
# ['ARCT', 10.69, 18.5]
# ['ARDX', 5.01, 12.0]
# ['ARNA', 48.16, 69.0]
# ['ARCC', 18.68, 19.46]
# ['ARGX', 128.0, 160.59]
# ['ARDS', 5.35, 24.0]
# ['ARKR', 20.53, 17.0]
# ['ARTX', 2.98, 4.5]
# ['ARQL', 8.05, 13.7]
# ['AROW', 36.53, 34.95]
# ['ARWR', 39.63, 40.14]
# ['ARTNA', 37.14, 17.0]
# ['ARTW', 1.85, 7.0]
# ['ARVN', 23.79, 32.86]
# ['ASNA', 0.4049, 1.0]
# ['ASND', 114.99, 153.81]
# ['ASLN', 2.39, 7.75]
# ['ASML', 269.08, 267.33]
# ['ASPU', 6.66, 9.5]
# ['AZPN', 116.05, 143.0]
# ['ASMB', 16.2, 43.4]
# ['ASRT', 0.7991, 5.5]
# ['ASFI', 10.04, 8.0]
# ['ASTE', 37.89, 33.67]
# ['ATRO', 31.55, 34.83]
# ['ALOT', 16.51, 28.0]
# ['ASTC', 1.4, 25.0]
# ['ASUR', 9.03, 13.3]
# ['ATRA', 12.58, 31.0]
# ['ATNX', 11.43, 27.42]
# ['ATHX', 1.36, 7.5]
# ['ACBI', 19.16, 20.0]
# ['AY', 23.25, 25.57]
# ['ATLC', 7.55, 3.0]
# ['AAWW', 26.5, 38.13]
# ['AFH', 0.5946, 2.25]
# ['TEAM', 115.37, 149.44]
# ['ATNI', 59.19, 65.25]
# ['ATOM', 3.15, 8.5]
# ['ATOS', 1.62, 9.0]
# ['ATRC', 28.41, 38.57]
# ['ATRI', 768.16, 300.0]
# ['ATIS', 0.79, 6.0]
# ['LIFE', 3.61, 5.75]
# ['BOLD', 26.95, 43.0]
# ['AUDC', 21.49, 23.0]
# ['AEYE', 3.36, 10.38]
# ['AUPH', 5.34, 11.5]
# ['EARS', 1.7, 14.46]
# ['JG', 4.09, 4.77]
# ['ADSK', 152.31, 173.26]
# ['AUTL', 13.09, 33.0]
# ['ADP', 160.54, 179.59]
# ['AUTO', 2.64, 4.33]
# ['AVDL', 5.53, 8.0]
# ['ATXI', 5.82, 12.0]
# ['AVEO', 0.51, 1.44]
# ['CDMO', 5.13, 9.5]
# ['AVID', 6.68, 11.25]
# ['AVGR', 1.17, 4.25]
# ['CAR', 29.63, 37.29]
# ['AVT', 41.59, 38.14]
# ['AVRO', 14.53, 37.78]
# ['AWRE', 2.85, 6.0]
# ['ACLS', 21.82, 24.8]
# ['AXGN', 13.5, 25.67]
# ['AAXN', 53.23, 71.0]
# ['AXNX', 22.88, 43.14]
# ['AXSM', 24.0, 38.43]
# ['AXTI', 3.09, 6.42]
# ['AYTU', 1.05, 4.88]
# ['AZRX', 0.7537, 6.7]
# ['BCOM', 1.39, 21.39]
# ['RILY', 29.41, 1.5]
# ['BIDU', 115.43, 140.45]
# ['BCPC', 105.97, 117.0]
# ['BLDP', 5.85, 4.27]
# ['BANF', 59.78, 58.75]
# ['BAND', 43.8, 85.0]
# ['BFC', 70.09, 65.0]
# ['BOCH', 11.49, 11.75]
# ['BMRC', 45.34, 43.6]
# ['OZK', 29.98, 31.22]
# ['BSVN', 18.75, 22.17]
# ['BFIN', 13.7, 14.0]
# ['BWFG', 28.99, 31.25]
# ['BANR', 56.7, 60.29]
# ['BZUN', 43.3, 49.77]
# ['BBSI', 94.56, 116.33]
# ['BSET', 17.74, 18.0]
# ['BCML', 22.05, 27.13]
# ['BCBP', 13.04, 13.67]
# ['BECN', 33.08, 35.0]
# ['BBGI', 2.88, 4.75]
# ['BBBY', 14.55, 13.54]
# ['BGNE', 187.46, 194.85]
# ['BELFB', 16.57, 21.0]
# ['BLPH', 0.4433, 2.5]
# ['BLCM', 0.98, 11.25]
# ['BNFT', 24.49, 45.5]
# ['BNTC', 0.62, 14.0]
# ['BRY', 10.63, 12.44]
# ['BYSI', 12.71, 41.0]
# ['BGCP', 5.67, 8.5]
# ['BGFV', 3.32, 5.0]
# ['BILI', 16.61, 19.8]
# ['BASI', 5.14, 2.15]
# ['BIOC', 0.7, 3.0]
# ['BCRX', 2.05, 7.57]
# ['BDSI', 5.78, 7.42]
# ['BFRA', 11.36, 15.5]
# ['BIIB', 289.52, 297.59]
# ['BHTG', 1.83, 3.58]
# ['BKYI', 0.5226, 2.0]
# ['BIOL', 0.5727, 3.06]
# ['BLFS', 17.86, 24.67]
# ['BLRX', 2.6, 18.0]
# ['BMRN', 75.44, 114.82]
# ['BMRA', 3.1, 6.25]
# ['BNGO', 1.38, 7.5]
# ['BVXV', 5.6, 30.0]
# ['BPTH', 11.2, 28.0]
# ['BIOS', 3.77, 4.35]
# ['BSGM', 7.21, 11.5]
# ['BSTC', 49.99, 90.0]
# ['TECH', 204.37, 240.0]
# ['BEAT', 44.02, 72.2]
# ['BTAI', 4.18, 20.8]
# ['BJRI', 40.1, 42.73]
# ['BLKB', 83.17, 88.5]
# ['BL', 51.01, 53.2]
# ['BKCC', 4.95, 5.5]
# ['TCPC', 14.12, 15.38]
# ['BLNK', 2.0, 5.0]
# ['BLMN', 23.3, 21.08]
# ['BCOR', 19.31, 39.67]
# ['BLBD', 19.65, 24.0]
# ['BLUE', 79.38, 155.24]
# ['BKEP', 1.22, 1.5]
# ['BPMC', 75.2, 106.31]
# ['BMCH', 28.6, 29.91]
# ['WIFI', 12.7, 23.56]
# ['BOKF', 83.44, 87.09]
# ['BNSO', 2.3343, 0.0]
# ['BRQS', 1.65, 12.0]
# ['BPFH', 11.54, 11.65]
# ['EPAY', 41.49, 52.28]
# ['BOXL', 1.7209, 5.63]
# ['BCLI', 3.79, 10.5]
# ['BDGE', 33.91, 34.4]
# ['BWB', 12.7, 14.33]
# ['BRID', 24.1, 7.93]
# ['BCOV', 9.55, 14.5]
# ['BHF', 42.01, 38.0]
# ['AVGO', 315.58, 320.27]
# ['BVSN', 2.37, 0.0]
# ['BWEN', 1.5377, 2.75]
# ['BPY', 19.05, 21.88]
# ['BRKL', 16.0, 16.0]
# ['BRKS', 44.99, 43.0]
# ['BRKR', 48.23, 51.45]
# ['BMTC', 39.4, 40.1]
# ['BSQR', 1.03, 1.47]
# ['BLDR', 24.21, 26.18]
# ['BFST', 24.9, 27.75]
# ['CHRW', 78.7, 81.12]
# ['CCMP', 158.97, 149.67]
# ['CDNS', 67.37, 75.79]
# ['CDZI', 11.43, 17.5]
# ['CZR', 12.43, 12.2]
# ['CSTE', 16.65, 19.0]
# ['CAMP', 11.5, 16.69]
# ['CVGW', 86.2, 99.0]
# ['CALA', 3.22, 12.0]
# ['CALM', 41.67, 42.75]
# ['CLMT', 3.51, 5.5]
# ['CLXT', 4.51, 22.67]
# ['CAC', 45.51, 43.0]
# ['CAMT', 10.36, 13.5]
# ['CSIQ', 17.18, 25.33]
# ['CGIX', 3.07, 3.0]
# ['CPHC', 12.25, 11.0]
# ['CBNK', 14.38, 15.5]
# ['CCBG', 30.85, 27.9]
# ['CPLP', 11.71, 13.8]
# ['CSWC', 21.03, 22.08]
# ['CPTA', 8.33, 8.5]
# ['CFFN', 14.41, 14.25]
# ['CAPR', 2.6, 19.5]
# ['CSTR', 17.09, 17.17]
# ['CPST', 2.56, 18.75]
# ['CARA', 19.55, 31.89]
# ['CARB', 18.03, 24.78]
# ['CSII', 43.04, 54.6]
# ['CDLX', 41.87, 39.2]
# ['CATM', 38.8, 44.83]
# ['CDNA', 20.19, 49.2]
# ['CECO', 17.0, 24.5]
# ['CTRE', 22.45, 25.25]
# ['CARG', 36.35, 46.17]
# ['CARO', 38.57, 39.3]
# ['CRZO', 7.55, 12.49]
# ['TAST', 6.72, 12.25]
# ['CARV', 3.01, 0.0]
# ['CASA', 3.78, 6.6]
# ['CWST', 42.46, 49.0]
# ['CASY', 173.35, 178.5]
# ['CASI', 3.16, 7.0]
# ['CATB', 5.48, 31.0]
# ['CBIO', 5.73, 24.75]
# ['CPRX', 4.71, 8.83]
# ['CATS', 14.67, 23.75]
# ['CATY', 37.38, 37.71]
# ['CVCO', 198.94, 201.0]
# ['CBFV', 27.45, 29.0]
# ['CBTX', 29.39, 30.67]
# ['CDK', 50.61, 59.5]
# ['CDW', 132.81, 135.13]
# ['CECE', 7.88, 9.7]
# ['CELC', 14.11, 35.5]
# ['CELG', 108.2, 103.4]
# ['CLDX', 2.65, 19.0]
# ['APOP', 3.15, 12.0]
# ['CLRB', 1.41, 6.6]
# ['CLLS', 12.5, 40.82]
# ['CBMG', 18.16, 24.0]
# ['CLSN', 1.43, 8.67]
# ['CELH', 3.74, 9.67]
# ['CYAD', 9.11, 44.25]
# ['CETX', 1.47, 12.0]
# ['CDEV', 3.58, 6.65]
# ['CSFL', 26.53, 26.44]
# ['CETV', 4.44, 2.9]
# ['CENT', 31.24, 30.0]
# ['CENTA', 29.26, 32.25]
# ['CVCY', 21.0, 20.88]
# ['CTRC', 2.46, 8.0]
# ['CENX', 8.11, 8.88]
# ['CNBKA', 87.39, 16.0]
# ['CNTY', 7.81, 12.13]
# ['CRNT', 1.83, 3.5]
# ['CERC', 3.49, 10.33]
# ['CERN', 67.2, 75.42]
# ['CERS', 4.15, 8.0]
# ['CEVA', 30.91, 30.67]
# ['CSBR', 5.35, 9.75]
# ['CYOU', 9.75, 9.43]
# ['BURG', 0.83, 2.5]
# ['CTHR', 1.3095, 2.5]
# ['GTLS', 58.69, 94.55]
# ['CHTR', 468.62, 490.3]
# ['CHKP', 114.52, 119.33]
# ['CHEK', 1.76, 10.0]
# ['CKPT', 1.95, 15.67]
# ['CEMI', 5.53, 11.25]
# ['CCXI', 9.99, 19.0]
# ['CHMG', 45.0, 47.0]
# ['CHFS', 0.85, 15.0]
# ['CHMA', 5.46, 13.2]
# ['CSSE', 9.85, 20.38]
# ['PLCE', 85.56, 106.75]
# ['CMRX', 1.6, 5.0]
# ['CAAS', 2.0, 3.25]
# ['CBPO', 114.72, 88.14]
# ['JRJC', 0.67, 8.3]
# ['CJJD', 1.25, 7.0]
# ['CNET', 1.32, 27.7]
# ['IMOS', 21.74, 20.0]
# ['CDXC', 3.0, 7.63]
# ['CHDN', 123.16, 147.67]
# ['CHUY', 25.11, 24.43]
# ['CDTX', 2.2, 6.83]
# ['CMCT', 14.5, 15.08]
# ['CMPR', 135.34, 109.33]
# ['CINF', 110.54, 108.63]
# ['CIDM', 0.943, 2.0]
# ['CTAS', 264.29, 272.0]
# ['CRUS', 69.27, 63.5]
# ['CSCO', 48.61, 55.09]
# ['CTRN', 19.03, 28.0]
# ['CTXR', 0.52, 1.65]
# ['CZNC', 26.55, 27.0]
# ['CZWI', 11.17, 12.67]
# ['CIZN', 20.9, 24.0]
# ['CTXS', 109.9, 113.29]
# ['CHCO', 81.24, 76.5]
# ['CIVB', 22.72, 25.13]
# ['CLAR', 11.69, 16.4]
# ['CLNE', 2.41, 6.5]
# ['CLFD', 12.31, 17.0]
# ['CLRO', 1.73, 4.05]
# ['CLSD', 1.1, 3.0]
# ['CBLI', 0.6668, 2.0]
# ['CLVS', 4.3, 16.28]
# ['CME', 199.02, 216.06]
# ['CCNE', 33.18, 31.75]
# ['CCB', 15.42, 17.5]
# ['COKE', 268.49, 144.0]
# ['COCP', 0.693, 11.0]
# ['CODA', 7.28, 18.0]
# ['CDXS', 15.43, 22.5]
# ['JVA', 4.06, 9.0]
# ['CCOI', 60.1, 51.55]
# ['CGNX', 53.84, 48.0]
# ['CTSH', 62.74, 67.72]
# ['COHR', 162.9, 159.25]
# ['CHRS', 17.5, 31.71]
# ['COHU', 19.77, 24.25]
# ['CLCT', 27.62, 13.5]
# ['COLL', 15.7, 27.0]
# ['CIGI', 67.97, 80.8]
# ['CLGN', 4.3, 7.01]
# ['CBAN', 15.74, 10.0]
# ['COLB', 40.51, 40.5]
# ['CLBK', 16.65, 16.5]
# ['COLM', 93.42, 115.38]
# ['CMCO', 37.5, 48.2]
# ['CMCSA', 44.48, 51.11]
# ['CBSH', 66.75, 57.33]
# ['CVGI', 7.05, 8.5]
# ['COMM', 12.88, 18.18]
# ['JCS', 6.28, 8.0]
# ['ESXB', 8.89, 9.0]
# ['CTBI', 45.22, 44.0]
# ['CVLT', 49.89, 55.0]
# ['CGEN', 5.62, 8.5]
# ['CPSI', 26.94, 26.0]
# ['CTG', 5.71, 7.0]
# ['SCOR', 3.31, 4.9]
# ['CHCI', 2.1596, 7.0]
# ['CMTL', 34.86, 38.25]
# ['CNAT', 0.352, 1.6]
# ['CNCE', 6.8, 16.71]
# ['CDOR', 11.02, 11.05]
# ['CFMS', 1.91, 3.88]
# ['CNFR', 4.0, 4.0]
# ['CNMD', 111.09, 115.4]
# ['CNOB', 25.33, 28.83]
# ['CONN', 23.96, 33.83]
# ['CNSL', 4.32, 5.0]
# ['CWCO', 17.6, 17.0]
# ['CNST', 26.91, 23.86]
# ['ROAD', 17.59, 16.96]
# ['CPSS', 3.36, 5.0]
# ['CFRX', 0.32, 2.13]
# ['AWSM', 0.137, 35.0]
# ['CPRT', 82.03, 88.13]
# ['CRBP', 5.15, 23.8]
# ['CORT', 14.33, 16.0]
# ['CORE', 32.61, 37.5]
# ['CSOD', 58.16, 67.0]
# ['CORV', 2.49, 5.84]
# ['CRVL', 77.71, 0.0]
# ['CRVS', 3.9, 9.75]
# ['CSGP', 550.57, 646.1]
# ['COST', 303.93, 301.09]
# ['CPAH', 1.1511, 3.45]
# ['ICBK', 23.01, 22.83]
# ['COUP', 130.58, 160.79]
# ['CVTI', 15.82, 20.5]
# ['COWN', 15.5, 21.33]
# ['PMTS', 1.78, 6.0]
# ['CRAI', 52.14, 69.0]
# ['CBRL', 163.33, 166.14]
# ['BREW', 7.74, 13.2]
# ['CACC', 424.65, 380.13]
# ['CREE', 50.39, 48.67]
# ['CRESY', 5.01, 21.57]
# ['CRNX', 19.08, 39.5]
# ['CRSP', 49.13, 62.21]
# ['CRTO', 18.1, 21.84]
# ['CROX', 35.39, 42.86]
# ['CCRN', 12.35, 11.9]
# ['CRWS', 7.21, 6.0]
# ['CYRX', 13.96, 24.14]
# ['CSGS', 56.42, 58.67]
# ['CCLP', 2.77, 4.83]
# ['CSPI', 12.56, 65.0]
# ['CSWI', 73.31, 69.5]
# ['CSX', 73.91, 76.86]
# ['CTIC', 0.7763, 4.0]
# ['CTIB', 1.42, 7.0]
# ['CTRP', 34.1, 41.36]
# ['CUE', 8.62, 13.0]
# ['CUI', 0.72, 2.5]
# ['CPIX', 5.62, 12.25]
# ['CMLS', 13.89, 22.33]
# ['CRIS', 1.84, 9.0]
# ['CUTR', 33.15, 31.67]
# ['CVBF', 21.49, 22.14]
# ['CVV', 3.93, 16.0]
# ['CYAN', 2.59, 14.0]
# ['CYBR', 116.37, 144.71]
# ['CYBE', 18.33, 20.0]
# ['CYCC', 0.42, 7.0]
# ['CBAY', 5.72, 16.36]
# ['CY', 23.35, 23.78]
# ['CYRN', 1.62, 3.0]
# ['CONE', 68.47, 75.15]
# ['CYTK', 9.98, 22.0]
# ['CTMX', 6.16, 20.78]
# ['CTSO', 4.61, 12.3]
# ['CYTR', 0.28, 4.5]
# ['DAKT', 6.99, 7.75]
# ['DARE', 0.87, 4.0]
# ['DRIO', 0.23, 0.75]
# ['DZSI', 7.69, 16.0]
# ['DSKE', 3.08, 5.17]
# ['DAIO', 3.78, 4.0]
# ['PLAY', 41.49, 44.45]
# ['DTEA', 1.73, 3.48]
# ['DWSN', 2.65, 4.0]
# ['DBVT', 7.43, 15.45]
# ['DCPH', 46.79, 57.08]
# ['TACO', 7.9, 12.33]
# ['DMPI', 0.74, 2.0]
# ['DNLI', 16.67, 26.3]
# ['DENN', 20.12, 25.21]
# ['XRAY', 58.15, 59.29]
# ['DERM', 7.11, 22.67]
# ['DXLG', 1.54, 4.0]
# ['DSWL', 2.54, 7.75]
# ['DXCM', 185.2, 206.31]
# ['FANG', 77.75, 132.24]
# ['DCIX', 0.96, 6.16]
# ['DRNA', 17.42, 24.13]
# ['DFFN', 0.7, 10.0]
# ['DGII', 14.23, 17.43]
# ['DMRC', 35.5, 53.0]
# ['DRAD', 4.33, 5.0]
# ['DGLY', 1.29, 5.7]
# ['APPS', 6.88, 8.29]
# ['DCOM', 19.86, 21.33]
# ['DIOD', 46.66, 49.5]
# ['DISCA', 28.72, 34.32]
# ['DISCB', 38.18, 30.0]
# ['DISCK', 26.5, 28.0]
# ['DISH', 35.99, 42.95]
# ['DVCR', 2.71, 6.0]
# ['SAUC', 1.03, 2.0]
# ['DLHC', 4.364, 7.63]
# ['BOOM', 45.96, 70.6]
# ['DNBF', 47.19, 38.0]
# ['DOCU', 66.25, 73.58]
# ['DLTR', 113.37, 116.44]
# ['DLPN', 0.68, 2.47]
# ['DOMO', 16.35, 26.83]
# ['DGICA', 14.72, 17.0]
# ['DORM', 73.54, 70.0]
# ['DOVA', 28.03, 26.9]
# ['DBX', 20.66, 29.82]
# ['DCAR', 0.601, 12.0]
# ['DSPG', 15.45, 19.2]
# ['DLTH', 9.58, 12.33]
# ['DNKN', 75.88, 80.58]
# ['DRRX', 1.9, 3.7]
# ['DXPE', 38.98, 38.67]
# ['DYSL', 1.515, 3.0]
# ['DYNT', 0.83, 3.24]
# ['DVAX', 5.29, 20.75]
# ['ETFC', 43.8, 44.17]
# ['SSP', 14.12, 17.71]
# ['EBMT', 19.25, 21.5]
# ['EGBN', 46.16, 47.0]
# ['EGRX', 60.79, 58.67]
# ['EWBC', 46.12, 53.5]
# ['EAST', 3.93, 10.5]
# ['EBAY', 35.51, 40.17]
# ['EBIX', 43.08, 80.0]
# ['ECHO', 21.95, 25.58]
# ['SATS', 40.99, 52.5]
# ['ESES', 0.0111, 4.0]
# ['EDAP', 4.5, 5.68]
# ['EDIT', 20.62, 46.71]
# ['EGAN', 7.64, 11.5]
# ['EHTH', 75.79, 116.2]
# ['EIDX', 42.5, 51.14]
# ['EIGR', 11.29, 36.67]
# ['EKSO', 0.61, 1.43]
# ['LOCO', 14.98, 14.5]
# ['ESLT', 165.1, 173.0]
# ['ERI', 47.5, 59.11]
# ['ECOR', 1.51, 9.75]
# ['EA', 99.29, 109.69]
# ['ELOX', 5.1, 16.83]
# ['EMKR', 3.06, 4.73]
# ['EMMS', 4.68, 1.0]
# ['NYNY', 9.83, 10.0]
# ['ENTA', 61.97, 96.5]
# ['ECPG', 35.8, 43.43]
# ['WIRE', 58.42, 63.67]
# ['ENDP', 4.28, 4.78]
# ['ELGX', 2.65, 6.71]
# ['EIGI', 4.08, 5.63]
# ['WATT', 2.79, 9.23]
# ['EFOI', 0.415, 2.75]
# ['ERII', 9.54, 14.0]
# ['ENPH', 18.32, 30.67]
# ['ESGR', 199.33, 185.0]
# ['ENFC', 30.04, 24.0]
# ['ENTG', 48.5, 52.11]
# ['ENTX', 2.4224, 12.8]
# ['EFSC', 46.08, 50.33]
# ['EPZM', 13.61, 18.88]
# ['PLUS', 96.15, 87.33]
# ['EQ', 3.4, 18.0]
# ['EQIX', 530.96, 614.59]
# ['EQBK', 28.9, 31.25]
# ['ERIC', 8.88, 10.8]
# ['ERIE', 177.46, 115.0]
# ['ERYP', 4.8, 21.25]
# ['ESCA', 11.27, 16.0]
# ['ESPR', 37.39, 81.23]
# ['ESQ', 23.98, 28.0]
# ['ESSA', 16.33, 17.0]
# ['ESTA', 21.16, 39.5]
# ['ESTR', 0.215, 10.01]
# ['ETSY', 42.74, 67.0]
# ['EDRY', 7.31, 11.25]
# ['EEFT', 148.69, 181.11]
# ['ESEA', 0.5795, 1.15]
# ['EVLO', 6.78, 17.75]
# ['EVBG', 77.23, 97.0]
# ['EVER', 29.5, 33.86]
# ['MRAM', 5.91, 11.0]
# ['EVOP', 29.55, 29.78]
# ['EVFM', 5.22, 9.8]
# ['EVGN', 1.5828, 8.0]
# ['EVOK', 0.9, 8.0]
# ['EOLS', 14.49, 25.56]
# ['EVOL', 1.17, 7.0]
# ['EXAS', 81.5, 126.55]
# ['XELA', 0.6102, 5.0]
# ['EXEL', 15.28, 24.6]
# ['EXFO', 4.21, 4.54]
# ['EXLS', 69.34, 72.18]
# ['EXPI', 9.58, 18.0]
# ['EXPE', 115.15, 139.43]
# ['EXPD', 77.22, 73.15]
# ['EXPO', 64.67, 73.8]
# ['STAY', 13.99, 17.04]
# ['XOG', 2.1, 4.58]
# ['EXTR', 6.75, 9.25]
# ['EYEG', 3.92, 90.0]
# ['EYEN', 3.01, 14.8]
# ['EYPT', 1.6, 4.38]
# ['EZPW', 5.31, 11.38]
# ['FFIV', 148.58, 162.5]
# ['FB', 191.91, 238.96]
# ['FLMN', 6.34, 8.65]
# ['FARM', 13.89, 12.17]
# ['FMAO', 25.65, 26.5]
# ['FMNB', 15.6, 15.63]
# ['FARO', 50.33, 54.0]
# ['FAST', 37.4, 34.13]
# ['FAT', 4.63, 11.75]
# ['FATE', 13.57, 24.79]
# ['FBSS', 19.82, 17.5]
# ['FNHC', 14.45, 18.0]
# ['FENC', 4.91, 18.0]
# ['GSM', 0.6688, 2.5]
# ['FCSC', 2.98, 3.0]
# ['FGEN', 39.07, 64.29]
# ['FDUS', 15.16, 16.42]
# ['FRGI', 9.52, 10.5]
# ['FITB', 30.67, 31.2]
# ['FISI', 32.45, 33.33]
# ['FNJN', 1.84, 5.0]
# ['FEYE', 16.71, 18.3]
# ['FBNC', 38.93, 40.25]
# ['FRBA', 10.86, 12.25]
# ['BUSE', 27.28, 28.71]
# ['FBIZ', 24.75, 26.63]
# ['FCBP', 22.95, 25.0]
# ['FCBC', 32.54, 35.0]
# ['FCCO', 19.03, 21.67]
# ['FDEF', 31.69, 33.17]
# ['FFBC', 24.46, 25.08]
# ['FFIN', 34.6, 30.25]
# ['THFF', 45.6, 46.0]
# ['FFNW', 14.42, 15.5]
# ['FFWM', 16.5, 17.9]
# ['FGBI', 19.77, 22.0]
# ['FHB', 28.53, 27.79]
# ['INBK', 23.11, 27.0]
# ['FIBK', 43.2, 45.25]
# ['FRME', 41.47, 43.38]
# ['FMBH', 36.0, 38.25]
# ['FMBI', 22.05, 22.93]
# ['FSFG', 62.65, 75.0]
# ['FSLR', 53.76, 72.0]
# ['FUNC', 23.75, 22.0]
# ['MYFW', 15.52, 18.0]
# ['FCFS', 81.99, 97.0]
# ['SVVC', 6.8, 34.0]
# ['FSV', 88.13, 69.33]
# ['FISV', 108.0, 120.92]
# ['FIVE', 128.19, 142.55]
# ['FPRX', 3.75, 11.33]
# ['FVE', 5.26, 1.0]
# ['FIVN', 60.34, 64.85]
# ['FLEX', 11.86, 13.79]
# ['FLXN', 16.78, 26.38]
# ['FLXS', 18.01, 50.0]
# ['FLIR', 53.71, 59.56]
# ['FLNT', 2.41, 5.8]
# ['FLDM', 2.55, 8.3]
# ['FFIC', 21.42, 22.0]
# ['FOMX', 3.9, 15.5]
# ['FOCS', 25.0, 35.81]
# ['FSCT', 27.0, 37.45]
# ['FRSX', 1.34, 5.38]
# ['FORM', 22.53, 23.11]
# ['FORR', 36.02, 54.0]
# ['FRTA', 11.49, 10.0]
# ['FTNT', 93.62, 97.28]
# ['FBIO', 1.37, 7.5]
# ['FTSV', 8.07, 19.36]
# ['FWRD', 71.19, 70.2]
# ['FORD', 1.06, 2.28]
# ['FWP', 0.8715, 37.0]
# ['FOSL', 9.55, 14.33]
# ['FOXF', 64.42, 78.14]
# ['FRAN', 16.97, 1.75]
# ['FELE', 54.94, 48.67]
# ['RAIL', 2.94, 4.0]
# ['FEIM', 11.49, 17.0]
# ['FRPT', 53.81, 53.67]
# ['FTDR', 44.67, 52.3]
# ['FTEO', 6.12, 23.0]
# ['FTR', 0.86, 0.77]
# ['FRPH', 52.56, 45.0]
# ['FSBW', 58.43, 61.67]
# ['FTEK', 0.99, 1.75]
# ['FCEL', 0.5, 1.0]
# ['FLGT', 11.58, 11.15]
# ['FLL', 2.98, 4.25]
# ['FULT', 17.78, 16.17]
# ['FNKO', 14.69, 26.89]
# ['FTFT', 0.61, 4.0]
# ['FFHL', 2.74, 357.8]
# ['FVCB', 17.32, 19.0]
# ['WILC', 11.75, 10.0]
# ['GTHX', 23.07, 66.5]
# ['GAIA', 8.73, 14.06]
# ['GLPG', 185.45, 199.52]
# ['GALT', 3.87, 11.0]
# ['GLMD', 4.51, 30.89]
# ['GMDA', 5.0, 17.6]
# ['GLPI', 42.04, 43.27]
# ['GRMN', 93.74, 87.67]
# ['GARS', 6.72, 9.0]
# ['GLIBA', 69.02, 75.0]
# ['GDS', 43.24, 49.51]
# ['GEMP', 0.3801, 2.0]
# ['GENC', 12.55, 13.75]
# ['GFN', 9.61, 13.0]
# ['GENE', 1.93, 12.5]
# ['GNUS', 0.641, 4.5]
# ['GNMK', 6.05, 10.29]
# ['GNCA', 2.45, 17.5]
# ['GHDX', 63.88, 72.0]
# ['GNPX', 0.48, 5.25]
# ['GNTX', 29.37, 25.06]
# ['THRM', 43.26, 45.6]
# ['GEOS', 15.3, 17.25]
# ['GABC', 33.82, 33.5]
# ['GERN', 1.49, 3.75]
# ['GEVO', 2.6, 10.0]
# ['ROCK', 54.03, 56.25]
# ['GIGM', 2.489, 1.5]
# ['GIII', 29.41, 29.7]
# ['GILT', 7.91, 5.5]
# ['GILD', 65.02, 78.65]
# ['GBCI', 44.39, 42.57]
# ['GLAD', 10.04, 9.25]
# ['GOOD', 23.06, 24.75]
# ['GAIN', 13.54, 12.81]
# ['LAND', 12.0, 13.0]
# ['GBT', 47.77, 91.36]
# ['ENT', 0.609, 1.5]
# ['GBLI', 26.06, 27.0]
# ['SELF', 4.26, 5.75]
# ['GWRS', 12.0, 12.5]
# ['GLBS', 2.19, 20.0]
# ['GLUU', 5.06, 7.44]
# ['GLYC', 5.6, 10.75]
# ['GOGO', 6.75, 6.1]
# ['GLNG', 14.26, 24.75]
# ['GMLP', 9.98, 12.77]
# ['GDEN', 15.45, 20.6]
# ['GOGL', 5.56, 7.85]
# ['GBDC', 17.81, 18.75]
# ['GTIM', 1.7213, 4.83]
# ['GSHD', 43.79, 51.67]
# ['GPRO', 4.42, 5.3]
# ['LOPE', 87.41, 138.67]
# ['GRVY', 34.37, 0.0]
# ['GECC', 8.29, 11.0]
# ['GEC', 3.3142, 12.0]
# ['GLDD', 9.79, 13.9]
# ['GSBC', 61.99, 59.67]
# ['GRBK', 10.01, 12.0]
# ['GPP', 14.0, 15.67]
# ['GPRE', 15.04, 17.6]
# ['GLRE', 11.13, 1.0]
# ['GRNQ', 0.765, 8.0]
# ['GSKY', 7.23, 7.63]
# ['GSUM', 1.92, 19.83]
# ['GRFS', 21.52, 22.38]
# ['GRIN', 7.09, 7.0]
# ['GRTS', 7.76, 22.0]
# ['GRPN', 2.93, 3.59]
# ['OMAB', 54.96, 56.93]
# ['GVP', 1.26, 2.5]
# ['GSIT', 7.79, 8.0]
# ['GNTY', 32.1, 33.5]
# ['GFED', 24.06, 27.0]
# ['GH', 65.15, 115.8]
# ['GIFI', 4.83, 8.0]
# ['GURE', 0.7299, 14.5]
# ['GPOR', 3.47, 4.43]
# ['GWPH', 113.39, 206.93]
# ['GWGH', 9.8, 10.7]
# ['HEES', 36.91, 34.8]
# ['HNRG', 3.02, 9.0]
# ['HALL', 17.16, 18.5]
# ['HALO', 17.08, 19.8]
# ['HLNE', 55.44, 59.75]
# ['HWC', 41.45, 43.65]
# ['HAFC', 19.91, 19.0]
# ['HONE', 10.47, 12.0]
# ['HLIT', 7.96, 9.38]
# ['HBIO', 2.5, 4.17]
# ['HCAP', 8.86, 9.5]
# ['HAS', 95.66, 114.71]
# ['HA', 30.75, 27.38]
# ['HWKN', 44.63, 40.0]
# ['HAYN', 37.25, 45.5]
# ['HDS', 41.0, 46.07]
# ['HIIQ', 23.66, 54.63]
# ['HCSG', 25.25, 28.43]
# ['HQY', 59.33, 76.62]
# ['HSTM', 27.38, 28.0]
# ['HTLD', 22.17, 22.0]
# ['HTLF', 48.36, 49.6]
# ['HTBX', 0.53, 6.88]
# ['HSII', 30.13, 33.0]
# ['HELE', 156.3, 174.4]
# ['HMNY', 0.0026, 3000.0]
# ['HSDT', 1.12, 2.12]
# ['HMTV', 12.91, 16.5]
# ['HNNA', 12.3, 13.25]
# ['HSIC', 69.0, 67.71]
# ['HTBK', 12.32, 13.88]
# ['HFWA', 28.7, 29.2]
# ['HCCI', 27.96, 31.0]
# ['MLHR', 47.23, 45.0]
# ['HRTX', 21.07, 42.3]
# ['HSKA', 90.12, 100.05]
# ['HX', 0.59, 4.0]
# ['HIBB', 25.5, 19.8]
# ['HIMX', 2.54, 2.9]
# ['HMNF', 20.98, 27.0]
# ['HMSY', 27.01, 38.0]
# ['HOLI', 15.46, 23.7]
# ['HOLX', 49.56, 53.33]
# ['HBCP', 39.4, 41.0]
# ['HOMB', 19.19, 21.63]
# ['HMST', 31.44, 31.75]
# ['HTBI', 27.01, 28.5]
# ['FIXX', 11.87, 33.4]
# ['HOFT', 24.15, 37.0]
# ['HOPE', 14.69, 14.4]
# ['HBNC', 19.04, 20.08]
# ['HZNP', 29.53, 35.5]
# ['HRZN', 12.48, 11.5]
# ['TWNK', 13.0, 16.0]
# ['HMHC', 6.47, 7.57]
# ['HWCC', 4.326, 8.0]
# ['HBMD', 16.54, 16.0]
# ['HTGM', 0.93, 4.1]
# ['HTHT', 37.41, 36.73]
# ['HUBG', 49.59, 53.29]
# ['HDSN', 0.75, 0.8]
# ['HBAN', 15.0, 15.1]
# ['HURC', 36.02, 38.0]
# ['HURN', 67.93, 73.33]
# ['HCM', 21.3, 35.15]
# ['HBP', 2.0, 8.1]
# ['HYRE', 2.01, 7.19]
# ['IIIV', 21.01, 27.83]
# ['IAC', 223.57, 294.53]
# ['IBKC', 78.39, 82.75]
# ['ICAD', 7.11, 8.5]
# ['IEP', 67.5, 58.0]
# ['ICFI', 87.0, 93.75]
# ['ICHR', 32.0, 34.25]
# ['ICLK', 3.08, 7.5]
# ['ICLR', 149.06, 168.92]
# ['ICON', 2.23, 0.7]
# ['ICUI', 166.12, 192.5]
# ['IPWR', 2.52, 0.5]
# ['INVE', 5.08, 8.86]
# ['IDRA', 2.68, 8.6]
# ['IDXX', 261.86, 301.5]
# ['IESC', 20.17, 6.5]
# ['INFO', 69.63, 71.53]
# ['IIVI', 36.84, 47.3]
# ['ILMN', 299.35, 333.85]
# ['ISNS', 5.06, 4.0]
# ['IMMR', 7.52, 12.0]
# ['IMGN', 3.42, 4.67]
# ['IMMU', 17.52, 26.1]
# ['IMMP', 1.89, 5.39]
# ['PI', 35.13, 38.83]
# ['INCY', 83.84, 94.06]
# ['INDB', 85.59, 85.75]
# ['IBCP', 22.96, 23.9]
# ['IBTX', 56.28, 60.75]
# ['ILPT', 21.22, 24.0]
# ['INFN', 5.48, 6.16]
# ['INFI', 1.04, 3.0]
# ['IFRX', 3.1, 4.35]
# ['IEA', 2.51, 5.0]
# ['INWK', 5.49, 6.33]
# ['INOD', 1.4, 5.0]
# ['IPHS', 32.12, 35.5]
# ['IOSP', 99.4, 108.5]
# ['INNT', 0.86, 10.0]
# ['ISSC', 4.63, 4.0]
# ['INVA', 12.07, 13.5]
# ['INGN', 67.91, 68.7]
# ['INOV', 16.18, 18.06]
# ['INO', 2.51, 8.71]
# ['INPX', 0.083, 0.25]
# ['INSG', 5.03, 7.0]
# ['NSIT', 62.77, 69.0]
# ['ISIG', 0.99, 3.0]
# ['INSM', 18.78, 42.56]
# ['INSE', 7.57, 11.33]
# ['IIIN', 20.8, 23.0]
# ['PODD', 159.92, 159.43]
# ['NTEC', 0.7, 5.83]
# ['IART', 58.53, 66.33]
# ['INTC', 58.0, 56.03]
# ['NTLA', 12.78, 28.05]
# ['IPAR', 77.28, 77.0]
# ['ICPT', 78.89, 145.58]
# ['IDCC', 57.47, 92.6]
# ['TILE', 17.13, 19.0]
# ['LINK', 4.49, 0.0]
# ['INAP', 2.32, 5.83]
# ['IBOC', 42.98, 22.0]
# ['IMXI', 15.34, 17.33]
# ['IGLD', 12.7, 44.09]
# ['IDXG', 0.7643, 2.72]
# ['XENT', 21.75, 25.14]
# ['IVAC', 6.13, 6.8]
# ['INTL', 41.65, 46.0]
# ['ITCI', 10.01, 25.22]
# ['XON', 5.52, 9.67]
# ['IIN', 17.19, 31.67]
# ['INTU', 253.0, 280.56]
# ['ISRG', 558.21, 610.21]
# ['ISTR', 25.35, 27.08]
# ['ISBC', 12.2, 14.0]
# ['ITIC', 160.22, 39.0]
# ['NVIV', 0.5, 2.0]
# ['IONS', 54.36, 68.27]
# ['IOVA', 21.42, 34.5]
# ['IPGP', 150.61, 162.21]
# ['IQ', 18.64, 19.91]
# ['IRMD', 23.05, 31.0]
# ['IRTC', 68.09, 106.4]
# ['IRIX', 2.22, 7.0]
# ['IRDM', 25.32, 30.75]
# ['IRBT', 50.62, 55.86]
# ['IRWD', 10.93, 14.13]
# ['IRCP', 11.49, 27.9]
# ['ITI', 4.97, 8.4]
# ['ITRM', 2.56, 17.0]
# ['ITRI', 80.31, 85.43]
# ['ITRN', 24.8, 31.5]
# ['IZEA', 0.3001, 1.85]
# ['JJSF', 190.93, 192.5]
# ['JBHT', 119.99, 112.89]
# ['JCOM', 99.63, 109.38]
# ['JKHY', 148.06, 143.22]
# ['JACK', 84.81, 95.06]
# ['JAGX', 0.765, 7.5]
# ['JAKK', 0.931, 1.0]
# ['JRVR', 36.09, 42.4]
# ['JASN', 0.285, 3.5]
# ['JAZZ', 127.6, 170.28]
# ['JD', 33.64, 36.15]
# ['JRSH', 6.8, 10.0]
# ['JBLU', 19.71, 21.53]
# ['JBSS', 102.58, 94.0]
# ['JOUT', 61.2, 74.0]
# ['JNCE', 3.92, 12.0]
# ['KALU', 112.32, 113.0]
# ['KALA', 3.66, 19.67]
# ['KALV', 10.9, 32.14]
# ['KMDA', 5.22, 9.0]
# ['KNDI', 4.71, 4.59]
# ['KPTI', 14.09, 22.88]
# ['KZIA', 3.03, 15.22]
# ['KRNY', 14.25, 14.33]
# ['KELYA', 22.34, 31.67]
# ['KMPH', 0.512, 7.26]
# ['KEQU', 15.41, 28.0]
# ['KTCC', 6.2, 9.25]
# ['KZR', 3.44, 24.33]
# ['KFRC', 41.46, 39.67]
# ['KE', 17.5, 17.0]
# ['KBAL', 21.85, 15.0]
# ['KIN', 8.82, 15.28]
# ['KINS', 8.84, 10.25]
# ['KNSA', 6.79, 25.0]
# ['KNSL', 87.75, 112.33]
# ['KIRK', 1.34, 2.7]
# ['KTOV', 0.77, 12.0]
# ['KLAC', 173.58, 181.14]
# ['KLXE', 9.17, 14.13]
# ['KOD', 21.9, 29.33]
# ['KOPN', 0.5511, 2.1]
# ['KRNT', 34.81, 33.33]
# ['KTOS', 18.6, 23.7]
# ['KRYS', 44.07, 71.6]
# ['KLIC', 25.6, 26.5]
# ['KURA', 14.99, 27.5]
# ['KVHI', 10.11, 15.0]
# ['FSTR', 19.38, 30.38]
# ['LJPC', 6.94, 20.17]
# ['LBAI', 17.12, 18.58]
# ['LKFN', 47.29, 46.5]
# ['LAKE', 10.55, 15.5]
# ['LRCX', 278.25, 265.5]
# ['LAMR', 82.86, 84.0]
# ['LANC', 155.26, 154.0]
# ['LNDC', 11.0, 13.4]
# ['LMRK', 16.34, 17.83]
# ['LE', 11.22, 21.0]
# ['LSTR', 117.83, 113.1]
# ['LNTH', 20.68, 24.0]
# ['LTRX', 3.12, 5.13]
# ['LSCC', 19.69, 21.43]
# ['LAUR', 16.24, 20.69]
# ['LAWS', 46.95, 52.0]
# ['LAZY', 3.7, 10.0]
# ['LCNB', 18.04, 24.0]
# ['LPTX', 1.36, 6.83]
# ['LMAT', 32.69, 36.57]
# ['TREE', 365.15, 375.42]
# ['LEVL', 24.68, 31.0]
# ['LXRX', 4.16, 8.0]
# ['LX', 11.9, 16.88]
# ['LGIH', 74.43, 80.8]
# ['LHCG', 130.44, 140.91]
# ['LBRDA', 117.12, 121.4]
# ['LBRDK', 116.98, 131.0]
# ['LBTYA', 23.96, 29.81]
# ['LBTYK', 23.5, 32.5]
# ['LILA', 19.58, 21.98]
# ['LILAK', 19.32, 21.0]
# ['BATRA', 29.84, 37.16]
# ['FWONA', 38.67, 46.68]
# ['FWONK', 40.42, 47.0]
# ['LSXMA', 45.52, 57.71]
# ['LSXMK', 45.71, 57.5]
# ['LTRPA', 8.96, 8.0]
# ['LCUT', 7.78, 11.0]
# ['LFVN', 14.76, 20.0]
# ['LWAY', 2.0, 7.25]
# ['LGND', 103.81, 196.2]
# ['LTBR', 5.73, 10.5]
# ['LPTH', 0.7091, 2.0]
# ['LLEX', 0.23, 1.5]
# ['LMB', 4.75, 10.5]
# ['LLNW', 4.27, 4.44]
# ['LMST', 15.02, 17.13]
# ['LMNR', 18.76, 24.17]
# ['LINC', 2.0, 4.25]
# ['LECO', 92.64, 92.33]
# ['LIND', 15.27, 19.8]
# ['LPCN', 2.78, 5.67]
# ['YVR', 2.05, 4.4]
# ['LQDA', 4.04, 33.5]
# ['LQDT', 6.76, 9.0]
# ['LFUS', 185.62, 189.2]
# ['LIVN', 74.7, 88.14]
# ['LOB', 19.0, 20.0]
# ['LIVE', 8.1, 49.62]
# ['LPSN', 42.0, 43.07]
# ['LIVX', 1.5, 5.38]
# ['LKQ', 35.59, 40.04]
# ['LOGC', 10.01, 22.25]
# ['LOGI', 42.15, 48.2]
# ['LOGM', 70.24, 80.78]
# ['LONE', 2.74, 6.5]
# ['LORL', 40.21, 89.0]
# ['LPLA', 87.11, 93.33]
# ['LYTS', 5.68, 7.25]
# ['LULU', 202.0, 211.35]
# ['LITE', 65.85, 74.5]
# ['LMNX', 17.68, 25.0]
# ['LUNA', 6.38, 7.28]
# ['LBC', 11.95, 12.38]
# ['MCBC', 10.8, 11.0]
# ['MFNC', 15.8, 18.25]
# ['MTSI', 23.37, 19.59]
# ['MGNX', 8.31, 25.2]
# ['MDGL', 92.83, 185.08]
# ['MGLN', 68.38, 75.67]
# ['MGTA', 10.83, 20.0]
# ['MGIC', 9.0, 10.5]
# ['MGYR', 12.03, 13.0]
# ['MHLD', 0.6, 1.0]
# ['MMYT', 27.85, 32.14]
# ['MBUU', 35.16, 48.0]
# ['MLVF', 22.55, 23.0]
# ['TUSK', 1.74, 5.64]
# ['MANH', 75.69, 96.67]
# ['LOAN', 6.38, 7.5]
# ['MNTX', 5.94, 7.0]
# ['MNKD', 1.35, 2.88]
# ['MANT', 75.38, 71.71]
# ['MARA', 1.38, 4.0]
# ['MCHX', 3.57, 7.5]
# ['MRIN', 1.9, 2.0]
# ['MRNS', 1.16, 5.29]
# ['MRKR', 4.05, 13.08]
# ['MKTX', 349.48, 325.0]
# ['MRLN', 22.17, 28.0]
# ['MAR', 132.55, 138.17]
# ['MBII', 1.28, 2.14]
# ['MRTN', 22.59, 24.5]
# ['MMLP', 5.01, 5.5]
# ['MRVL', 27.08, 28.19]
# ['MASI', 141.59, 172.4]
# ['MTCH', 68.31, 81.95]
# ['MTLS', 19.47, 18.97]
# ['MTRX', 18.41, 27.5]
# ['MAT', 12.26, 13.96]
# ['MATW', 38.64, 55.0]
# ['MXIM', 60.3, 63.71]
# ['MCFT', 17.83, 21.75]
# ['MGRC', 75.25, 85.5]
# ['MDCA', 2.91, 3.0]
# ['MFIN', 7.09, 9.88]
# ['MTBC', 3.74, 7.38]
# ['MNOV', 7.93, 20.0]
# ['MDWD', 2.86, 7.7]
# ['MEDP', 71.75, 81.0]
# ['MEIP', 1.85, 8.5]
# ['MGTX', 14.57, 35.25]
# ['MLCO', 21.97, 28.36]
# ['MLNT', 2.55, 12.33]
# ['MLNX', 114.95, 123.75]
# ['MELR', 17.67, 19.0]
# ['MNLO', 5.19, 17.83]
# ['MELI', 487.45, 654.11]
# ['AMTB', 21.65, 19.88]
# ['MBWM', 36.39, 35.4]
# ['MERC', 12.99, 14.3]
# ['MBIN', 17.14, 20.67]
# ['MRCY', 70.63, 83.0]
# ['EBSB', 20.04, 19.67]
# ['VIVO', 9.65, 10.67]
# ['MRBK', 18.0, 21.67]
# ['MMSI', 27.1, 33.29]
# ['MACK', 3.94, 4.0]
# ['MRSN', 1.95, 9.25]
# ['MRUS', 15.5, 23.43]
# ['MESA', 7.36, 12.17]
# ['MLAB', 228.01, 262.67]
# ['MESO', 6.16, 12.8]
# ['CASH', 32.37, 40.0]
# ['MEOH', 41.0, 42.87]
# ['MGEE', 74.33, 50.0]
# ['MGPI', 46.26, 85.0]
# ['MBOT', 5.09, 10.0]
# ['MCHP', 96.1, 108.15]
# ['MSFT', 143.84, 160.16]
# ['MSTR', 155.8, 165.67]
# ['MVIS', 0.73, 2.56]
# ['MCEP', 0.358, 0.78]
# ['MBCN', 46.45, 49.25]
# ['MSEX', 63.49, 73.0]
# ['MSBI', 27.94, 30.25]
# ['MOFG', 35.03, 35.6]
# ['MIME', 40.22, 55.53]
# ['MDXG', 5.55, 18.0]
# ['NERV', 5.2, 19.2]
# ['MGEN', 0.74, 11.0]
# ['MRTX', 99.0, 114.54]
# ['MSON', 16.83, 28.33]
# ['MIND', 2.3541, 7.0]
# ['MITK', 9.47, 15.13]
# ['MMAC', 32.36, 27.0]
# ['MINI', 38.64, 47.17]
# ['MOBL', 4.9, 7.3]
# ['MTEM', 8.54, 20.2]
# ['MBRX', 1.07, 4.33]
# ['MNTA', 15.8, 24.43]
# ['MOMO', 38.15, 42.23]
# ['MKGI', 2.47, 3.75]
# ['MCRI', 43.53, 46.75]
# ['MDLZ', 52.17, 61.16]
# ['MGI', 3.58, 3.33]
# ['MDB', 125.51, 164.69]
# ['MPWR', 162.61, 168.57]
# ['MNRO', 72.84, 73.6]
# ['MRCC', 11.1, 12.63]
# ['MNST', 56.0, 66.79]
# ['MORN', 161.94, 75.0]
# ['MOSY', 2.17, 1.0]
# ['MTFB', 0.17, 3.5]
# ['MPAA', 20.49, 26.0]
# ['MOTS', 1.85, 8.1]
# ['MPVD', 0.8802, 7.0]
# ['COOP', 12.85, 14.83]
# ['MTSC', 60.12, 63.0]
# ['MBIO', 2.71, 10.67]
# ['MFSF', 40.25, 36.13]
# ['MVBF', 20.25, 20.5]
# ['MYSZ', 0.4011, 0.15]
# ['MYL', 17.21, 25.81]
# ['MYOK', 57.28, 81.45]
# ['MYOS', 1.612, 3.75]
# ['MYRG', 34.33, 36.75]
# ['MYGN', 23.48, 25.5]
# ['NBRV', 1.96, 8.42]
# ['NNDM', 3.02, 19.0]
# ['NSTG', 25.1, 34.5]
# ['NAOV', 2.785, 10.5]
# ['NH', 0.71, 1.13]
# ['NK', 1.11, 1.02]
# ['NSSC', 28.68, 34.67]
# ['NDAQ', 100.44, 106.38]
# ['NTRA', 38.01, 40.0]
# ['NAUH', 0.0361, 4.0]
# ['NKSH', 43.59, 44.0]
# ['FIZZ', 44.58, 43.25]
# ['NCMI', 7.48, 9.5]
# ['NESR', 7.36, 16.75]
# ['NGHC', 22.04, 29.75]
# ['NATI', 42.9, 45.33]
# ['EYE', 28.44, 36.1]
# ['NHTC', 7.02, 0.0]
# ['NATR', 10.1, 15.0]
# ['NAVI', 14.36, 16.44]
# ['NBTB', 40.77, 40.5]
# ['NCSM', 2.36, 2.98]
# ['NKTR', 18.95, 33.38]
# ['NEOG', 65.53, 71.0]
# ['NEO', 22.76, 28.57]
# ['NTGN', 1.96, 17.78]
# ['NEON', 1.69, 3.0]
# ['NEOS', 1.5, 7.0]
# ['NVCN', 3.68, 1.88]
# ['UEPS', 2.98, 7.0]
# ['NETE', 4.4116, 90.7]
# ['NTAP', 58.37, 54.16]
# ['NFLX', 290.7, 361.63]
# ['NTGR', 27.53, 35.0]
# ['NTCT', 25.03, 27.5]
# ['NTWK', 5.64, 10.0]
# ['NBIX', 102.98, 114.44]
# ['NURO', 0.2823, 5.0]
# ['STIM', 5.2, 11.75]
# ['NTRP', 0.6896, 1.0]
# ['NBEV', 2.68, 7.0]
# ['NYMT', 6.16, 6.17]
# ['NLNK', 1.55, 4.0]
# ['NMRK', 11.7, 13.63]
# ['NWSA', 13.59, 14.68]
# ['NEWT', 22.8, 21.17]
# ['NXST', 99.58, 135.33]
# ['NEXT', 6.1, 6.63]
# ['NXGN', 17.15, 18.0]
# ['EGOV', 22.75, 23.67]
# ['NICE', 158.93, 157.42]
# ['NICK', 8.97, 8.0]
# ['NCBS', 70.19, 68.0]
# ['NIHD', 1.76, 1.25]
# ['NIU', 9.45, 13.33]
# ['LASR', 16.93, 18.57]
# ['NMIH', 31.0, 35.14]
# ['NNBR', 7.69, 16.67]
# ['NDSN', 163.97, 147.8]
# ['NBN', 23.11, 25.0]
# ['NTIC', 11.95, 16.0]
# ['NTRS', 106.92, 104.78]
# ['NFBK', 17.06, 15.88]
# ['NRIM', 39.66, 40.0]
# ['NWBI', 17.15, 15.83]
# ['NWPX', 33.6, 41.0]
# ['NCLH', 53.21, 64.35]
# ['NWFL', 34.01, 0.0]
# ['NVMI', 34.73, 37.5]
# ['NOVN', 2.15, 6.0]
# ['NOVT', 82.93, 79.5]
# ['NVAX', 4.44, 14.25]
# ['NVCR', 77.34, 86.57]
# ['NVUS', 0.6285, 6.88]
# ['NUAN', 16.34, 19.5]
# ['NCNA', 6.91, 1763.42]
# ['NTNX', 27.6, 34.94]
# ['NUVA', 71.88, 71.6]
# ['NVTR', 1.38, 6.0]
# ['NVEE', 69.41, 94.0]
# ['NVEC', 64.0, 79.0]
# ['NVDA', 211.11, 197.43]
# ['NXPI', 118.19, 127.57]
# ['NXTD', 0.4349, 2.0]
# ['OIIM', 1.58, 4.0]
# ['OCSL', 5.2, 6.0]
# ['OCSI', 8.16, 8.75]
# ['OBLN', 1.89, 19.5]
# ['OBSV', 5.02, 28.14]
# ['OPTT', 1.53, 6.0]
# ['OCFC', 24.18, 26.29]
# ['OCUL', 3.44, 6.8]
# ['ODT', 31.36, 46.5]
# ['OMEX', 4.04, 3.5]
# ['ODP', 2.5, 2.03]
# ['OFS', 11.98, 12.5]
# ['OHAI', 1.32, 6.5]
# ['OKTA', 107.45, 142.63]
# ['ODFL', 194.17, 186.5]
# ['OLBK', 30.01, 32.75]
# ['ONB', 18.62, 18.31]
# ['OSBC', 12.69, 14.3]
# ['OLLI', 66.04, 72.67]
# ['ZEUS', 15.71, 13.75]
# ['OMER', 13.01, 37.2]
# ['OMCL', 74.58, 84.25]
# ['ON', 21.89, 23.75]
# ['ONTX', 0.51, 13.42]
# ['ONCS', 2.1, 7.67]
# ['OSS', 2.31, 4.5]
# ['OSPN', 19.28, 24.8]
# ['OPBK', 9.8, 11.0]
# ['OTEX', 41.0, 47.0]
# ['OPRA', 8.91, 16.75]
# ['OPGN', 1.19, 16.25]
# ['OPNT', 15.25, 40.0]
# ['OPK', 1.5, 4.67]
# ['OBAS', 12.13, 5.9]
# ['OPRX', 10.87, 21.67]
# ['OPTN', 9.74, 23.4]
# ['OPB', 25.5, 24.75]
# ['ORMP', 3.09, 13.5]
# ['OSUR', 8.91, 7.5]
# ['ORBC', 4.67, 7.75]
# ['ORTX', 11.97, 25.33]
# ['ORLY', 443.1, 458.0]
# ['ONVO', 0.399, 3.0]
# ['ORGS', 3.48, 9.5]
# ['SEED', 5.74, 5.0]
# ['OBNK', 35.53, 37.0]
# ['OESX', 2.74, 4.13]
# ['ORIT', 19.45, 17.0]
# ['ORRF', 21.49, 24.5]
# ['OFIX', 44.32, 62.0]
# ['KIDS', 34.7, 45.6]
# ['OSIS', 96.83, 115.25]
# ['OSMT', 4.05, 8.5]
# ['OTIC', 2.29, 8.0]
# ['OTTR', 51.29, 54.0]
# ['OSTK', 10.2, 48.0]
# ['OVID', 2.62, 12.33]
# ['OXBR', 0.961, 8.5]
# ['OXFD', 16.81, 20.0]
# ['OXLC', 9.36, 10.0]
# ['OXSQ', 5.46, 5.0]
# ['PTSI', 56.95, 55.0]
# ['PCAR', 80.0, 73.21]
# ['PACB', 4.84, 7.63]
# ['PCB', 17.0, 18.33]
# ['PEIX', 0.585, 4.5]
# ['PMBC', 7.28, 8.88]
# ['PPBI', 34.64, 35.0]
# ['PCRX', 38.21, 55.43]
# ['PACW', 39.36, 39.67]
# ['PAAS', 16.79, 21.52]
# ['PANL', 3.355, 4.85]
# ['PZZA', 61.09, 65.82]
# ['PRTK', 4.15, 19.67]
# ['TEUM', 0.455, 4.63]
# ['PCYG', 5.46, 10.75]
# ['PKBK', 24.1, 13.0]
# ['PKOH', 32.7, 39.67]
# ['PTNR', 4.49, 22.0]
# ['PATK', 52.78, 55.71]
# ['PNBK', 12.9, 24.0]
# ['PATI', 18.01, 30.0]
# ['PEGI', 27.16, 26.59]
# ['PDCO', 18.68, 19.75]
# ['PTEN', 9.16, 10.2]
# ['PAVM', 0.91, 3.0]
# ['PAYX', 83.2, 83.35]
# ['PCTY', 103.7, 115.69]
# ['PYPL', 100.94, 125.38]
# ['CNXN', 48.61, 52.0]
# ['PCSB', 20.32, 21.5]
# ['PCTI', 6.98, 8.0]
# ['PDCE', 23.09, 43.51]
# ['PDFS', 15.92, 19.38]
# ['PDLI', 2.77, 3.0]
# ['PDLB', 13.77, 16.0]
# ['PGC', 30.39, 31.88]
# ['PEGA', 75.87, 85.25]
# ['PENN', 22.02, 26.67]
# ['PVAC', 27.75, 47.0]
# ['PFLT', 11.73, 13.0]
# ['PNNT', 6.1, 7.44]
# ['PEBO', 33.42, 34.25]
# ['PEBK', 29.32, 13.0]
# ['PBCT', 16.98, 16.77]
# ['PUB', 30.0, 31.0]
# ['PEP', 134.41, 139.67]
# ['PRCP', 4.5, 9.0]
# ['PRFT', 39.49, 45.5]
# ['PFMT', 1.02, 3.0]
# ['PESI', 5.67, 5.0]
# ['PPIH', 9.11, 32.0]
# ['PETQ', 25.81, 41.0]
# ['PETS', 23.52, 22.33]
# ['PFSW', 3.35, 4.63]
# ['PGTI', 16.0, 19.43]
# ['PHAS', 4.2, 20.0]
# ['PAHC', 22.84, 20.5]
# ['PLAB', 12.3, 12.67]
# ['PICO', 10.74, 31.0]
# ['PIRS', 3.95, 7.33]
# ['PPC', 31.4, 35.43]
# ['PDD', 44.16, 37.8]
# ['PME', 2.0, 15.0]
# ['PNFP', 61.02, 64.9]
# ['PPSI', 3.4, 7.5]
# ['PXLW', 3.18, 5.13]
# ['PLYA', 7.69, 10.1]
# ['PLXS', 75.93, 74.0]
# ['PLUG', 2.72, 3.53]
# ['PS', 17.93, 26.29]
# ['PSTI', 3.4296, 18.5]
# ['PLXP', 4.4878, 14.0]
# ['PCOM', 10.88, 14.5]
# ['POLA', 3.07, 6.5]
# ['PTE', 3.0, 23.33]
# ['POOL', 203.11, 209.4]
# ['POPE', 83.98, 15.0]
# ['BPOP', 56.02, 65.25]
# ['PTLA', 28.52, 40.0]
# ['PBPB', 4.99, 5.33]
# ['PCH', 44.01, 45.33]
# ['POWL', 40.11, 44.5]
# ['POWI', 94.29, 89.8]
# ['PRAA', 34.52, 35.0]
# ['PRAH', 97.72, 114.58]
# ['PRPO', 2.37, 6.3]
# ['PFBC', 55.05, 55.5]
# ['PFBI', 18.01, 0.0]
# ['PINC', 37.29, 42.33]
# ['PSDO', 16.57, 16.4]
# ['PRGX', 4.94, 7.13]
# ['PSMT', 77.08, 78.0]
# ['PRMW', 11.22, 15.67]
# ['PRIM', 22.96, 28.25]
# ['PFG', 56.68, 58.15]
# ['PRNB', 32.89, 50.0]
# ['PDEX', 13.85, 19.0]
# ['IPDN', 1.2237, 36.0]
# ['PFIE', 1.8, 3.12]
# ['PGNX', 5.86, 9.3]
# ['PRGS', 40.71, 51.0]
# ['PFPT', 115.07, 141.84]
# ['PRPH', 1.9, 15.55]
# ['PRQR', 7.83, 29.37]
# ['PSEC', 6.42, 6.0]
# ['PTGX', 12.0, 20.17]
# ['PTVCB', 16.25, 28.53]
# ['PRTO', 0.264, 1.0]
# ['PTI', 0.9, 8.5]
# ['PRTA', 9.18, 14.5]
# ['PRVB', 8.28, 21.83]
# ['PROV', 21.05, 22.5]
# ['PMD', 9.56, 32.0]
# ['PTC', 72.22, 87.77]
# ['PTCT', 40.13, 50.63]
# ['PULM', 0.815, 10.0]
# ['PBYI', 6.76, 13.88]
# ['PCYO', 11.49, 6.55]
# ['PRPL', 8.37, 12.0]
# ['PXS', 1.25, 2.25]
# ['QADA', 48.27, 50.75]
# ['QADB', 37.0, 52.0]
# ['QCRH', 42.0, 44.86]
# ['QGEN', 31.1, 31.3]
# ['QIWI', 18.55, 29.84]
# ['QRVO', 102.0, 90.2]
# ['QCOM', 89.83, 87.11]
# ['QBAK', 5.48, 12.0]
# ['QLYS', 84.41, 93.95]
# ['QTRX', 20.25, 33.75]
# ['QTRH', 1.37, 2.44]
# ['QRHC', 2.2676, 3.75]
# ['QUIK', 0.321, 0.78]
# ['QDEL', 59.05, 69.67]
# ['QNST', 13.2, 17.83]
# ['QUMU', 2.7, 6.0]
# ['QTNT', 7.26, 13.5]
# ['QRTEA', 9.62, 17.33]
# ['QTT', 3.63, 4.93]
# ['RRD', 3.93, 6.5]
# ['RCM', 11.75, 15.2]
# ['RARX', 46.9, 48.0]
# ['RADA', 5.31, 7.5]
# ['RDCM', 9.41, 12.0]
# ['RDUS', 23.62, 33.57]
# ['RDNT', 16.55, 18.0]
# ['RDWR', 24.06, 31.75]
# ['METC', 3.57, 6.61]
# ['RMBS', 14.57, 15.17]
# ['GOLD', 16.9, 20.38]
# ['RNDB', 15.31, 15.0]
# ['RPD', 50.55, 68.44]
# ['RAVE', 2.6104, 2.5]
# ['RAVN', 35.77, 36.0]
# ['RBB', 20.6, 22.13]
# ['ROLL', 167.02, 166.0]
# ['RICK', 19.8, 33.0]
# ['RCMT', 2.91, 6.5]
# ['RDI', 11.79, 15.0]
# ['RGSE', 0.1046, 2.0]
# ['RNWK', 1.61, 6.5]
# ['RP', 51.65, 70.67]
# ['RETA', 201.24, 219.5]
# ['RCON', 0.67, 2.01]
# ['REPH', 15.87, 15.6]
# ['RRGB', 27.95, 32.67]
# ['RRR', 21.7, 24.11]
# ['RDFN', 20.0, 23.37]
# ['RDHL', 7.05, 21.88]
# ['REGN', 329.18, 386.75]
# ['RGNX', 36.48, 76.33]
# ['RGLS', 0.671, 1.5]
# ['RBNC', 22.65, 25.58]
# ['RELV', 4.37, 21.0]
# ['MARK', 0.81, 5.0]
# ['RNST', 36.16, 35.57]
# ['REGI', 17.36, 27.25]
# ['RCII', 23.08, 29.0]
# ['RGEN', 81.46, 105.25]
# ['REPL', 17.1, 26.29]
# ['FRBK', 4.18, 4.25]
# ['REFR', 3.61, 3.0]
# ['RSLS', 0.057, 32.0]
# ['RESN', 2.4, 4.8]
# ['RECN', 14.8, 15.5]
# ['HAIR', 0.4, 1.0]
# ['TORC', 7.87, 24.33]
# ['ROIC', 18.38, 19.38]
# ['RTRX', 12.56, 28.57]
# ['RVNC', 15.38, 35.56]
# ['RVLT', 0.124, 2.0]
# ['RWLK', 2.57, 9.0]
# ['RGCO', 29.43, 30.0]
# ['RYTM', 21.21, 37.57]
# ['RBBN', 4.27, 6.33]
# ['RIBT', 2.82, 4.5]
# ['RIGL', 2.14, 8.14]
# ['RNET', 5.2, 19.0]
# ['RMNI', 4.0, 9.17]
# ['RIOT', 1.57, 3.5]
# ['REDU', 7.63, 8.31]
# ['RTTR', 0.279, 7.0]
# ['RVSB', 7.5, 8.0]
# ['RCKT', 14.85, 31.75]
# ['RMTI', 1.99, 10.67]
# ['RCKY', 30.64, 31.0]
# ['RMCF', 8.56, 18.0]
# ['ROKU', 118.75, 137.29]
# ['ROSE', 1.69, 4.5]
# ['ROST', 112.35, 111.9]
# ['RGLD', 109.3, 121.08]
# ['RTIX', 1.87, 5.75]
# ['RBCN', 8.38, 0.75]
# ['RUBY', 10.31, 24.0]
# ['RMBL', 2.69, 8.7]
# ['RUSHA', 45.32, 51.83]
# ['RUTH', 25.15, 25.0]
# ['RYAAY', 84.7, 81.43]
# ['STBA', 38.64, 41.5]
# ['SANW', 2.12, 5.3]
# ['SBRA', 23.11, 22.23]
# ['SABR', 22.5, 26.5]
# ['SAEX', 1.73, 580.5]
# ['SAFT', 98.8, 70.0]
# ['SAGE', 139.62, 203.28]
# ['SAIA', 97.98, 98.73]
# ['SALM', 1.49, 3.63]
# ['SAL', 41.6, 45.75]
# ['SAFM', 157.0, 161.75]
# ['SASR', 36.03, 38.17]
# ['SGMO', 9.87, 20.67]
# ['SANM', 32.53, 34.67]
# ['SPNS', 23.2, 20.19]
# ['SRPT', 93.23, 187.32]
# ['SVRA', 0.9, 8.5]
# ['SBFG', 17.35, 20.0]
# ['SBBX', 22.57, 25.88]
# ['SBAC', 230.1, 257.73]
# ['SCSC', 33.92, 41.0]
# ['SCHN', 21.97, 20.5]
# ['SRRK', 9.63, 31.67]
# ['SCHL', 38.89, 39.0]
# ['SGMS', 26.66, 29.44]
# ['SCPH', 5.15, 9.75]
# ['SCYX', 1.32, 5.36]
# ['SEAC', 3.0, 2.0]
# ['SBCF', 29.7, 29.08]
# ['STX', 58.23, 55.1]
# ['SHIP', 0.56, 1.3]
# ['SPNE', 13.29, 21.0]
# ['SGEN', 108.25, 110.13]
# ['EYES', 0.86, 2.5]
# ['SECO', 5.7, 8.75]
# ['SCWX', 12.14, 13.71]
# ['SEIC', 62.99, 63.6]
# ['SLCT', 11.75, 13.5]
# ['SIC', 10.6, 16.0]
# ['SELB', 1.52, 10.6]
# ['SIGI', 69.24, 73.67]
# ['SLS', 0.135, 1.75]
# ['LEDS', 2.72, 3.0]
# ['SMTC', 54.19, 53.33]
# ['SNES', 0.716, 2.17]
# ['SNH', 9.07, 9.42]
# ['SRTS', 4.95, 10.42]
# ['SQBG', 0.3959, 0.3]
# ['MCRB', 3.71, 8.67]
# ['SREV', 1.19, 1.5]
# ['SFBS', 36.59, 36.88]
# ['SESN', 1.15, 3.58]
# ['SGBX', 0.4189, 6.0]
# ['SMED', 4.65, 5.33]
# ['SHSP', 9.02, 17.17]
# ['SHEN', 38.63, 46.5]
# ['SHLO', 3.84, 5.0]
# ['SCVL', 36.26, 35.5]
# ['SHBI', 16.2, 18.0]
# ['SSTI', 19.51, 43.63]
# ['SIBN', 18.9, 26.0]
# ['SNNA', 0.17, 5.0]
# ['SIEN', 7.06, 13.43]
# ['BSRR', 28.13, 28.75]
# ['SRRA', 0.29, 3.0]
# ['SWIR', 8.9, 12.2]
# ['SIFY', 1.34, 4.0]
# ['SIGA', 5.53, 11.0]
# ['SGLB', 0.55, 2.0]
# ['SBNY', 125.72, 139.65]
# ['SLGN', 31.03, 32.91]
# ['SILC', 33.01, 50.0]
# ['SLAB', 109.82, 122.63]
# ['SIMO', 42.18, 47.6]
# ['SAMG', 13.23, 17.0]
# ['SSNT', 3.4263, 5.0]
# ['SFNC', 25.96, 27.83]
# ['SLP', 33.15, 37.0]
# ['SINA', 42.83, 58.6]
# ['SBGI', 38.02, 55.56]
# ['SINO', 0.72, 1.75]
# ['SVA', 6.49, 6.0]
# ['SIRI', 6.79, 7.2]
# ['SITO', 0.6291, 2.25]
# ['SKYS', 0.6211, 5.0]
# ['SKYW', 62.8, 73.88]
# ['SWKS', 99.2, 87.52]
# ['SNBR', 49.0, 44.57]
# ['SLM', 8.99, 12.33]
# ['SGH', 31.86, 33.6]
# ['SND', 2.65, 3.71]
# ['SMBK', 22.62, 23.63]
# ['SMSI', 4.74, 7.75]
# ['SMTX', 2.26, 6.0]
# ['SRAX', 1.56, 10.0]
# ['SCKT', 1.73, 6.0]
# ['SOHU', 11.73, 19.16]
# ['SLRC', 20.8, 22.39]
# ['SUNS', 17.71, 18.5]
# ['SEDG', 78.19, 90.25]
# ['SLNO', 1.51, 12.0]
# ['SLGL', 8.28, 19.2]
# ['SLDB', 10.65, 12.38]
# ['SNGX', 0.99, 5.63]
# ['SOFO', 1.1, 10.4]
# ['SNOA', 5.8, 9.0]
# ['SONO', 15.0, 16.83]
# ['SPHS', 0.4902, 3.5]
# ['SORL', 3.42, 10.0]
# ['SRNE', 1.66, 24.5]
# ['SOHO', 6.52, 7.63]
# ['SSB', 82.88, 78.8]
# ['SFST', 41.93, 45.63]
# ['SMBC', 36.81, 39.5]
# ['SONA', 15.85, 16.0]
# ['SBSI', 35.16, 34.8]
# ['SP', 46.24, 51.0]
# ['SPKE', 9.51, 10.0]
# ['ONCE', 111.62, 105.79]
# ['SPTN', 13.18, 12.6]
# ['SPPI', 8.03, 24.5]
# ['SPRO', 10.82, 24.0]
# ['ANY', 1.01, 5.0]
# ['SPEX', 1.28, 19.0]
# ['SAVE', 39.41, 45.21]
# ['STXB', 21.71, 24.88]
# ['SPLK', 123.45, 149.99]
# ['SPOK', 12.17, 7.0]
# ['SPWH', 7.3, 7.0]
# ['SBPH', 3.39, 21.0]
# ['SFM', 20.02, 19.88]
# ['SPSC', 53.87, 60.44]
# ['SSNC', 57.51, 64.87]
# ['SSRM', 14.74, 11.75]
# ['STAA', 36.0, 46.0]
# ['STAF', 0.92, 4.25]
# ['STMP', 84.0, 81.0]
# ['SBLK', 10.42, 14.15]
# ['SBUX', 83.06, 94.58]
# ['STFC', 32.74, 33.33]
# ['GASS', 3.3416, 6.0]
# ['STCN', 1.4, 22.5]
# ['STLD', 31.26, 33.5]
# ['SMRT', 0.7881, 2.0]
# ['STML', 10.29, 28.71]
# ['SRCL', 62.82, 58.8]
# ['SBT', 10.03, 12.17]
# ['STRL', 15.83, 25.0]
# ['SHOO', 42.69, 41.22]
# ['SFIX', 23.07, 27.18]
# ['SYBT', 41.21, 38.0]
# ['BANX', 22.85, 23.67]
# ['STNE', 34.25, 35.39]
# ['SSKN', 2.73, 5.0]
# ['SSYS', 21.16, 25.5]
# ['STRA', 132.22, 186.67]
# ['STRT', 23.95, 52.0]
# ['STRM', 1.33, 2.75]
# ['SBBP', 1.77, 8.86]
# ['SUMR', 0.3037, 1.0]
# ['SMMF', 26.39, 26.5]
# ['SSBI', 12.6, 7.2]
# ['SMMT', 1.69, 3.0]
# ['WISA', 0.765, 3.0]
# ['SNDE', 1.05, 5.17]
# ['SNSS', 0.46, 3.83]
# ['STKL', 2.49, 3.67]
# ['SPWR', 8.79, 10.06]
# ['RUN', 14.96, 22.4]
# ['SUNW', 1.88, 9.8]
# ['SPCB', 0.656, 2.5]
# ['SCON', 0.19, 9.0]
# ['SGC', 16.3, 20.0]
# ['SUPN', 20.0, 33.33]
# ['SPRT', 1.69, 3.0]
# ['SURF', 1.69, 10.5]
# ['SGRY', 10.59, 12.5]
# ['SRDX', 39.51, 62.75]
# ['STRO', 10.51, 22.86]
# ['SIVB', 235.5, 247.32]
# ['SVMK', 17.64, 21.5]
# ['SYKE', 37.51, 37.33]
# ['SYMC', 23.59, 22.86]
# ['SYNC', 1.54, 2.33]
# ['SYNL', 15.21, 11.0]
# ['SYNA', 47.2, 39.0]
# ['SNCR', 4.47, 11.33]
# ['SNDX', 7.06, 14.5]
# ['SYNH', 48.25, 58.55]
# ['SYBX', 2.26, 9.83]
# ['SNPS', 137.06, 149.72]
# ['SES', 7.11, 6.0]
# ['SYPR', 1.0, 1.25]
# ['SYRS', 5.28, 13.5]
# ['TROW', 121.15, 118.64]
# ['TTOO', 2.77, 8.09]
# ['TRHC', 51.59, 80.9]
# ['TCMD', 51.27, 74.33]
# ['TTWO', 117.86, 137.2]
# ['TLND', 37.79, 52.17]
# ['TNDM', 58.06, 77.83]
# ['TLF', 5.15, 3.5]
# ['TAOP', 0.5172, 9.0]
# ['TEDU', 0.8201, 6.18]
# ['CGBD', 13.75, 14.85]
# ['AMTD', 40.24, 39.17]
# ['TECD', 126.23, 118.2]
# ['TTGT', 26.94, 28.33]
# ['TGLS', 8.57, 11.08]
# ['TGEN', 2.47, 6.0]
# ['TNAV', 4.68, 6.25]
# ['TLGT', 0.6811, 3.5]
# ['TELL', 7.82, 11.32]
# ['TENB', 25.7, 35.0]
# ['TENX', 1.29, 4.22]
# ['TERP', 16.61, 16.69]
# ['TBNK', 30.62, 30.0]
# ['TSLA', 329.14, 259.28]
# ['TESS', 12.43, 20.0]
# ['TTEK', 88.14, 89.83]
# ['TTPH', 3.23, 1.5]
# ['TCBI', 59.18, 59.53]
# ['TXN', 120.94, 126.46]
# ['TXRH', 59.31, 58.85]
# ['TFSL', 19.57, 20.0]
# ['TGTX', 7.67, 22.75]
# ['ANDE', 21.41, 25.33]
# ['TBBK', 11.5, 12.0]
# ['BPRN', 28.71, 29.25]
# ['CG', 27.82, 29.68]
# ['CAKE', 43.71, 46.63]
# ['CHEF', 35.37, 41.5]
# ['TCFC', 33.69, 35.33]
# ['DSGX', 39.21, 42.82]
# ['DXYN', 1.96, 5.0]
# ['ENSG', 42.29, 49.0]
# ['XONE', 7.33, 11.5]
# ['FBMS', 33.56, 37.94]
# ['FLIC', 24.12, 23.75]
# ['GT', 16.95, 18.86]
# ['HABT', 10.99, 13.29]
# ['HCKT', 15.15, 20.33]
# ['HAIN', 24.8, 21.79]
# ['CUBA', 6.71, 9.75]
# ['JYNT', 20.11, 25.0]
# ['KHC', 33.17, 31.14]
# ['LOVE', 13.97, 35.83]
# ['MSG', 277.69, 354.49]
# ['MDCO', 53.84, 69.46]
# ['MEET', 4.5, 6.2]
# ['MIK', 9.7, 9.05]
# ['MIDD', 117.2, 139.88]
# ['STKS', 3.2, 4.67]
# ['PRSC', 68.5, 90.0]
# ['RMR', 48.99, 47.36]
# ['SMPL', 23.72, 30.29]
# ['TSG', 21.61, 27.78]
# ['TTD', 193.19, 276.0]
# ['YORW', 42.66, 38.0]
# ['TXMD', 2.85, 10.33]
# ['TRPX', 2.43, 18.0]
# ['TBPH', 17.31, 32.67]
# ['TCRD', 6.89, 7.31]
# ['TTS', 1.83, 4.0]
# ['TLRY', 23.03, 38.42]
# ['TSBK', 28.29, 12.5]
# ['TITN', 17.47, 24.0]
# ['TTNP', 0.178, 6.97]
# ['TVTY', 17.78, 31.0]
# ['TIVO', 8.31, 22.0]
# ['TLSA', 2.86, 10.0]
# ['TMUS', 82.4, 89.74]
# ['TOCA', 0.66, 1.0]
# ['TNXP', 3.0, 45.0]
# ['TOPS', 1.48, 6.0]
# ['TRCH', 0.81, 2.85]
# ['TRMD', 9.59, 16.0]
# ['TSEM', 22.23, 24.32]
# ['CLUB', 1.57, 3.0]
# ['TOWN', 28.81, 28.0]
# ['TPIC', 18.5, 26.4]
# ['TCON', 0.4, 1.67]
# ['TSCO', 96.03, 110.09]
# ['TWMC', 2.85, 2.75]
# ['TACT', 11.0, 14.0]
# ['TRNS', 31.3, 32.42]
# ['TGA', 1.23, 2.17]
# ['TBIO', 9.3, 19.17]
# ['TA', 10.78, 34.0]
# ['TZOO', 10.05, 10.0]
# ['TRMT', 4.85, 5.25]
# ['TRVN', 0.8, 3.75]
# ['TPCO', 9.49, 15.17]
# ['TCDA', 39.5, 50.0]
# ['TCBK', 38.62, 40.0]
# ['TRIL', 0.27, 11.02]
# ['TRS', 30.9, 33.0]
# ['TRMB', 40.34, 44.33]
# ['TRIB', 0.8844, 6.0]
# ['TRIP', 36.2, 44.91]
# ['TSC', 24.16, 25.6]
# ['TBK', 33.84, 34.07]
# ['TRVG', 2.73, 3.44]
# ['TROV', 1.68, 14.5]
# ['TRUE', 3.69, 4.9]
# ['THST', 1.15, 1.83]
# ['TRUP', 30.0, 36.88]
# ['TRST', 8.8, 8.5]
# ['TRMK', 35.63, 34.0]
# ['TTEC', 48.91, 56.33]
# ['TTMI', 12.64, 14.69]
# ['TCX', 56.25, 76.01]
# ['TUES', 1.56, 2.85]
# ['TOUR', 3.11, 4.24]
# ['HEAR', 10.5, 20.8]
# ['FOX', 33.15, 51.5]
# ['FOXA', 33.95, 38.16]
# ['TWIN', 11.87, 14.5]
# ['TWST', 21.76, 34.33]
# ['TRCB', 21.17, 18.0]
# ['TYME', 1.26, 8.5]
# ['USCR', 53.5, 57.57]
# ['PRTS', 1.85, 5.0]
# ['USEG', 0.3703, 3.9]
# ['USAU', 0.8, 2.7]
# ['UFPT', 41.73, 48.0]
# ['ULTA', 246.59, 288.68]
# ['UCTT', 23.29, 21.7]
# ['RARE', 37.85, 70.17]
# ['UMBF', 67.78, 67.43]
# ['UMPQ', 16.84, 17.45]
# ['QURE', 50.96, 82.13]
# ['UBCP', 12.4, 0.0]
# ['UBSI', 40.6, 36.67]
# ['UCBI', 31.08, 32.14]
# ['UCFC', 11.59, 12.82]
# ['UAL', 94.0, 109.88]
# ['UBNK', 14.44, 15.0]
# ['UFCS', 45.63, 46.0]
# ['UIHC', 12.95, 13.0]
# ['UNFI', 8.49, 8.0]
# ['UBFO', 10.36, 0.0]
# ['UTHR', 90.82, 128.0]
# ['UNIT', 7.09, 8.0]
# ['UNTY', 21.35, 24.5]
# ['UBX', 6.88, 19.0]
# ['OLED', 199.99, 206.7]
# ['UEIC', 53.75, 55.67]
# ['UFPI', 51.83, 51.33]
# ['ULH', 20.59, 28.0]
# ['USAP', 14.18, 20.5]
# ['UVSP', 26.47, 27.5]
# ['UMRX', 1.22, 11.0]
# ['UPLD', 39.17, 54.63]
# ['UPWK', 13.75, 20.56]
# ['UONEK', 2.24, 6.0]
# ['URBN', 30.7, 27.69]
# ['URGN', 23.17, 59.29]
# ['UROV', 10.41, 24.0]
# ['ECOL', 61.98, 68.5]
# ['USAT', 7.2, 9.5]
# ['USAK', 7.27, 11.25]
# ['UTSI', 2.98, 4.5]
# ['UXIN', 3.27, 4.97]
# ['VCNX', 5.45, 21.33]
# ['VLRX', 1.5, 11.0]
# ['VLY', 12.1, 12.28]
# ['VNDA', 14.25, 28.2]
# ['VREX', 31.86, 37.2]
# ['VRNS', 72.83, 83.69]
# ['VBLT', 1.21, 2.94]
# ['VXRT', 0.337, 4.0]
# ['VBIV', 0.5671, 8.25]
# ['VECO', 16.62, 15.38]
# ['VEON', 2.35, 3.52]
# ['VRA', 11.52, 10.67]
# ['VCYT', 23.99, 34.0]
# ['VSTM', 1.1, 2.75]
# ['VCEL', 18.88, 25.5]
# ['VRNT', 47.69, 68.0]
# ['VRSN', 186.85, 235.33]
# ['VRSK', 140.66, 158.4]
# ['VBTX', 25.5, 29.5]
# ['VERI', 2.48, 7.2]
# ['VRML', 0.582, 1.0]
# ['VRNA', 4.74, 29.67]
# ['VRCA', 14.14, 27.0]
# ['VTNR', 1.11, 2.5]
# ['VRTX', 196.4, 228.0]
# ['VERU', 2.0, 7.38]
# ['VIA', 24.57, 78.0]
# ['VIAB', 22.21, 29.27]
# ['VSAT', 67.99, 95.86]
# ['VIAV', 16.0, 17.06]
# ['VICR', 37.16, 41.0]
# ['VCTR', 17.76, 22.8]
# ['VRAY', 2.78, 7.0]
# ['VKTX', 7.44, 24.3]
# ['VIOT', 9.16, 12.41]
# ['VNOM', 24.83, 35.82]
# ['VIRC', 3.9476, 4.75]
# ['VTSI', 3.02, 5.4]
# ['VIRT', 16.36, 19.05]
# ['VRTS', 115.61, 117.6]
# ['VRTU', 39.8, 51.0]
# ['VTGN', 1.08, 2.35]
# ['VC', 94.2, 86.27]
# ['VIVE', 4.98, 400.0]
# ['VVUS', 3.03, 10.0]
# ['VOD', 20.94, 26.77]
# ['VOXX', 4.5392, 5.3]
# ['VYGR', 13.9, 29.83]
# ['VTVT', 1.37, 6.5]
# ['VUZI', 2.4, 4.5]
# ['WBA', 59.82, 56.95]
# ['WAFD', 37.19, 34.33]
# ['WASH', 52.8, 51.75]
# ['WSBF', 18.95, 19.5]
# ['WVE', 26.85, 43.57]
# ['WSTG', 13.55, 19.0]
# ['WDFC', 184.0, 194.5]
# ['WB', 53.14, 52.94]
# ['WEN', 20.85, 22.4]
# ['WERN', 38.37, 39.0]
# ['WSBC', 38.45, 40.8]
# ['WTBA', 24.5, 24.0]
# ['WABC', 67.21, 59.67]
# ['WSTL', 1.28, 5.0]
# ['WDC', 54.56, 61.88]
# ['WNEB', 9.68, 10.25]
# ['WPRT', 2.99, 5.1]
# ['WWR', 2.93, 3.0]
# ['WEYS', 24.59, 26.0]
# ['WHLR', 2.36, 7.0]
# ['WHF', 14.23, 14.9]
# ['WHLM', 5.0, 0.22]
# ['WLDN', 30.33, 43.0]
# ['WLFC', 63.43, 32.0]
# ['WLTW', 187.06, 217.25]
# ['WSC', 16.63, 18.75]
# ['WING', 77.27, 95.88]
# ['WTFC', 68.18, 73.46]
# ['WETF', 5.37, 5.72]
# ['WIX', 127.59, 161.06]
# ['WWD', 111.7, 113.88]
# ['WDAY', 161.49, 213.09]
# ['WKHS', 2.45, 4.0]
# ['WRLD', 99.6, 71.0]
# ['WMGI', 29.64, 28.88]
# ['WSFS', 44.26, 49.15]
# ['WYNN', 125.45, 133.4]
# ['XBIT', 10.36, 13.0]
# ['XELB', 1.79, 5.0]
# ['XEL', 60.59, 65.67]
# ['XNCR', 33.34, 46.63]
# ['XBIO', 1.27, 10.0]
# ['XENE', 9.23, 21.25]
# ['XERS', 9.01, 18.5]
# ['XLNX', 96.28, 108.12]
# ['XOMA', 22.66, 45.0]
# ['XPER', 20.11, 28.25]
# ['XSPA', 1.1001, 18.0]
# ['XTLB', 1.41, 30.0]
# ['XNET', 6.7, 12.0]
# ['YNDX', 34.4, 47.21]
# ['YTRA', 4.16, 7.75]

# %%
for x in price_targets:
    price = x[1]
    est = x[2]
    if est - price > 0 and (est - price) / price > .9 and price > 10:
        print(x)
# Out:
# ['AERI', 19.02, 41.56]
# ['AGIO', 31.78, 65.4]
# ['ALBO', 19.22, 54.43]
# ['ANAB', 37.88, 101.4]
# ['ASMB', 16.2, 43.4]
# ['ATRA', 12.58, 31.0]
# ['ATNX', 11.43, 27.42]
# ['AUTL', 13.09, 33.0]
# ['AVRO', 14.53, 37.78]
# ['AXGN', 13.5, 25.67]
# ['BAND', 43.8, 85.0]
# ['BYSI', 12.71, 41.0]
# ['BPTH', 11.2, 28.0]
# ['BCOR', 19.31, 39.67]
# ['BLUE', 79.38, 155.24]
# ['CDNA', 20.19, 49.2]
# ['CELC', 14.11, 35.5]
# ['CLLS', 12.5, 40.82]
# ['CRNX', 19.08, 39.5]
# ['CSPI', 12.56, 65.0]
# ['EDIT', 20.62, 46.71]
# ['EIGR', 11.29, 36.67]
# ['ESPR', 37.39, 81.23]
# ['FLXS', 18.01, 50.0]
# ['GTHX', 23.07, 66.5]
# ['GBT', 47.77, 91.36]
# ['HIIQ', 23.66, 54.63]
# ['HRTX', 21.07, 42.3]
# ['FIXX', 11.87, 33.4]
# ['INSM', 18.78, 42.56]
# ['NTLA', 12.78, 28.05]
# ['IGLD', 12.7, 44.09]
# ['ITCI', 10.01, 25.22]
# ['IRCP', 11.49, 27.9]
# ['KALV', 10.9, 32.14]
# ['LOGC', 10.01, 22.25]
# ['LORL', 40.21, 89.0]
# ['MDGL', 92.83, 185.08]
# ['MGTX', 14.57, 35.25]
# ['OMER', 13.01, 37.2]
# ['OPNT', 15.25, 40.0]
# ['OPRX', 10.87, 21.67]
# ['ORTX', 11.97, 25.33]
# ['OSTK', 10.2, 48.0]
# ['PICO', 10.74, 31.0]
# ['RGNX', 36.48, 76.33]
# ['RTRX', 12.56, 28.57]
# ['RVNC', 15.38, 35.56]
# ['RCKT', 14.85, 31.75]
# ['RUBY', 10.31, 24.0]
# ['SRPT', 93.23, 187.32]
# ['SSTI', 19.51, 43.63]
# ['SPRO', 10.82, 24.0]
# ['STML', 10.29, 28.71]
# ['STRT', 23.95, 52.0]
# ['STRO', 10.51, 22.86]
# ['LOVE', 13.97, 35.83]
# ['TA', 10.78, 34.0]
# ['HEAR', 10.5, 20.8]
# ['URGN', 23.17, 59.29]
# ['UROV', 10.41, 24.0]
# ['VNDA', 14.25, 28.2]
# ['VRCA', 14.14, 27.0]
# ['VIA', 24.57, 78.0]
# ['VYGR', 13.9, 29.83]
# ['XOMA', 22.66, 45.0]

# %%
parse('AAPL')
# Out:
# OrderedDict([('Previous Close', '256.47'),
#              ('Open', '258.74'),
#              ('Bid', '259.30 x 1800'),
#              ('Ask', '259.49 x 800'),
#              ("Day's Range", '258.12 - 260.35'),
#              ('52 Week Range', '142.00 - 260.35'),
#              ('Volume', '23,735,083'),
#              ('Avg. Volume', '26,934,518'),
#              ('Market Cap', '1.172T'),
#              ('Beta (3Y Monthly)', '1.25'),
#              ('PE Ratio (TTM)', '21.82'),
#              ('EPS (TTM)', 11.89),
#              ('Earnings Date', '2020-01-27 to 2020-01-31'),
#              ('Forward Dividend & Yield', '3.08 (1.24%)'),
#              ('Ex-Dividend Date', '2019-11-07'),
#              ('1y Target Est', 253.16),
#              ('EPS Beat Ratio', '1.0669'),
#              ('ticker', 'AAPL'),
#              ('url', 'https://finance.yahoo.com/quote/AAPL?p=AAPL')])

# %%
analyze('MCD')
# Out:
# Failed to find the company industry.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Invalid figure 'Total Current Assets' passed.
# C:\Users\kevin\Anaconda3\envs\tensorflow_env\lib\site-packages\IPython\core\interactiveshell.py:3334: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# %tb
# Out:
# ---------------------------------------------------------------------------
# SystemExit                                Traceback (most recent call last)
# <ipython-input-2-f6076df39a75> in <module>
# ----> 1 analyze('MCD')
#
# ~\Documents\Projects\Coding Projects\Stock Market\Stock-Market-Analysis\market.py in analyze(ticker, industry)
#     952             industry_debt_to_equity, industry_current_ratio, industry_bvps, industry_beta] = get_industry_averages()
#     953
# --> 954     altman_zscore = get_altman_zscore(ticker)
#     955     print("ANALYSIS FOR " + ticker)
#     956     print("Industry: " + str(industry))
#
# ~\Documents\Projects\Coding Projects\Stock Market\Stock-Market-Analysis\market.py in get_altman_zscore(ticker)
#     512     '''
#     513     # A = working capital / total assets
# --> 514     total_cur_assets = periodic_figure_values(financials_soup(ticker, "bs"), "Total Current Assets")[0]
#     515     total_cur_liabilities = periodic_figure_values(financials_soup(ticker, "bs"), "Total Current Liabilities")[0]
#     516     total_assets = periodic_figure_values(financials_soup(ticker, "bs"), "Total Assets")[0]
#
# ~\Documents\Projects\Coding Projects\Stock Market\Stock-Market-Analysis\market.py in periodic_figure_values(soup, yahoo_figure)
#     126             row = title.parent
#     127         else:
# --> 128             sys.exit("Invalid figure '" + yahoo_figure + "' passed.")
#     129
#     130     cells = row.find_all("td")[1:] # exclude the <td> with figure name
#
# SystemExit: Invalid figure 'Total Current Assets' passed.

# %%
preiodic_figurefinancials_soup('MCD', "bs")
# Out:
# <!DOCTYPE html>
# <html class="NoJs featurephone" id="atomic" lang="en-US"><head prefix="og: http://ogp.me/ns#"><script>window.performance && window.performance.mark && window.performance.mark('PageStart');</script><meta charset="utf-8"/><title>McDonald's Corporation (MCD) Balance Sheet</title><meta content="balance sheet,asset,liabilities,shareholders equity,return on equity,cash equivalents,retained earning" name="keywords"/><meta content="on" http-equiv="x-dns-prefetch-control"/><meta content="on" property="twitter:dnt"/><meta content="90376669494" property="fb:app_id"/><meta content="#400090" name="theme-color"/><meta content="width=device-width, initial-scale=1" name="viewport"/><meta content="Get the annual and quarterly balance sheet of McDonald's Corporation (MCD) including details of assets, liabilities and shareholders' equity." lang="en-US" name="description"/><meta content="guce.yahoo.com" name="oath:guce:consent-host"/><meta content="A9862C0E6E1BE95BCE0BF3D0298FD58B" name="msvalidate.01"/><link href="/manifest.json" rel="manifest"/><link href="//l.yimg.com" rel="dns-prefetch"/><link href="//s.yimg.com" rel="dns-prefetch"/><link href="//csc.beap.bc.yahoo.com" rel="dns-prefetch"/><link href="//geo.query.yahoo.com" rel="dns-prefetch"/><link href="//y.analytics.yahoo.com" rel="dns-prefetch"/><link href="//b.scorecardresearch.com" rel="dns-prefetch"/><link href="//iquery.finance.yahoo.com" rel="dns-prefetch"/><link href="//fc.yahoo.com" rel="dns-prefetch"/><link href="//video-api.yql.yahoo.com" rel="dns-prefetch"/><link href="//yrtas.btrll.com" rel="dns-prefetch"/><link href="//shim.btrll.com" rel="dns-prefetch"/><link href="//consent.cmp.oath.com" rel="dns-prefetch"/><link href="//geo.yahoo.com" rel="dns-prefetch"/><link crossorigin="anonymous" href="//l.yimg.com" rel="preconnect"/><link crossorigin="anonymous" href="//s.yimg.com" rel="preconnect"/><link href="//csc.beap.bc.yahoo.com" rel="preconnect"/><link href="//geo.query.yahoo.com" rel="preconnect"/><link href="//y.analytics.yahoo.com" rel="preconnect"/><link href="//b.scorecardresearch.com" rel="preconnect"/><link href="//iquery.finance.yahoo.com" rel="preconnect"/><link href="//fc.yahoo.com" rel="preconnect"/><link href="//video-api.yql.yahoo.com" rel="preconnect"/><link href="//yrtas.btrll.com" rel="preconnect"/><link href="//shim.btrll.com" rel="preconnect"/><link href="//consent.cmp.oath.com" rel="preconnect"/><link href="//geo.yahoo.com" rel="preconnect"/><link href="//ads.yahoo.com" rel="preconnect"/><link href="/_finStreamer-worker.js" rel="preload"/><link href="/_rapidworker-1.2.js" rel="preload"/><link href="https://s.yimg.com/cv/apiv2/default/icons/favicon_y19_32x32_custom.svg" rel="icon" sizes="any"/><link href="https://s.yimg.com/cv/apiv2/default/fp/20180826/icons/favicon_y19_32x32.ico" rel="alternate icon" type="image/x-icon"/><link href="https://finance.yahoo.com/quote/MCD/balance-sheet/" rel="canonical"/><meta content="@YahooFinance" property="twitter:site"/><meta content="90376669494" property="fb:pages"/><meta content="https://s.yimg.com/cv/apiv2/social/images/yahoo_default_logo.png" property="og:image"/><meta content="Get the annual and quarterly balance sheet of McDonald's Corporation (MCD) including details of assets, liabilities and shareholders' equity." property="og:description"/><meta content="McDonald's Corporation (MCD) Balance Sheet" property="og:title"/><meta content="Get the annual and quarterly balance sheet of McDonald's Corporation (MCD) including details of assets, liabilities and shareholders' equity." property="twitter:description"/><meta content="McDonald's Corporation (MCD) Balance Sheet" property="twitter:title"/><meta content="yfinance://quote/MCD" property="al:ios:url"/><meta content="328412701" property="al:ios:app_store_id"/><meta content="Yahoo Finance" property="al:ios:app_name"/><meta content="intent://quote/MCD/#Intent;scheme=yfinance;action=android.intent.action.VIEW;package=com.yahoo.mobile.client.android.finance;S.browser_fallback_ ...
# if (!window.YAHOO || !window.YAHOO.i13n || !window.YAHOO.i13n.Rapid) { return; }
# var rapidConfig = {"async_all_clicks":true,"click_timeout":300,"client_only":1,"compr_type":"deflate","keys":{"ver":"ydotcom","navtype":"server","pt":"utility","pct":"qsp","pstcat":"equities","pg_name":"balance-sheet","rvt":"MCD","ticker":"MCD","mrkt":"us","site":"finance","lang":"en-US","colo":"gq1","_yrid":"4vnrihhes64e8","_rid":"4vnrihhes64e8","abk":""},"pageview_on_init":true,"query_parameters":true,"test_id":"finance-US-en-US-def","tracked_mods_viewability":[],"track_right_click":true,"viewability":true,"dwell_on":true,"perf_navigationtime":2,"perf_resourcetime":1,"webworker_file":"/__rapidworker-1.2.js","spaceid":980779724};
# window.rapidInstance = new window.YAHOO.i13n.Rapid(rapidConfig);
# })();</script></head><body><div id="app"><div data-react-checksum="201402862" data-reactid="1" data-reactroot=""><div data-reactid="2"><div class="render-target-active render-target-default" data-reactid="3" id="render-target-default"><div class="finance US en-US H(100%) uh-search-open_Ovy(h) uh-search-open_H(100vh)" data-reactid="4"><div class="YDC-MainCanvas Bgc($bg-body) Mih(100%)" data-reactid="5" id="YDC-MainCanvas" style="padding-top:54px;margin-bottom:auto;"><div class="YDC-UH lw-nav-open_D(n)" data-reactid="6" id="YDC-UH" style="height:54px;"><div class="YDC-UH-Stack Z(10) End(0) Start(0) T(0) Pos(f) uh-search-open_Pos(a) uh-mobile-nav-open_D(n) lw-nav-open_D(n)" data-reactid="7" id="YDC-UH-Stack"><div data-reactid="8" id="YDC-UH-Stack-Composite"><div data-reactid="9"><div data-locator="subtree-root" id="mrt-node-UH-0-UH"><div data-react-checksum="-277824499" data-reactid="1" data-reactroot="" id="UH-0-UH-Proxy"><div data-reactid="2"><div data-reactid="3"><div class="C(#fff) Fz(13px) H(22px)" data-reactid="4" id="masterNav"><ul class="H(22px) Lh(1.7) M(0) NavLinks P(0) Whs(nw) Z(11) Bgc(#2d1152) Pos(a) Start(0) End(0)" data-reactid="5" id="eyebrow" role="navigation"><!-- react-empty: 6 --></ul></div><div class="Miw(980px) UH Z(10) Py(14px) Pos(r)" data-name="tdv2-applet-uh" data-reactid="7" data-version="10.1.62" id="UH-0-UH-0-Header"><div data-reactid="8"><div class="Fl(start) Fz(0) M(0) P(0) ie-7_W(190px) Miw(190px) UHMR1D_Py(0)" data-reactid="9" style="background-color:transparent;"><div data-reactid="10"><style data-reactid="11">#UH-0-UH-0-Header #uh-logo {background-image: url(https://s.yimg.com/rz/d/yahoo_finance_en-US_s_f_pw_351x40_finance.png);} @media  only screen and ( -webkit-min-device-pixel-ratio: 2 ), only screen and ( min--moz-device-pixel-ratio: 2), only screen and ( -o-min-device-pixel-ratio: 2/1), only screen and ( min-device-pixel-ratio: 2), only screen and ( min-resolution: 192dpi), only screen and ( min-resolution: 2dppx), only screen and ( min-aspect-ratio: 2/1 ) { #UH-0-UH-0-Header #uh-logo {background-image: url(https://s.yimg.com/rz/d/yahoo_finance_en-US_s_f_pw_351x40_finance_2x.png);} }</style><a class="Bgpx(0) Bgr(nr) Cur(p) D(b) H(35px) Bgz(702px) Mx(a)! W(92px)" data-reactid="12" href="https://finance.yahoo.com/" id="uh-logo"><b class="Hidden" data-reactid="13">Yahoo</b></a></div></div><div class="Bdrs(3px) D(b) Start(0) W(100%) Z(4)" data-reactid="14" id="uh-search"><form action="/quote/" class="M(0) P(0) Whs(nw)" data-reactid="15" method="get" name="input"><label class="Hidden" data-reactid="16" for="fin-srch-assist">Search</label><div class="" data-reactid="17"><div class="Z(2) Pos(r) IbBox uh-search-open_W($srchInputTouchDeviceWidth) W(100%)" data-reactid="18" id="fin-srch-assist"><input aria-label="Search" autocapitalize="off" autocomplete="off" autocorrect="off" class="Pos(r) W(100%) H(35px) M(0) O(0) O(0):f Bgc(white) Z(2) Bxsh(n) Bxsh(n):f Pt(6px) Pb(8px) Pstart(36px) Pend(20px) Va(t) Bd(0) Bdrs(2px) Fz(16px)" data-reactid="19" id="yfin-usr-qry" maxlength="4096" name="yfin-usr-qry" placeholder="Search for news, symbols or companies" type="text" value=""/><div class="Z(2) Pos(a) Start(8px) T(8px)" data-reactid="20"><svg class="H(20px) W(20px) Va(m)! Fill($finDarkGray)! Stk($finDarkGray) Cur(p)" data-icon="search" data-reactid="21" height="20" style="fill:#000;stroke:#000;stroke-width:0;vertical-align:bottom;" viewbox="0 0 24 24" width="20"><path d="M9 3C5.686 3 3 5.686 3 9c0 3.313 2.686 6 6 6s6-2.687 6-6c0-3.314-2.686-6-6-6m13.713 19.713c-.387.388-1.016.388-1.404 0l-7.404-7.404C12.55 16.364 10.85 17 9 17c-4.418 0-8-3.582-8-8 0-4.42 3.582-8 8-8s8 3.58 8 8c0 1.85-.634 3.55-1.69 4.905l7.403 7.404c.39.386.39 1.015 0 1.403" data-reactid="22"></path></svg></div><div class="Pos(a) Z(2) End(0) T(0)" data-reactid="23"></div></div><script data-reactid="24">(function () {
#         var inputEl = document.getElementById('yfin-usr-qry');
#         var perf = window.performance;
#         if (inputEl && inputEl.addEventListener && perf && perf.mark && perf.getEntriesByName) {
#             var listener = function (e) {
#                 inputEl.removeEventListener('keyup', listener);
#                 if (perf.getEntriesByName('Fin.Search first keyup').length === 0) {
#                     perf.mark('Fin.Search first keyup');
#                 }
#             };
#             inputEl.addEventListener('keyup', listener);
#         }
#     })();</script><div class="Pos(a) Ta(start) Start(0) End(0) Bgc(white) Z(1) Wob(ba) Whs(n) Bxsh($boxShadow) D(n) Mt(8px) Bd(0)" data-reactid="25" data-test="search-assist-input-sugglst"><div class="M(0) Pb(5px) Bxsh($boxShadow) Bdrsbend(3px) Bdrsbstart(3px)" data-reactid="26"><div class="Mb(10px) Pt(40px) Ta(c)" data-reactid="27"><svg class="H(20px) W(20px) Mend(10px) Va(m)! Fill($finDarkGray)! Stk($finDarkGray) Cur(a)! Cur(p)" data-icon="attention" data-reactid="28" height="20" style="fill:#000;stroke:#000;stroke-width:0;vertical-align:bottom;" viewbox="0 0 48 48" width="20"><path d="M24.993 46.424c-12.13 0-22-9.87-22-22s9.87-22 22-22 22 9.87 22 22-9.87 22-22 22zm0-40c-9.925 0-18 8.075-18 18 0 9.926 8.075 18 18 18s18-8.074 18-18c0-9.924-8.075-18-18-18zM24.993 27.424c-1.104 0-2-.895-2-2v-10c0-1.104.896-2 2-2s2 .896 2 2v10c0 1.105-.895 2-2 2zM22.993 33.424a2 2 0 1 0 4 0 2 2 0 1 0-4 0z" data-reactid="29"></path></svg></div><div class="C($finDarkGray) Fw(500) Fz(m) Ta(c) Pb(40px) Px(20px)" data-reactid="30"><span data-reactid="31">No matching results for ''</span></div></div><div class="Ta(start) C($finDarkGray) Fz(s) Fz(500) D(b) Py(8px) Pstart(20px)" data-reactid="32"><span data-reactid="33">Tip: Try a valid symbol or a specific company name for relevant results</span></div></div><button class="C(white) Bd(0) Fw(500) Fz(s) Px(10px) Py(5px) Ta(c) uh-search-open_D(ib) D(n) Va(m) H(35px) Fl(end)" data-reactid="34" type="button"><div class="Ell D(ib) Maw(80px)" data-reactid="35"><span data-reactid="36">Cancel</span></div></button></div><input data-reactid="37" name="fr" type="hidden" value="uh3_finance_vert"/><input data-reactid="38" name="fr2" type="hidden" value="p:finvsrp,m:sb"/><input data-reactid="39" name=".tsrc" type="hidden" value=""/></form></div><ul class="End(20px) List(n) Pos(a) T(14px)" data-reactid="40" id="uh-right"><li class="Fl(start) Mx(4px) Mend(9px) V(h)" data-reactid="41"><svg class="Cur(p)" data-icon="profile" data-reactid="42" height="34" style="fill:#400090;stroke:#400090;stroke-width:0;vertical-align:bottom;" viewbox="0 0 48 48" width="34"><path d="M4.095 33.61c1.092 2.7 2.607 4.937 4.562 6.696 1.94 1.766 4.23 3.072 6.847 3.922 2.632.846 5.472 1.27 8.53 1.27 3.012 0 5.837-.425 8.458-1.27 1.053-.342 2.046-.754 2.986-1.244 1.41-.732 2.705-1.617 3.87-2.678 1.948-1.76 3.472-3.996 4.558-6.697 1.092-2.7 1.636-5.903 1.636-9.614 0-3.702-.544-6.904-1.636-9.61-1.086-2.703-2.608-4.934-4.56-6.694-1.944-1.767-4.23-3.07-6.854-3.922-2.62-.847-5.445-1.27-8.457-1.27-3.06 0-5.9.423-8.53 1.27-.847.277-1.662.607-2.443.98-1.623.777-3.1 1.753-4.404 2.942-1.956 1.76-3.47 3.992-4.562 6.694-1.09 2.706-1.636 5.908-1.636 9.61-.002 3.71.545 6.914 1.635 9.613zM35.838 34.758l-23.674.002v-2.21s.017-1.425 3.123-2.716c1.538-.633 3.35-1.854 6.6-2.24-.997-.705-1.44-2.154-2.29-4.17-.02-.032-.03-.068-.043-.1-.193.032-.393.032-.537-.046-.398-.232-.636-1.48-.642-2.092-.01-.906.48-.824.48-.824s.017 0 .042-.004c-.006-.07-.01-.142-.01-.213 0-.86-.174-2.24.053-2.988.353-1.176.78-2.46 1.72-2.464.874 0 .28-1.006 1.348-1.345 1.102-.348 2.912.262 3.283.262.53 0 1.863.378 2.78 1.284.646.64.572 1.08.93 2.25.23.777.057 2.167.057 3 0 .07-.007.14-.014.213.018.007.03.007.03.007s.487-.082.478.824c-.004.612-.248 1.86-.635 2.092-.146.078-.34.078-.53.052-.01.026-.023.058-.033.09-.85 1.996-1.308 3.457-2.305 4.162 3.283.38 5.107 1.61 6.654 2.25 3.128 1.287 3.14 2.533 3.14 2.533l-.002 2.39z" data-reactid="43"></path></svg></li><li class="D(ib) Mstart(14px) Mt(-1px) ua-ie8_Pb(10px) ua-ie9_Pb(10px)" data-reactid="44"><a class="Pos(r) D(ib) Ta(s) Td(n):h" data-reactid="45" href="https://mail.yahoo.com/?.intl=us&amp;.lang=en-US&amp;.partner=none&amp;.src=finance" id="uh-mail"><svg class="Cur(p)" data-icon="NavMail" data-reactid="46" height="35" style="fill:#400090;stroke:#400090;stroke-width:0;vertical-align:bottom;" viewbox="0 0 512 512" width="30"><path d="M460.586 91.31H51.504c-10.738 0-19.46 8.72-19.46 19.477v40.088l224 104.03 224-104.03v-40.088c0-10.757-8.702-19 ...
# window._adPerfData = [];
# window._adPosMsg = [];
# window._perfMark = function _perfMark (name) {if (window.performance && window.performance.mark){try {if (window.performance.getEntriesByName("NAVIGATE_START") && window.performance.getEntriesByName("NAVIGATE_START")[0]) { name = "CL_" + name ;}window.performance.mark(name);} catch (e) {console.warn(name + ' could not be marked:',e);}};};
# window._perfMeasure = function _perfMeasure (name, start, end) {if (window.performance && window.performance.measure){try {if (window.performance.getEntriesByName("NAVIGATE_START") && window.performance.getEntriesByName("NAVIGATE_START")[0]) { start = "CL_" + start ;end = "CL_" + end ;name = "CL_" + name ;}window.performance.measure(name, start, end);} catch (e) {console.warn(name + ' could not be added:',e);}};};
# window._pushAdPerfMetric = function _pushAdPerfMetric(key) {if (window.performance && window.performance.now) {_adPerfData.push([key, Math.round(window.performance.now())]);}};
# window._fireAdPerfBeacon = function _fireAdPerfBeacon(eventName) {try {if (window && window.rapidInstance && window.performance) {var navClickMark = window.performance.getEntriesByName('NAVIGATE_START') &&window.performance.getEntriesByName('NAVIGATE_START').pop();var navClickTime = navClickMark && navClickMark.startTime || 0;var userTime = {};window.performance.getEntries().forEach(function forEachPerfTime (item) {if (item.name.search('DARLA_') > -1) {if (item.entryType === "mark") {userTime[item.name] = Math.round(item.startTime) - navClickTime;window.performance.clearMarks(item.name);} else if (item.entryType === "measure") {userTime[item.name] = Math.round(item.duration);window.performance.clearMeasures(item.name);}}});var perfData = {perf_usertime: {utm: userTime}};
# window.rapidInstance.beaconPerformanceData(perfData);}} catch (e) {console.warn('Could not send the beacon:',e);}};
# window.DARLA_CONFIG = {"debug":false,"dm":1,"autoRotation":10000,"rotationTimingDisabled":true,"k2":{"res":{"rate":5,"pos":["BTN","BTN-1","BTN-2","BTN-3","BTN1","LREC","LREC2","LREC3","LDRB","MAST"]}},"positions":{"DEFAULT":{"name":"DEFAULT","enable":true,"fallback":null,"metaSize":false,"staticLayout":false,"clean":"defaultcleanDEFAULT","dest":"defaultdestDEFAULT","id":"DEFAULT","meta":{"hostURL":"https://finance.yahoo.com/quote/MCD/balance-sheet"}},"WPS":{"id":"WPS","clean":"defaultcleanWPS","dest":"defaultdestWPS","metaSize":true,"w":320,"h":50,"enable":true,"fallback":null,"staticLayout":false,"meta":{"hostURL":"https://finance.yahoo.com/quote/MCD/balance-sheet"}},"BTN1":{"id":"BTN1","clean":"defaultcleanBTN1","dest":"defaultdestBTN1","metaSize":true,"w":120,"h":60,"enable":false,"fallback":null,"staticLayout":false,"meta":{"hostURL":"https://finance.yahoo.com/quote/MCD/balance-sheet"}},"BTN1-1":{"id":"BTN1","clean":"defaultcleanBTN1-1","dest":"defaultdestBTN1-1","metaSize":true,"w":120,"h":60,"enable":false,"fallback":null,"staticLayout":false,"meta":{"hostURL":"https://finance.yahoo.com/quote/MCD/balance-sheet"}},"BTN":{"id":"BTN","clean":"defaultcleanBTN","dest":"defaultdestBTN","metaSize":true,"w":120,"h":60,"enable":false,"fallback":null,"staticLayout":false,"meta":{"hostURL":"https://finance.yahoo.com/quote/MCD/balance-sheet"}},"BTN-1":{"id":"BTN-1","clean":"defaultcleanBTN-1","dest":"defaultdestBTN-1","w":120,"h":60,"enable":false,"fallback":null,"metaSize":false,"staticLayout":false,"meta":{"hostURL":"https://finance.yahoo.com/quote/MCD/balance-sheet"}},"BTN-2":{"id":"BTN-2","clean":"defaultcleanBTN-2","dest":"defaultdestBTN-2","metaSize":true,"w":120,"h":60,"enable":false,"fallback":null,"staticLayout":false,"meta":{"hostURL":"https://finance.yahoo.com/quote/MCD/balance-sheet"}},"BTN-3":{"id":"BTN-3","clean":"defaultcleanBTN-3","dest":"defaultdestBTN-3","metaSize":true,"w":120,"h":60,"enable":false,"fallback":null,"staticLayout":false,"meta":{"hostURL":"https://finance.yahoo.com/quote/MCD/balance-sheet"}},"BTN-5":{"id":"BTN-5","clean":"defaultcleanBTN-5","dest":"defaultdestBTN-5","metaSize":true,"w":120,"h":60,"enable":false,"fallback":null,"staticLayout":false,"meta":{"hostURL":"https://finance.yahoo.com/quote/MCD/balance-sheet"}},"BTN-6":{"id":"BTN-6","clean":"defaultcleanBTN-6","dest":"defaultdestBTN-6","metaSize":true,"w":120,"h":60,"enable":false,"fallback":null,"staticLayout":false,"meta":{"hostURL":"https://finance.yahoo.com/quote/MCD/balance-sheet"}},"BTN-7":{"id":"BTN-7","clean":"defaultcleanBTN-7","dest":"defaultdestBTN-7","metaSize":true,"w":120,"h":60,"enable":false,"fallback":null,"staticLayout":false,"meta":{"hostURL":"https://finance.yahoo.com/quote/MCD/balance-sheet"}},"BTN-8":{"id":"BTN-8","clean":"defaultcleanBTN-8","dest":"defaultdestBTN-8","metaSize":true,"w":120,"h":60,"enable":true,"fallback":null,"staticLayout":false,"meta":{"hostURL":"https://finance.yahoo.com/quote/MCD/balance-sheet"}},"BTNA":{"id":"BTNA","clean":"defaultcleanBTNA","dest":"defaultdestBTNA","metaSize":true,"w":120,"h":60,"enable":false,"fallback":null,"staticLayout":false,"meta":{"hostURL":"https://finance.yahoo.com/quote/MCD/balance-sheet"}},"BTNB":{"id":"BTNB","clean":"defaultcleanBTNB","dest":"defaultdestBTNB","metaSize":true,"w":120,"h":60,"enable":false,"fallback":null,"staticLayout":false,"meta":{"hostURL":"https://finance.yahoo.com/quote/MCD/balance-sheet"}},"BTNC":{"id":"BTNC","clean":"defaultcleanBTNC","dest":"defaultdestBTNC","metaSize":true,"w":120,"h":60,"enable":false,"fallback":null,"staticLayout":false,"meta":{"hostURL":"https://finance.yahoo.com/quote/MCD/balance-sheet"}},"BTND":{"id":"BTND","clean":"defaultcleanBTND","dest":"defaultdestBTND","metaSize":true,"w":120,"h":60,"enable":false,"fallback":null,"staticLayout":false,"meta":{"hostURL":"https://finance.yahoo.com/quote/MCD/balance-sheet"}},"WIDGET":{"id":"WIDGET","clean":"defaultcleanWIDGET","dest":"defaultdestWIDGET","metaSize":false,"w":650,"h":635,"e ...
# window.DARLA_CONFIG.servicePath = window.location.protocol + "//fc.yahoo.com/sdarla/php/fc.php";window.DARLA_CONFIG.dm = 1;window.DARLA_CONFIG.onStartRequest = function() {window._perfMark('DARLA_REQSTART');};
# window.DARLA_CONFIG.onFinishRequest = function() {window._perfMark('DARLA_REQEND');};
# window.DARLA_CONFIG.onStartParse = function() {window._perfMark('DARLA_PSTART');};
# window.DARLA_CONFIG.onSuccess = function(eventName) {if (eventName === 'AUTO') {return;}if (window._DarlaEvents) {window._DarlaEvents.emit("success", {eventName: eventName});}window._perfMark('DARLA_DONE_' + eventName);window._darlaSuccessEvt = eventName;if (window._loadEvt) {window._fireAdPerfBeacon(eventName);}};
# window.DARLA_CONFIG.onStartPosRender = function(posItem) {var posId = posItem && posItem.pos;window._perfMark('DARLA_ADSTART_' + posId);if (window._pushAdPerfMetric) {window._pushAdPerfMetric("DARLA_ADSTART_" + posId);}};
# window.DARLA_CONFIG.onFinishPosRender = function(posId, reqList, posItem) {var ltime;window._perfMark('DARLA_ADEND_' + posId);window._perfMeasure('DARLA_RENDERTIME_' + posId, 'DARLA_ADSTART_'+posId, 'DARLA_ADEND_'+posId);if(window._DarlaEvents) {window._DarlaEvents.emit("finishrender", {pos:posId, list:reqList, item:posItem});}var aboveFoldPositions = ["WPS","MAST","LDRB","SPRZ","SPL","LREC","BTN","BTN-1","BTN-2","BTN-3","BTN1","BTNA","BTNB","BTNC","BTND","FB2","FB2-1","FB2-2","FB2-3","FB2A","FB2B","FB2C","FB2D","NE4","NE4-1","NE4-2","NE4-3","NE4A","NE4B","NE4C","NE4D"];if (window._pushAdPerfMetric) {if (window.performance && window.performance.now) {ltime = window.performance.now();}window._pushAdPerfMetric("ADEND_"+posId);var adModDiv = posItem.conf.dest.replace("dest", "") + "-sizer";setTimeout(function () {if (window.performance && window.YAFT !== undefined &&window.YAFT.isInitialized() && -1 !== aboveFoldPositions.indexOf(posId)) {window.YAFT.triggerCustomTiming(adModDiv, "", ltime);}}, 300);}};
# window.DARLA_CONFIG.onBeforePosMsg = function(msg, posId) {var maxWidth = 970, maxHeight = 600;var newWidth, newHeight, pos;if ("MAST" !== posId) {return;}if (msg === "resize-to") {newWidth = arguments[2];newHeight = arguments[3];} else if (msg === "exp-push" || msg === "exp-ovr") {pos = $sf.host.get("MAST");newWidth = pos.conf.w + arguments[6] + arguments[7];newHeight = pos.conf.h + arguments[5] + arguments[8];}if (newWidth > maxWidth || newHeight > maxHeight) {return true;}};
# window.DARLA_CONFIG.onFinishParse = function(eventName, response) {try {window._perfMark('DARLA_PEND');if (eventName === "prefetch") {window._DarlaPrefetchResponse = response;}if (window._DarlaEvents) {window._DarlaEvents.emit("finishparse", {response: response,eventName: eventName});}} catch (e) {console.error(e);throw e;}
# };
# window.DARLA_CONFIG.onStartPrefetchRequest = function(eventName) {window._perfMark('DARLA_PFSTART');};
# window.DARLA_CONFIG.onFinishPrefetchRequest = function(eventName, status) {window._perfMark('DARLA_PFEND');try {window._DarlaEvents.emit('finishprefetch', {status: status,eventName: eventName});} catch (e) {console.error(e);throw e;}
# };
# window.DARLA_CONFIG.onPosMsg = function(cmd, pos, msg) {try {if (window._DarlaEvents && cmd === "cmsg") {var posmsg = {pos: pos,msg: msg};window._DarlaEvents.emit("splashmsg", posmsg);if (window._adPosMsg) {window._adPosMsg[window._adPosMsg.length] = posmsg;}}if (window._DarlaEvents && (cmd === "ui-fclose-show" || cmd === "ui-fclose-close")) {setTimeout(function _emitAdResize(){window._DarlaEvents.emit("adresize", {pos: pos})}, 0);}} catch (e) {console.error(e);throw e;}
# };
# (function () {var _onloadEvt = function _onloadEvtHandler() {window._loadEvt = true;if (window._darlaSuccessEvt) {window._fireAdPerfBeacon(window._darlaSuccessEvt);}};if (window.addEventListener) {window.addEventListener("load", _onloadEvt);} else if (window.attachEvent) {window.attachEvent("onload", _onloadEvt);}function _onDarlaError (type) {return function _darlaErrHandler(evName) {try {if (window._DarlaEvents) {window._DarlaEvents.emit("darlaerror" + evName);window._DarlaEvents.emit("darlaerror", {type: type,eventName: evName,error: true});}} catch (e) {console.error(e);throw e;}};};window.DARLA_CONFIG.onRequestTimeout = _onDarlaError("requestTimeout");window.DARLA_CONFIG.onRenderTimeout = _onDarlaError("renderTimeout");window.DARLA_CONFIG.onFailure = _onDarlaError("failure");window.DARLA_CONFIG.onIdle = function onDarlaIdle () {    try {        window._DarlaEvents && window._DarlaEvents.emit("onIdle");    } catch (e) {        console.error(e);        throw e;    }};})();
# window.$sf = window.sf = {};
# window.$sf.host = {onReady: function (autorender, deferrender, firstRenderPos, deferRenderDelay) {window._perfMark('DARLA_ONREADY');window._perfMeasure('DARLA_ONREADY');window.sfready = true;if (window._DarlaEvents && !autorender) {window._DarlaEvents.emit("darlaboot");} else if (autorender){window._perfMark('DARLA_RSTART');if (typeof DARLA !== "undefined" && DARLA) {if (deferrender && firstRenderPos) {var firstBatchPos = [];var prefetchedPos = DARLA.prefetched();if (prefetchedPos.length <= 0) {return;}var firstRender = firstRenderPos.split(',');if (firstRender && firstRender.length > 0) {for (var i = 0; i < firstRender.length; i++) {var position = firstRender[i];var index = prefetchedPos.indexOf(position);if (index >= 0) {firstBatchPos = firstBatchPos.concat(prefetchedPos.splice(index, 1));}};}if (firstBatchPos.length > 0) {var renderWithRetry = function(pos) {if (DARLA.inProgress()) {var waittime = 600, maxwait = 100, deferRetry = 0, interval;interval = setInterval(function() {deferRetry ++;if (!DARLA.inProgress()){clearInterval(interval);DARLA.render(pos);}if (deferRetry > maxwait){clearInterval(interval);}}, waittime);} else {DARLA.render(pos);}};renderWithRetry(firstBatchPos);setTimeout(renderWithRetry, deferRenderDelay, prefetchedPos);} else {DARLA.render();}} else {DARLA.render();}}}}
# };
# window.sf_host = window.$sf.host;
# document.onreadystatechange = function () {if (document.readyState == "interactive") {window._perfMark('DOM_INTERACTIVE');}};</script>
# <script _ver="3-20-0" id="fc" type="text/x-safeframe">{"positions":[{"id":"LREC","html":"<!-- SpaceID=0 robot -->\n","lowHTML":"","meta":{"y":{"pos":"LREC","cscHTML":false,"cscURI":"","behavior":"non_exp","adID":"#19","matchID":"#19","bookID":false,"slotID":false,"serveType":false,"ttl":-1,"err":"robot","hasExternal":false,"supp_ugc":false,"placementID":-1,"fdb":null,"serveTime":-1,"impID":"","creativeID":-1,"adc":"{\"label\":\"AdChoices\",\"url\":\"https:\\\/\\\/info.yahoo.com\\\/privacy\\\/us\\\/yahoo\\\/relevantads.html\",\"close\":\"Close\",\"closeAd\":\"Close Ad\",\"showAd\":\"Show ad\",\"collapse\":\"Collapse\",\"fdb\":\"I don't like this ad\",\"code\":\"en-us\"}","is3rd":1,"facStatus":{},"userProvidedData":{},"facRotation":{},"slotData":{}}}},{"id":"LREC2","html":"<!-- SpaceID=0 robot -->\n","lowHTML":"","meta":{"y":{"pos":"LREC2","cscHTML":false,"cscURI":"","behavior":"non_exp","adID":"#19","matchID":"#19","bookID":false,"slotID":false,"serveType":false,"ttl":-1,"err":"robot","hasExternal":false,"supp_ugc":false,"placementID":-1,"fdb":null,"serveTime":-1,"impID":"","creativeID":-1,"adc":"{\"label\":\"AdChoices\",\"url\":\"https:\\\/\\\/info.yahoo.com\\\/privacy\\\/us\\\/yahoo\\\/relevantads.html\",\"close\":\"Close\",\"closeAd\":\"Close Ad\",\"showAd\":\"Show ad\",\"collapse\":\"Collapse\",\"fdb\":\"I don't like this ad\",\"code\":\"en-us\"}","is3rd":1,"facStatus":{},"userProvidedData":{},"facRotation":{},"slotData":{}}}},{"id":"FOOT","html":"<!-- SpaceID=0 robot -->\n","lowHTML":"","meta":{"y":{"pos":"FOOT","cscHTML":false,"cscURI":"","behavior":"non_exp","adID":"#19","matchID":"#19","bookID":false,"slotID":false,"serveType":false,"ttl":-1,"err":"robot","hasExternal":false,"supp_ugc":false,"placementID":-1,"fdb":null,"serveTime":-1,"impID":"","creativeID":-1,"adc":"{\"label\":\"AdChoices\",\"url\":\"https:\\\/\\\/info.yahoo.com\\\/privacy\\\/us\\\/yahoo\\\/relevantads.html\",\"close\":\"Close\",\"closeAd\":\"Close Ad\",\"showAd\":\"Show ad\",\"collapse\":\"Collapse\",\"fdb\":\"I don't like this ad\",\"code\":\"en-us\"}","is3rd":1,"facStatus":{},"userProvidedData":{},"facRotation":{},"slotData":{}}}},{"id":"FSRVY","html":"<!-- SpaceID=0 robot -->\n","lowHTML":"","meta":{"y":{"pos":"FSRVY","cscHTML":false,"cscURI":"","behavior":"non_exp","adID":"#19","matchID":"#19","bookID":false,"slotID":false,"serveType":false,"ttl":-1,"err":"robot","hasExternal":false,"supp_ugc":false,"placementID":-1,"fdb":null,"serveTime":-1,"impID":"","creativeID":-1,"adc":"{\"label\":\"AdChoices\",\"url\":\"https:\\\/\\\/info.yahoo.com\\\/privacy\\\/us\\\/yahoo\\\/relevantads.html\",\"close\":\"Close\",\"closeAd\":\"Close Ad\",\"showAd\":\"Show ad\",\"collapse\":\"Collapse\",\"fdb\":\"I don't like this ad\",\"code\":\"en-us\"}","is3rd":1,"facStatus":{},"userProvidedData":{},"facRotation":{},"slotData":{}}}}],"conf":{"useYAC":0,"usePE":1,"servicePath":"","xservicePath":"","beaconPath":"","renderPath":"","allowFiF":false,"srenderPath":"https:\/\/s.yimg.com\/rq\/darla\/3-20-0\/html\/r-sf.html","renderFile":"https:\/\/s.yimg.com\/rq\/darla\/3-20-0\/html\/r-sf.html","sfbrenderPath":"https:\/\/s.yimg.com\/rq\/darla\/3-20-0\/html\/r-sf.html","msgPath":"https:\/\/fc.yahoo.com\/unsupported-1946.html","cscPath":"https:\/\/s.yimg.com\/rq\/darla\/3-20-0\/html\/r-csc.html","root":"sdarla","edgeRoot":"https:\/\/s.yimg.com\/rq\/darla\/3-20-0","sedgeRoot":"https:\/\/s.yimg.com\/rq\/darla\/3-20-0","version":"3-20-0","tpbURI":"","hostFile":"https:\/\/s.yimg.com\/rq\/darla\/3-20-0\/js\/g-r-min.js","property":"finance_en-US","fdb_locale":"What don't you like about this ad?|It's offensive|Something else|Thank you for helping us improve your Yahoo experience|It's not relevant|It's distracting|I don't like this ad|Send|Done|Why do I see ads?|Learn more about your feedback.|Want an ad-free inbox? Upgrade to Yahoo Mail Pro!|Upgrade Now","positions":{"LREC":{"dest":"destLREC","asz":"300x250","id":"LREC","w":"300","h":"250"},"LREC2":{"dest":"destLREC2","asz":"300x250","id ...
# <!-- gq1-sdarlaws-002.adx.gq1.yahoo.com Wed Nov  6 18:32:40 UTC 2019 -->
# <script type="text/javascript">if (typeof DARLA !== "undefined" && DARLA) {DARLA.config(window.DARLA_CONFIG);window.sf_host.onReady(true,true,'FB2A,FB2B,FB2C,FB2D,LDRB,LDRB2,LREC',3000);}</script>
# <style>
# .hide-lrec-ad .darla-lrec-ad {display: none;}.hide-non-lrec34 .darla-nonlrec34-ad {display: none;}.hide-non-lrec34 .sticky-outer-wrapper .tdv2-applet-stream .js-stream-content .controller,.hide-non-lrec34 .YDC-Height-Container .tdv2-applet-stream .js-stream-content .controller {display: none;}.hide-non-lrec34ldrb .darla-nonlrec34ldrb-ad {display: none;}.hide-non-lrec34ldrb .sticky-outer-wrapper .tdv2-applet-stream .js-stream-content .controller,.hide-non-lrec34ldrb .YDC-Height-Container .tdv2-applet-stream .js-stream-content .controller {display: none;}.hide-lrec-groups-lrec12 .darla-nonlrec34ldrb-ad,.hide-lrec-groups-lrec34 .darla-lrec34-ad,.hide-all-lrecs .darla-lrec-ad {display: none;}</style>
# </div><script>
# (function (root) {
# /* -- Data -- */
# root.App || (root.App = {});
# root.App.now = 1573065160226;
# root.App.main = {"context":{"dispatcher":{"stores":{"PageStore":{"currentPageName":"quote","currentRenderTargetId":"default","pagesConfigRaw":{"base":{"quote":{"layout":{"bundleName":"yahoodotcom-layout.MobileOneColumnLayout","name":"MobileOneColumnLayout","config":{"enableHeaderCollapse":false,"additionalBodyWrapperClasses":"Bgc($layoutBgColor)!","contentWrapperClasses":"Bgc($layoutBgColor)!","Header":{"isFixed":true,"uhContainerClasses":"Bgi($uhGrayGradient) D(n)--print","navContainerClasses":"Bgi($navrailGrayGradient) Bxsh($navrailShadow) Pos(r) hasScrolled_Bxsh(headerShadow) Panel-open_Bxsh(headerShadow)","navTransitionClasses":"HideNavrail_Translate3d(0,-46px,0) Panel-open_Translate3d(0,-46px,0)","secondaryNavContainerClasses":"hasScrolled_Bdbw(0px) Bgc(white) Bxsh($navrailShadow) D(n)--print","height":115},"fetchNewAttribution":true,"hideFeatureBar":true,"Side":null,"UH":{"containerClasses":"lw-nav-open_D(n)","height":54,"slotHeight":54}},"meta":{"property":{"twitter:site":"@YahooFinance"},"name":{"viewport":"width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no"}}},"meta":{"property":{"twitter:site":"@YahooFinance","fb:pages":"90376669494","og:image":"https:\u002F\u002Fs.yimg.com\u002Fcv\u002Fapiv2\u002Fsocial\u002Fimages\u002Fyahoo_default_logo.png"}},"videoOverrides":{"enableOathPlayer":true},"regions":{"SecondaryNav":[],"Overlay":[{"bundleName":"tdv2-applet-navrail","name":"DesktopNav","perfLabel":"NavLite","config":{"ui":{"navCache":true,"remoteAdapter":true,"makeSticky":false,"isNavLink":true,"relativeLinks":true,"darkTheme":true,"offsetHack":"Bgc(t)!","selectColor":"C($finNavBlueText)! Bdbw(0px) H(42px) Trstf(l) Trsde(0s) Trsdu(.18s) Trsp(border-bottom-width)","subnavClasses":"Bgc(white)!","hoverColor":"C($finNavBlueText):h","overrideColor":"C($finNavBlueText)","propertyHomeSelectColor":"Bdbc($c-fuji-blue-1-a) Bdbs(s)! Bdbw(4px) H(38px)","propertyHomeClasses":"Tt(c)! Bdbc($c-fuji-blue-1-a):h Bdbs(s):h Bdbw(4px):h H(38px) Trstf(l) Trsde(0s) Trsdu(.18s) Trsp(border-bottom-width)","navLinkClasses":"Tt(n)!","navLinkClassesOnHover":"Bdbc($c-fuji-blue-1-a)!:h Bdbs(s)!:h Bdbw(4px)!:h H(38px) Trstf(l) Trsde(0s) Trsdu(.18s) Trsp(border-bottom-width)","navLinkNonHoverClasses":"C($topNavLinkGray) Bdbs(n)","highlightTriangleColor":"transparent transparent #fff"},"featureSwitches":{"useNavSelectLogic":true},"i13n":{"itc":0,"sec":"navrail"},"site":"finance","theme":{"mobileIcon":"LogoYahoo2019","mobileIconHeight":60,"mobileIconWidth":100}},"props":{"key":"Overlay-0-DesktopNav","id":"Overlay-0-DesktopNav"},"isPageComposite":true},{"bundleName":"react-lightbox","name":"Lightbox","props":{"key":"Overlay-1-Lightbox","id":"Overlay-1-Lightbox"},"isPageComposite":true},{"bundleName":"react-finance","name":"Null","props":{"key":"Overlay-2-Null","id":"Overlay-2-Null"},"isPageComposite":true}],"Lead":[],"Col1":[{"bundleName":"tdv2-applet-swisschamp","name":"Empty","props":{"key":"Col1-0-Empty","id":"Col1-0-Empty"},"isPageComposite":true},{"bundleName":"QuotePage","name":"QuoteNav","props":{"className":"Pos(r) Mstart(a) Mend(a) Bxsh($horzScrollMenuShadow)","type":"scroll","key":"Col1-1-QuoteNav","id":"Col1-1-QuoteNav"},"isPageComposite":true},{"bundleName":"QuotePage","name":"QuoteHeader","props":{"type":"narrow","showPrice":false,"key":"Col1-2-QuoteHeader","id":"Col1-2-QuoteHeader"},"isPageComposite":true},{"bundleName":"Quote.financialsv2","name":"Financials","props":{"key":"Col1-3-Financials","id":"Col1-3-Financials"},"isPageComposite":true},{"bundleName":"react-finance","name":"AdUnitWithTdAds","props":{"className":"ad-lrec","positions":["LREC"],"style":{"marginBottom":"30px","marginTop":"-45px","marginLeft":"auto","marginRight":"auto","paddingBottom":"0","textAlign":"center","backgroundColor":"#fff","width":"100%","paddingTop":"10px"},"key":"Col1-4-AdUnitWithTdAds","id":"Col1-4-AdUnitWithTdAds"},"isPageComposite":true},{"bundleName":"QuotePage","name":"QuoteModule","props":{"type":"similarCompanies","key":"Col1-5-Quo ...
# }(this));
# </script><script defer="" src="https://s.yimg.com/zz/combo?uc/finance/dd-site/js/main-lightweight.9ef53babc497b87d75da.lightweight.js&amp;os/yaft/yaft-0.3.27.min.js&amp;os/yaft/yaft-plugin-aftnoad-0.1.5.min.js"></script>
# <script>window.webpackPublicPath='https://s.yimg.com/uc/finance/dd-site/js/';</script></body></html>

# %%
# %tb
# Out:
# ---------------------------------------------------------------------------
# SystemExit                                Traceback (most recent call last)
# <ipython-input-5-2b3a4c24c39c> in <module>
# ----> 1 total_cur_assets = periodic_figure_values(financials_soup('MCD', "bs"), "Total Current Assets")[0]
#
# ~\Documents\Projects\Coding Projects\Stock Market\Stock-Market-Analysis\market.py in periodic_figure_values(soup, yahoo_figure)
#     126             row = title.parent
#     127         else:
# --> 128             sys.exit("Invalid figure '" + yahoo_figure + "' passed.")
#     129
#     130     cells = row.find_all("td")[1:] # exclude the <td> with figure name
#
# SystemExit: Invalid figure 'Total Current Assets' passed.

# %%
predict_price_time_averaged('MCD', 5)
# Out:
# Training XGB model with hyperparameter tuning... Make sure csv is updated.
# C:\Users\kevin\Anaconda3\envs\tensorflow_env\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# Test Score: 0.892595831427404
# RMSE: 16.405113
# Training XGB model with hyperparameter tuning... Make sure csv is updated.
# C:\Users\kevin\Anaconda3\envs\tensorflow_env\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# Test Score: 0.9233402641325593
# RMSE: 15.158128
# Training XGB model with hyperparameter tuning... Make sure csv is updated.
# C:\Users\kevin\Anaconda3\envs\tensorflow_env\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# Test Score: 0.8842324882492475
# RMSE: 17.822236
# Training XGB model with hyperparameter tuning... Make sure csv is updated.
# C:\Users\kevin\Anaconda3\envs\tensorflow_env\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# Test Score: 0.8650431491010662
# RMSE: 18.735724
# Training XGB model with hyperparameter tuning... Make sure csv is updated.
# C:\Users\kevin\Anaconda3\envs\tensorflow_env\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# Test Score: 0.8242438614219599
# RMSE: 22.838800
# Mean predicted price: 189.80782
# Median predicted price: 180.63129
# Standard Dev. predicted price: 33.22662
# (189.80782, 33.22662)

# %%
predict_price_time_averaged('BMY', 3)
# Out:
# Mean predicted price: 59.47427
# Median predicted price: 60.551
# Standard Dev. predicted price: 2.7517064
# (59.47427, 2.7517064)

# %%
compute_returns()#filename='transactions_test.csv')
# Out:
# Starting amount: $500000
# Return on investment for PIH is 5.78%, or $-15.86
# Return on investment for ACST is -10.55%, or $6.21
# Return on investment for AEMD is 1248.89%, or $2004.82
# Return on investment for AKTS is -14.0%, or $-19.38
# Return on investment for ARCW is -28.0%, or $4.9
# Return on investment for ATAI is 12.56%, or $136.1
# Return on investment for BRQS is 0.0%, or $0.0
# Return on investment for CARV is 2.37%, or $5.74
# Return on investment for APOP is 547.62%, or $535.9
# Return on investment for CERC is 9.37%, or $27.9
# Return on investment for CIDM is -0.94%, or $-0.46
# Return on investment for CUTR is 18.25%, or $-397.14
# Return on investment for DSKE is 8.55%, or $-8.97
# Return on investment for DCIX is -5.61%, or $3.34
# Return on investment for ENTX is 28.79%, or $31.79
# Return on investment for FNHC is 0.37%, or $3.21
# Return on investment for FTEK is 1.18%, or $-0.52
# Return on investment for GOGL is -8.43%, or $-15.81
# Return on investment for ILPT is 1.75%, or $-14.11
# Return on investment for JAGX is -0.53%, or $-0.54
# Return on investment for KELYA is -3.06%, or $-50.99
# Return on investment for LAUR is 9.39%, or $70.78
# Return on investment for LECO is 10.66%, or $141.76
# Return on investment for LYTS is 9.2%, or $-11.28
# Return on investment for MLCO is 10.31%, or $173.52
# Return on investment for MESO is -2.56%, or $-4.16
# Return on investment for MGEN is -17.65%, or $7.35
# Return on investment for OVID is 18.18%, or $7.2
# Return on investment for TEUM is -59.88%, or $223.9
# Return on investment for PFMT is 6.5%, or $-1.3
# Return on investment for PLYA is 4.39%, or $-10.89
# Return on investment for QGEN is 16.18%, or $204.71
# Return on investment for RADA is 0.59%, or $0.99
# Return on investment for RETA is 135.98%, or $-16634.6
# Return on investment for REFR is 16.94%, or $27.56
# Return on investment for RTTR is -21.97%, or $-14.15
# Return on investment for SNNA is -37.69%, or $-9.02
# Return on investment for SLGL is 3.59%, or $-5.22
# Return on investment for STCN is -18.18%, or $14.7
# Return on investment for SIVB is 19.74%, or $1445.85
# Return on investment for FLIC is 6.93%, or $62.8
# Return on investment for TSG is 4.96%, or $134.51
# Return on investment for TNXP is 468.18%, or $57.68
# Return on investment for TUES is 4.0%, or $1.92
# Return on investment for XNET is 182.51%, or $-280.83
# Return on investment for CPLP is -3.78%, or $-6.75
# Return on investment for ICUI is 6.2%, or $-173.88
# Return on investment for IMXI is 4.67%, or $39.85
# Return on investment for PDCE is 10.72%, or $90.49
# Return on investment for CRNX is 11.17%, or $-40.11
# Return on investment for DLTR is -2.52%, or $58.0
# Return on investment for SABR is 5.45%, or $68.44
# Return on investment for AAPL is 3.67%, or $375.15
# Value of portfolio: $495919.24
# Total return is $1099.98
# Return on investment: 0.22%
# Sum of returns: $-11748.9
