# %%
from market_tests import *

# %%
# run tests
test_market_suite()
# Out:
# Tests for market.py PASSED!
# C:\Users\kevin\Anaconda3\envs\tensorflow_env\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# This instance of predict price is getting called with a specified model. Check that model is valid.
# The model could not be found at: ml_models/xgbr_2019-11-27.dat
# Could not train model for the data located in company_stats_2019-11-27.csv. Check that this file exists.
# The model could not be found at: ml_models/xgbr_2019-11-28.dat
# Could not train model for the data located in company_stats_2019-11-28.csv. Check that this file exists.
# The model could not be found at: ml_models/xgbr_2019-11-29.dat
# Could not train model for the data located in company_stats_2019-11-29.csv. Check that this file exists.
# This instance of predict price is getting called with a specified model. Check that model is valid.
# ...

# %%
# Test for market trading
tickers = list(get_tickers())
selection = [tickers[i] for i in range(len(tickers)) if i % 100 == 0] # Test trading
portfolio = {} #get_portfolio_from_csv()
transactions = run_trading_algo(selection, portfolio, time_averaged=True, time_averaged_period=5,
                                min_price_thresh=10, buy_alpha=0.05, short_alpha=0.00001,
                                append_to_csv=True, file_name='transactions_alpha0_05_0_00001.csv')
# Out:
# C:\Users\kevin\Anaconda3\envs\tensorflow_env\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# PIH's price is under the minimun price thresh of 10
# Failed to parse json response for ALQA
# Failed to parse json response for ALQA
# Failed to parse json response for ALQA
# Failed to parse json response for ALQA
# Failed to parse json response for ALQA
# Failed to parse json response for ALQA
# Failed to parse json response for ASNS
# Failed to parse json response for ASNS
# Failed to parse json response for ASNS
# Failed to parse json response for ASNS
# Failed to parse json response for ASNS
# Failed to parse json response for ASNS
# BASI's price is under the minimun price thresh of 10
# CARV's price is under the minimun price thresh of 10
# CMFN's price is under the minimun price thresh of 10
# CUTR is undervalued by 3.28, or 9.7%.
# ...

# %%
def filter_tickers_by_1y_target_est(tickers, thresh=0.5, verbose=False, price_filter=0):
    '''
    This code takes tickers and compares the real price to the 1y estimated yahoo finance price.
    You can optionally filter by price as well using price_filter.
    '''
    # Check inputs
    assert len(tickers) > 0, 'No tickers were passed in: ' + str(tickers)
    assert thresh >=0, 'Invalid thresh was passed in: ' + str(thresh)
    assert price_filter >=0, 'Invalid price filter of ' + str(price_filter) + ' passed in.'
    
    # Store ticker, price, estimate
    price_targets = []
    
    for ticker in tickers:
        # Collect data for ticker
        summ = parse(ticker)
        if 'error' in summ.keys():
            continue
        try:
            est = summ['1y Target Est']
            assert isinstance(est, numbers.Number), '1y target estimate not numeric'
            price = str_to_num(summ['Open'])
            if est - price > 0 and (est - price) / price > .5 and price >= price_filter:
                price_targets.append([ticker, price, est])
                print(ticker + '. Actual: ' + str(price) + '. 1y target est: ' + str(est))
        except:
            if verbose:
                print(ticker + ' failed.')
    return price_targets

filter_tickers_by_1y_target_est(get_tickers(), thresh=)

# %%
for x in price_targets:
    price = x[1]
    est = x[2]
    if est - price > 0 and (est - price) / price > .9 and price > 10:
        print(x)
# Out:
# ['AERI', 19.02, 41.56]
# ['AGIO', 31.78, 65.4]
# ['ALBO', 19.22, 54.43]
# ['ANAB', 37.88, 101.4]
# ['ASMB', 16.2, 43.4]
# ['ATRA', 12.58, 31.0]
# ['ATNX', 11.43, 27.42]
# ['AUTL', 13.09, 33.0]
# ['AVRO', 14.53, 37.78]
# ['AXGN', 13.5, 25.67]
# ['BAND', 43.8, 85.0]
# ['BYSI', 12.71, 41.0]
# ['BPTH', 11.2, 28.0]
# ['BCOR', 19.31, 39.67]
# ['BLUE', 79.38, 155.24]
# ['CDNA', 20.19, 49.2]
# ['CELC', 14.11, 35.5]
# ['CLLS', 12.5, 40.82]
# ['CRNX', 19.08, 39.5]
# ['CSPI', 12.56, 65.0]
# ['EDIT', 20.62, 46.71]
# ['EIGR', 11.29, 36.67]
# ['ESPR', 37.39, 81.23]
# ['FLXS', 18.01, 50.0]
# ['GTHX', 23.07, 66.5]
# ['GBT', 47.77, 91.36]
# ['HIIQ', 23.66, 54.63]
# ['HRTX', 21.07, 42.3]
# ['FIXX', 11.87, 33.4]
# ['INSM', 18.78, 42.56]
# ['NTLA', 12.78, 28.05]
# ['IGLD', 12.7, 44.09]
# ['ITCI', 10.01, 25.22]
# ['IRCP', 11.49, 27.9]
# ['KALV', 10.9, 32.14]
# ['LOGC', 10.01, 22.25]
# ['LORL', 40.21, 89.0]
# ['MDGL', 92.83, 185.08]
# ['MGTX', 14.57, 35.25]
# ['OMER', 13.01, 37.2]
# ['OPNT', 15.25, 40.0]
# ...

# %%
analyze('AAPL')
# Out:
# ANALYSIS FOR AAPL
# Industry: Computer Manufacturing
# Trailing P/E Ratio: 22.35. Industry Average: 72.34.
# Forward P/E Ratio: 17.87. Industry Average: 23.92.
# Price to Sales Ratio: 4.62. Industry Average: 3.18.
# Price to Book Ratio: 13.05. Industry Average: 4.73.
# Enterprise Value to Revenue: 4.57. Industry Average: 3.194.
# Enterprise Value to EBITDA: 15.54. Industry Average: 12.47.
# Profit Margin: 21.24%. Industry Average: 7.16%.
# Operating Margin: 24.57%. Industry Average: 8.67%.
# Return on Assets: 11.35%. Industry Average: 2.92%.
# Return on Equity: 55.92%. Industry Average: 12.98%.
# Quarterly Revenue Growth: 1.80%
# Gross Profit: 98.39B. Industry Average: 16643300000.0.
# Quarterly Earnings Growth: -3.10%
# Debt to Equity: 119.40. Industry Average: 39.9.
# Current Ratio: 1.54. Industry Average: 1.77.
# Book Value Per Share: 20.36. Industry Average: 15.56.
# Beta: 1.25. Industry Average: 0.76.
# Forward Dividend & Yield: 0.011699999999999999

# %%
get_altman_zscore('AAPL')
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Invalid figure 'Total Current Assets' passed.
# C:\Users\kevin\Anaconda3\envs\tensorflow_env\lib\site-packages\IPython\core\interactiveshell.py:3334: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# %tb
# Out:
# ---------------------------------------------------------------------------
# SystemExit                                Traceback (most recent call last)
# <ipython-input-2-f6076df39a75> in <module>
# ----> 1 analyze('MCD')
#
# ~\Documents\Projects\Coding Projects\Stock Market\Stock-Market-Analysis\market.py in analyze(ticker, industry)
#     952             industry_debt_to_equity, industry_current_ratio, industry_bvps, industry_beta] = get_industry_averages()
#     953
# --> 954     altman_zscore = get_altman_zscore(ticker)
#     955     print("ANALYSIS FOR " + ticker)
#     956     print("Industry: " + str(industry))
#
# ~\Documents\Projects\Coding Projects\Stock Market\Stock-Market-Analysis\market.py in get_altman_zscore(ticker)
#     512     '''
#     513     # A = working capital / total assets
# --> 514     total_cur_assets = periodic_figure_values(financials_soup(ticker, "bs"), "Total Current Assets")[0]
# ...

# %%
preiodic_figurefinancials_soup('MCD', "bs")
# Out:
# <!DOCTYPE html>
# ...

# %%
tickers = list(get_tickers())
path = 'C:/Users/kevin/Documents/Projects/Coding Projects/Stock Market/Stock-Market-Analysis/'
#selection = [tickers[i] for i in range(len(tickers)) if i % 100 == 0] # Test trading
portfolio = get_portfolio_from_csv(file_name='transactions_alpha05_00001.csv', path=path)
transactions = run_trading_algo(selection, portfolio, time_averaged=True, time_averaged_period=5,
                                min_price_thresh=10, buy_alpha=0.05, short_alpha=0.00001,
                                append_to_csv=True, file_name='transactions_alpha0_05_0_00001.csv', path=path)
# Out:
# ---------------------------------------------------------------------------
# SystemExit                                Traceback (most recent call last)
# <ipython-input-5-2b3a4c24c39c> in <module>
# ----> 1 total_cur_assets = periodic_figure_values(financials_soup('MCD', "bs"), "Total Current Assets")[0]
#
# ~\Documents\Projects\Coding Projects\Stock Market\Stock-Market-Analysis\market.py in periodic_figure_values(soup, yahoo_figure)
#     126             row = title.parent
#     127         else:
# --> 128             sys.exit("Invalid figure '" + yahoo_figure + "' passed.")
#     129
#     130     cells = row.find_all("td")[1:] # exclude the <td> with figure name
#
# SystemExit: Invalid figure 'Total Current Assets' passed.

# %%
predict_price_time_averaged('MCD', 5)
# Out:
# Training XGB model with hyperparameter tuning... Make sure csv is updated.
# C:\Users\kevin\Anaconda3\envs\tensorflow_env\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# Test Score: 0.892595831427404
# RMSE: 16.405113
# Training XGB model with hyperparameter tuning... Make sure csv is updated.
# C:\Users\kevin\Anaconda3\envs\tensorflow_env\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# Test Score: 0.9233402641325593
# RMSE: 15.158128
# Training XGB model with hyperparameter tuning... Make sure csv is updated.
# C:\Users\kevin\Anaconda3\envs\tensorflow_env\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# ...

# %%
predict_price_time_averaged('BMY', 3)
# Out:
# Mean predicted price: 59.47427
# Median predicted price: 60.551
# Standard Dev. predicted price: 2.7517064
# (59.47427, 2.7517064)

# %%
get_portfolio_from_csv(file_name='transactions_alpha0_05_0_00001.csv')
# Out:
# {'FLWS': 53.0,
#  'ACAD': 41.0,
#  'ACIW': 6.0,
#  'AMD': 21.0,
#  'ALDR': 149.0,
#  'ALXN': 7.0,
#  'AOSL': 16.0,
#  'AABA': 198.0,
#  'AMRN': 106.0,
#  'AMBC': 41.0,
#  'DOX': 15.0,
#  'APEI': 12.0,
#  'AMSWA': 3.0,
#  'APLS': 14.0,
#  'APPN': 24.0,
#  'ARCC': 10.0,
#  'ARWR': 35.0,
#  'BFIN': 29.0,
#  'BRY': 45.0,
#  'BILI': 66.0,
#  'BFRA': 30.0,
#  'BCOR': 20.0,
#  'BOKF': 14.0,
#  'BDGE': 13.0,
#  'BRKR': 11.0,
#  'CHRW': 8.0,
#  'CSIQ': 34.0,
#  'CPLP': 29.0,
#  'CSWC': 12.0,
#  'CBLK': 37.0,
#  'CARG': 72.0,
#  'CENT': 22.0,
#  'CVCY': 11.0,
#  'CZWI': 16.0,
#  'COHU': 22.0,
#  'CLBK': 12.0,
#  'CMCSA': 5.0,
#  'CNOB': 13.0,
#  'ROAD': 30.0,
#  'CORE': 4.0,
#  'ICBK': 8.0,
#  'COWN': 19.0,
#  'CRNX': 6.0,
#  'CCRN': 22.0,
#  'CTRP': 47.0,
#  'CMLS': 42.0,
#  'CYBR': 7.0,
#  'DNLI': 33.0,
#  'DCOM': 25.0,
#  'DISCB': 37.0,
#  'DGICA': 14.0,
#  'DBX': 29.0,
#  'DNKN': 18.0,
#  'DXPE': 7.0,
#  'EBIX': 22.0,
#  'SATS': 28.0,
#  'EIGR': 23.0,
#  'ESCA': 7.0,
#  'ESSA': 18.0,
# ...

# %%
compute_returns(filename='transactions_alpha0_05_0_00001.csv')
# Out:
# Starting amount: $500000
# Buying 56.0 shares of FLWS for $56.0, totalling $724.64. Capital is now $499275.36
# Buying 50.0 shares of ACAD for $50.0, totalling $2302.0. Capital is now $496973.36
# Buying 6.0 shares of ACIW for $6.0, totalling $200.52. Capital is now $496772.83999999997
# Buying 22.0 shares of AMD for $22.0, totalling $806.3. Capital is now $495966.54
# Buying 81.0 shares of ALDR for $81.0, totalling $1534.95. Capital is now $494431.58999999997
# Buying 6.0 shares of ALXN for $6.0, totalling $654.12. Capital is now $493777.47
# Buying 33.0 shares of AOSL for $33.0, totalling $417.78000000000003. Capital is now $493359.68999999994
# Buying 234.0 shares of AABA for $234.0, totalling $4577.04. Capital is now $488782.64999999997
# Buying 92.0 shares of AMRN for $92.0, totalling $1974.3200000000002. Capital is now $486808.32999999996
# Buying 52.0 shares of AMBC for $52.0, totalling $1067.04. Capital is now $485741.29
# ...

# %%
predict_price_time_averaged('BMY', 10)
# Out:
# Mean predicted price: 64.53385
# Median predicted price: 60.616817
# Standard Dev. predicted price: 7.760044
# (64.53385, 7.760044)

# %%
with open('csv_files/company_statistics.csv', newline='') as f:
        reader = csv.reader(f)
        company_matrix = np.array(list(reader))
        company_matrix = np.delete(company_matrix, (0), axis=0)
list(company_matrix[:, 0])
# Out:
# ['PIH',
#  'TURN',
#  'FLWS',
#  'FCCY',
#  'SRCE',
#  'VNET',
#  'TWOU',
#  'JOBS',
#  'EGHT',
#  'AAON',
#  'ABEO',
#  'ABIL',
#  'ABMD',
#  'AXAS',
#  'ACIU',
#  'ACIA',
#  'ACTG',
#  'ACHC',
#  'ACAD',
#  'ACST',
#  'AXDX',
#  'XLRN',
#  'ARAY',
#  'ACRX',
#  'ACER',
#  'ACHV',
#  'ACHN',
#  'ACIW',
#  'ACRS',
#  'ACMR',
#  'ACOR',
#  'ATVI',
#  'ADMS',
#  'ADMP',
#  'ADAP',
#  'ADUS',
#  'AEY',
#  'IOTS',
#  'ADIL',
#  'ADMA',
#  'ADBE',
#  'ADOM',
#  'ADTN',
#  'ADRO',
#  'ADES',
#  'AEIS',
#  'AMD',
#  'ADXS',
#  'ADVM',
#  'AEGN',
#  'AGLE',
#  'AEHR',
#  'AMTX',
#  'AERI',
#  'AVAV',
#  'ARPO',
#  'AEZS',
#  'AEMD',
#  'GNMX',
#  'AFMD',
#  'AGEN',
#  'AGRX',
#  'AGYS',
#  'AGIO',
#  'AGNC',
#  'AGFS',
#  'ALRN',
#  'AIMT',
#  'ATSG',
#  'AIRG',
#  'AKAM',
#  'AKTX',
#  'AKCA',
#  'AKBA',
#  'AKER',
#  'AKRX',
#  'AKTS',
#  'ALRM',
#  'ALSK',
#  'ALBO',
#  'ABDC',
#  'ALDR',
#  'ALDX',
#  'ALXN',
#  'ALCO',
#  'ALGN',
#  'ALIM',
#  'ALYA',
#  'ALKS',
#  'ALLK',
#  'ABTX',
# ...
